# %%
import csv

# %%
tbl_EspecieEmpenhocsv = open('tbl_EspecieEmpenho.csv')

# %%
tbl_EspecieEmpenhoreader = csv.reader(tbl_EspecieEmpenhocsv)

# %%
tbl_EspecieEmpenhoLista = list(tbl_EspecieEmpenhoreader)

# %%
tbl_EspecieEmpenhoLista
# Out:
# [['ï»¿--------------------------------------------------------------------------------------------------------------------'],
#  ['|        CÃ³d        |                                          DescriÃ§Ã£o                                           |'],
#  ['--------------------------------------------------------------------------------------------------------------------'],
#  ['|                -9 | NAO SE APLICA                                                                                |'],
#  ['--------------------------------------------------------------------------------------------------------------------'],
#  ['|                -8 | SEM INFORMACAO                                                                               |'],
#  ['--------------------------------------------------------------------------------------------------------------------'],
# ...
