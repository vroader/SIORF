# %%
import pandas as pd
import sqlalchemy
import csv

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://siorf:PMseis06@mysql.siorf.kinghost.net:3306/siorf')

# %%
tbl_GDFNaturezaDespesaDetalhada = open('tbl_GDFNaturezaDespesaDetalhada.csv')

# %%
NaturezaDespesaDetalhada_Readeble = csv.reader(tbl_GDFNaturezaDespesaDetalhada)

# %%
NaturezaDespesaDetalhada = list(NaturezaDespesaDetalhada_Readeble)

# %%
NaturezaDespesaDetalhada
# Out:
# [['',
#   '',
#   '',
#   '',
#   '',
#   'GOVERNO DO DISTRITO FEDERAL',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   'Classificação Orçamentária',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Tipo Classificação',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'D - Natureza da Despesa',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['', 'Classificação', '', '', '', '', '', '00000000', '', '', '', '', ''],
#  ['Código',
#   '',
#   '',
#   '',
#   'Nome da Classificação',
#   '',
#   '',
#   '',
#   '',
#   'Tipo',
#   '',
#   '',
#   ''],
#  ['30000000',
#   '',
#   '',
#   '',
#   'DESPESAS CORRENTES',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'D',
#   '',
#   ''],
#  ['31000000',
#   '',
#   '',
#   '',
#   'PESSOAL E ENCARGOS SOCIAIS',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'D',
#   '',
#   ''],
#  ['31200000',
#   '',
#   '',
#   '',
#   'TRANSFERÊNCIAS À UNIÃO',
#   '',
#   '',
#   '',
#   '',
# ...

# %%
def is_number(num):
    try:
        float(num)
        return True
    except:
        pass 
    return False

# %%
NaturezaDespesaDetalhadaLimpa = []

# %%
for lista in NaturezaDespesaDetalhada:
    if is_number(lista[0]):
        listaLimpa = []
        listaLimpa.append(lista[0])
        listaLimpa.append(lista[4])
        #for elemento in lista:
            #if elemento != '' and elemento != 'D'and elemento != '"':
                #listaLimpa.append(elemento)                               
        NaturezaDespesaDetalhadaLimpa.append(listaLimpa)
print( NaturezaDespesaDetalhadaLimpa)
# Out:
# [['30000000', 'DESPESAS CORRENTES'], ['31000000', 'PESSOAL E ENCARGOS SOCIAIS'], ['31200000', 'TRANSFERÊNCIAS À UNIÃO'], ['31209100', 'SENTENÇAS JUDICIAIS'], ['31209101', 'ACORDO TRABALHISTA/JUDICIAL'], ['31209102', 'PRECATÓRIOS ALIMENTARES'], ['31209103', 'PRECATÓRIOS NÃO ALIMENTARES'], ['31209104', 'REQUISIÇÕES JUDICIAIS DE PEQUENO VALOR'], ['31209105', 'SENTENÇAS JUDICIAIS A EX-EMPREGADOS'], ['31209106', 'FGTS'], ['31209107', 'INSS EMPREGADOR'], ['31209108', 'HONORÁRIO'], ['31209109', 'CUSTAS'], ['31209110', 'MANDADOS DE SEGURANÇA E MEDIDAS CAUTELARES'], ['31209141', 'MULTAS DEDUTÍVEIS'], ['31209142', 'JUROS E ENCARGOS'], ['31209144', 'MULTAS INDEDUTÍVEIS'], ['31209199', 'OUTRAS SENTENÇAS JUDICIAIS'], ['31209600', 'RESSARCIMENTO DE DESPESAS DE PESSOAL REQUISITADO'], ['31209601', 'PESSOAL CIVIL'], ['31209602', 'PESSOAL MILITAR'], ['31500000', 'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS SEM FINS LUCRATIVOS'], ['31509200', 'DESPESAS DE EXERCÍCIOS ANTERIORES'], ['31509234', 'OUTRAS DESPES
# ...

# %%
NaturezaDespesaDetalhadaCompleta = []

# %%
for linha in NaturezaDespesaDetalhadaLimpa:    
    linha.append(linha[0][0])
    linha.append(linha[0][1])
    linha.append(linha[0][2:4])
    linha.append(linha[0][6:])
    NaturezaDespesaDetalhadaCompleta.append(linha)
print(NaturezaDespesaDetalhadaCompleta)

# %%
for registro in NaturezaDespesaDetalhadaCompleta:
    engine.execute('INSERT INTO tbl_GDFNaturezaDespesaDetalhada (ndf_Codigo, ndf_Descricao, ndf_CategoriaEconomica, ndf_GrupoDespesa, ndf_ModalidadeAplicacao, ndf_ElementoDespesa) values ("'+registro[0]+'","'+registro[1]+'","'+registro[2]+'","'+registro[3]+'","'+registro[4]+'","'+registro[5]+'");')

# %%
NaturezaDespesaDetalhadaCompleta.dataframe()

# %%
NaturezaDespesaDetalhadaCompleta.head()

# %%
from pandas import DataFrame

df = DataFrame (NaturezaDespesaDetalhadaCompleta,columns=['NaturezaDetalhada', 'Descricao', 'Categoria','Grupo', 'Modalidade', 'Elemento',])

# %%
print(df)
