# %%
import pandas as pd
import sqlalchemy
import csv

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://siorf:PMseis06@mysql.siorf.kinghost.net:3306/siorf')

# %%
tbl_FCDFNaturezaDespesaDetalhada = open('tbl_FCDFNaturezaDespesaDetalhada.csv')

# %%
#NaturezaDespesaDetalhada_Readeble = csv.reader(tbl_FCDFNaturezaDespesaDetalhada)

# %%
NaturezaDespesaDetalhada_Readeble = csv.reader(tbl_FCDFNaturezaDespesaDetalhada, delimiter=';')

# %%
NaturezaDespesaDetalhada = list(NaturezaDespesaDetalhada_Readeble)

# %%
NaturezaDespesaDetalhada
# Out:
# [['Natureza Despesa Detalhada', '', '', '', '', '', ''],
#  ['-7', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '-7'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '-9'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '1'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '2'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '3'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '4'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '6'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '8'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '9'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '10'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '11'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '12'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '13'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '14'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '15'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '16'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '17'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '18'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '19'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '20'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '21'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '22'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '23'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '24'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '25'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '26'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '27'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '28'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '29'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '30'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '31'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '32'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '33'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '34'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '35'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '36'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '37'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '38'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '39'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '40'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '41'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '42'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '43'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '44'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '45'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '46'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '47'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '48'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '49'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '50'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '51'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '52'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '53'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '56'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '57'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '58'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '59'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '61'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '62'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '63'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '64'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '65'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '68'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '69'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '70'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '74'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '75'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '76'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '77'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '78'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '79'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '80'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '81'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '82'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '83'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '85'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '86'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '88'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '90'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '91'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '92'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '93'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '95'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '96'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '97'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '98'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '99'],
#  ['-8', 'SEM INFORMACAO', '-8', '-8', '-8', '-8', '-8'],
#  ['-9', 'NAO SE APLICA', '-9', '-9', '-9', '-9', '-9'],
#  ['0', 'VALOR DE ESCAPE - SIAFIWEB', '0', '0', '0', '0', '0'],
#  ['1', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '0', '1'],
#  ['14', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '0', '14'],
#  ['351', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '3', '51'],
#  ['495', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '4', '95'],
#  ['609', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '6', '9'],
#  ['699', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '6', '99'],
#  ['721', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '7', '21'],
#  ['748', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '7', '48'],
#  ['927', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '9', '27'],
#  ['972', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '9', '72'],
#  ['1781', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '17', '81'],
#  ['1992', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '19', '92'],
#  ['2650', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '26', '50'],
#  ['3390', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '33', '90'],
#  ['4105', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '41', '5'],
#  ['4364', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '43', '64'],
#  ['5850', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '58', '50'],
#  ['6842', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '68', '42'],
#  ['7112', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '71', '12'],
#  ['8082', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '80', '82'],
#  ['10800', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '8', '0'],
#  ['12490', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '24', '90'],
#  ['13129', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '31', '29'],
#  ['13195', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '31', '95'],
#  ['16138', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '61', '38'],
#  ['16984', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '69', '84'],
#  ['17747', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '77', '47'],
#  ['19124', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '91', '24'],
#  ['19391', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '93', '91'],
#  ['21587', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '15', '87'],
#  ['22861', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '28', '61'],
#  ['27000', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '70', '0'],
#  ['27562', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '75', '62'],
#  ['29428', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '94', '28'],
#  ['31002', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '3', '10', '2'],
#  ['32823', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '3', '28', '23'],
#  ['40934', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '9', '34'],
#  ['41588', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '15', '88'],
#  ['45337', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '53', '37'],
#  ['49351', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '93', '51'],
#  ['50096', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '5', '0', '96'],
#  ['54112', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '5', '41', '12'],
#  ['60876', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '8', '76'],
#  ['61329', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '13', '29'],
#  ['64019', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '40', '19'],
#  ['66150', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '61', '50'],
#  ['74939', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '7', '49', '39'],
#  ['78453', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '7', '84', '53'],
#  ['104525', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '10', '45', '25'],
#  ['116949', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '11', '69', '49'],
#  ['123736', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '12', '37', '36'],
#  ['133755', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '13', '37', '55'],
#  ['148491', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '14', '84', '91'],
#  ['001788-7', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '17', '88', '-7'],
#  ['181577', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '15', '77'],
#  ['183120', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '31', '20'],
#  ['183960', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '39', '60'],
#  ['184097', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '40', '97'],
#  ['194460', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '44', '60'],
#  ['196665', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '66', '65'],
#  ['199271', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '92', '71'],
#  ['205059', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '20', '50', '59'],
#  ['206115', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '20', '61', '15'],
#  ['212990', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '21', '29', '90'],
#  ['219077', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '21', '90', '77'],
#  ['222973', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '22', '29', '73'],
#  ['249607', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '24', '96', '7'],
#  ['251729', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '25', '17', '29'],
#  ['253071', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '25', '30', '71'],
#  ['267318', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '26', '73', '18'],
#  ['283339', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '28', '33', '39'],
#  ['287861', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '28', '78', '61'],
#  ['411306', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '41', '13', '6'],
#  ['829884', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '82', '98', '84'],
#  ['1013916', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '1', '39', '16'],
#  ['1022279', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '2', '22', '79'],
#  ['1326636', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '32', '66', '36'],
#  ['1377556', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '37', '75', '56'],
#  ['1657605', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '65', '76', '5'],
#  ['2127105', 'CODIGO INEXISTENTE NO SIAFI', '0', '2', '12', '71', '5'],
#  ['3390309', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '9'],
#  ['3390363', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '63'],
#  ['3390390', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '90'],
#  ['3390391', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '91'],
#  ['3390398', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '98'],
#  ['3390399', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '99'],
#  ['3390460', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '4', '60'],
#  ['3390923', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '9', '23'],
#  ['3391471', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '14', '71'],
#  ['3761577', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '76', '15', '77'],
#  ['6674266', 'CODIGO INEXISTENTE NO SIAFI', '0', '6', '67', '42', '66'],
#  ['79500', 'CODIGO INEXISTENTE NO SIAFI', '0', '7', '95', '0', '0'],
#  ['19008005', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '0', '80', '5'],
#  ['19011001', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '10', '1'],
#  ['19011301', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '13', '1'],
#  ['19011402', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '2'],
#  ['19011403', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '3'],
#  ['19011405', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '5'],
#  ['19011406', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '6'],
#  ['19092001', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '9', '20', '1'],
#  ['22339000', 'CODIGO INEXISTENTE NO SIAFI', '2', '2', '33', '90', '0'],
#  ['22410000', 'CODIGO INEXISTENTE NO SIAFI', '2', '2', '41', '0', '0'],
#  ['300000-7', 'CODIGO INVALIDO', '3', '0', '0', '0', '-7'],
#  ['300000-9', 'NAO SE APLICA', '3', '0', '0', '0', '-9'],
#  ['30000000', 'DESPESAS CORRENTES', '3', '0', '0', '0', '0'],
#  ['310000-7', 'CODIGO INVALIDO', '3', '1', '0', '0', '-7'],
#  ['310000-9', 'NAO SE APLICA', '3', '1', '0', '0', '-9'],
#  ['31000000', 'PESSOAL E ENCARGOS SOCIAIS', '3', '1', '0', '0', '0'],
#  ['31000001', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '1'],
#  ['31000002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '2'],
#  ['31000003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '3'],
#  ['31000005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '5'],
#  ['31000006', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '6'],
#  ['31000007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '7'],
#  ['31000008', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '8'],
#  ['31000009', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '9'],
#  ['31000010', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '10'],
#  ['31000012', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '12'],
#  ['31000013', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '13'],
#  ['31000021', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '21'],
#  ['31000026', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '26'],
#  ['31000027', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '27'],
#  ['31000032', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '32'],
#  ['31000033', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '33'],
#  ['31000040', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '40'],
#  ['31000042', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '42'],
#  ['31000043', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '43'],
#  ['31000044', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '44'],
#  ['31000045', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '45'],
#  ['31000046', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '46'],
#  ['31000099', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '99'],
#  ['313000-7', 'CODIGO INVALIDO', '3', '1', '30', '0', '-7'],
#  ['313000-8', 'SEM INFORMACAO', '3', '1', '30', '0', '-8'],
#  ['313000-9', 'NAO SE APLICA', '3', '1', '30', '0', '-9'],
#  ['31300000',
#   'TRANSF. A ESTADOS E AO DISTRITO FEDERAL',
#   '3',
#   '1',
#   '30',
#   '0',
#   '0'],
#  ['313041-7', 'CODIGO INVALIDO', '3', '1', '30', '41', '-7'],
#  ['313041-8', 'SEM INFORMACAO', '3', '1', '30', '41', '-8'],
#  ['313041-9', 'NAO SE APLICA', '3', '1', '30', '41', '-9'],
#  ['31304100', 'CONTRIBUICOES', '3', '1', '30', '41', '0'],
#  ['31304101', 'ACRE', '3', '1', '30', '41', '1'],
#  ['31304103', 'ALAGOAS', '3', '1', '30', '41', '3'],
#  ['31304104', 'AMAPA', '3', '1', '30', '41', '4'],
#  ['31304105', 'AMAZONAS', '3', '1', '30', '41', '5'],
#  ['31304107', 'BAHIA', '3', '1', '30', '41', '7'],
#  ['31304109', 'CEARA', '3', '1', '30', '41', '9'],
#  ['31304111', 'DISTRITO FEDERAL', '3', '1', '30', '41', '11'],
#  ['31304113', 'ESPIRITO SANTO', '3', '1', '30', '41', '13'],
#  ['31304115', 'GOIAS', '3', '1', '30', '41', '15'],
#  ['31304117', 'MARANHAO', '3', '1', '30', '41', '17'],
#  ['31304119', 'MATO GROSSO', '3', '1', '30', '41', '19'],
#  ['31304121', 'MATO GROSSO DO SUL', '3', '1', '30', '41', '21'],
#  ['31304123', 'MINAS GERAIS', '3', '1', '30', '41', '23'],
#  ['31304125', 'PARA', '3', '1', '30', '41', '25'],
#  ['31304127', 'PARAIBA', '3', '1', '30', '41', '27'],
#  ['31304129', 'PARANA', '3', '1', '30', '41', '29'],
#  ['31304131', 'PERNAMBUCO', '3', '1', '30', '41', '31'],
#  ['31304133', 'PIAUI', '3', '1', '30', '41', '33'],
#  ['31304135', 'RIO DE JANEIRO', '3', '1', '30', '41', '35'],
#  ['31304137', 'RIO GRANDE DO NORTE', '3', '1', '30', '41', '37'],
#  ['31304139', 'RIO GRANDE DO SUL', '3', '1', '30', '41', '39'],
#  ['31304141', 'RONDONIA', '3', '1', '30', '41', '41'],
#  ['31304142', 'RORAIMA', '3', '1', '30', '41', '42'],
#  ['31304143', 'SANTA CATARINA', '3', '1', '30', '41', '43'],
#  ['31304145', 'SAO PAULO', '3', '1', '30', '41', '45'],
#  ['31304147', 'SERGIPE', '3', '1', '30', '41', '47'],
#  ['31304148', 'TOCANTINS', '3', '1', '30', '41', '48'],
#  ['31304184',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '30',
#   '41',
#   '84'],
#  ['31304190',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '30',
#   '41',
#   '90'],
#  ['31304198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '30', '41', '98'],
#  ['31304199', 'OUTRAS CONTRIBUICOES', '3', '1', '30', '41', '99'],
#  ['31309900', 'NAO SE APLICA', '3', '1', '30', '99', '0'],
#  ['317000-7', 'CODIGO INVALIDO', '3', '1', '70', '0', '-7'],
#  ['317000-9', 'NAO SE APLICA', '3', '1', '70', '0', '-9'],
#  ['31700000',
#   'TRANSF. A INSTITUICOES MULTIGOVERNAMENTAIS',
#   '3',
#   '1',
#   '70',
#   '0',
#   '0'],
#  ['317041-7', 'CODIGO INVALIDO', '3', '1', '70', '41', '-7'],
#  ['317041-9', 'NAO SE APLICA', '3', '1', '70', '41', '-9'],
#  ['31704100', 'CONTRIBUICOES', '3', '1', '70', '41', '0'],
#  ['317100', 'SEM INFORMACAO', '3', '1', '71', '0', '-8'],
#  ['317100-7', 'CODIGO INVALIDO', '3', '1', '71', '0', '-7'],
#  ['317100-9', 'NAO SE APLICA', '3', '1', '71', '0', '-9'],
#  ['31710000',
#   'TRANSF.CONSOR.PUB.MEDIANTE CONTRATO DE RATEIO',
#   '3',
#   '1',
#   '71',
#   '0',
#   '0'],
#  ['317111', 'SEM INFORMACAO', '3', '1', '71', '11', '-8'],
#  ['317111-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '11', '-9'],
#  ['31711100', 'NAO SE APLICA', '3', '1', '71', '11', '0'],
#  ['31711101',
#   'TRANSFERENCIAS A CONSORCIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '11',
#   '1'],
#  ['31711133', 'VENCIMENTOS E SALARIOS', '3', '1', '71', '11', '33'],
#  ['317116', 'SEM INFORMACAO', '3', '1', '71', '16', '-8'],
#  ['317116-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '16', '-9'],
#  ['31711600', 'NAO SE APLICA', '3', '1', '71', '16', '0'],
#  ['31711601',
#   'TRANSFERENCIAS A CONSORCIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '16',
#   '1'],
#  ['317170', 'SEM INFORMACAO', '3', '1', '71', '70', '-8'],
#  ['31717000', 'NAO SE APLICA', '3', '1', '71', '70', '0'],
#  ['31717001',
#   'TRANSFERENCIA PARA CONSORICIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '70',
#   '1'],
#  ['317196', 'SEM INFORMACAO', '3', '1', '71', '96', '-8'],
#  ['317196-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '96', '-9'],
#  ['31719600', 'NAO SE APLICA', '3', '1', '71', '96', '0'],
#  ['31719601',
#   'TRANSFERENCIA A CONSORCIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '96',
#   '1'],
#  ['317300-7', 'CODIGO INVALIDO', '3', '1', '73', '0', '-7'],
#  ['317300-9', 'NAO SE APLICA', '3', '1', '73', '0', '-9'],
#  ['31730000',
#   'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12',
#   '3',
#   '1',
#   '73',
#   '0',
#   '0'],
#  ['317370-7', 'CODIGO INVALIDO', '3', '1', '73', '70', '-7'],
#  ['317370-9', 'NAO SE APLICA', '3', '1', '73', '70', '-9'],
#  ['31737000',
#   'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO',
#   '3',
#   '1',
#   '73',
#   '70',
#   '0'],
#  ['317400-7', 'CODIGO INVALIDO', '3', '1', '74', '0', '-7'],
#  ['317400-9', 'NAO SE APLICA', '3', '1', '74', '0', '-9'],
#  ['31740000',
#   'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12',
#   '3',
#   '1',
#   '74',
#   '0',
#   '0'],
#  ['317470-7', 'CODIGO INVALIDO', '3', '1', '74', '70', '-7'],
#  ['317470-9', 'NAO SE APLICA', '3', '1', '74', '70', '-9'],
#  ['31747000',
#   'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO',
#   '3',
#   '1',
#   '74',
#   '70',
#   '0'],
#  ['318000-7', 'CODIGO INVALIDO', '3', '1', '80', '0', '-7'],
#  ['318000-8', 'SEM INFORMACAO', '3', '1', '80', '0', '-8'],
#  ['318000-9', 'NAO SE APLICA', '3', '1', '80', '0', '-9'],
#  ['31800000', 'TRANSFEENCIAS AO EXTERIOR', '3', '1', '80', '0', '0'],
#  ['318004-7', 'CODIGO INVALIDO', '3', '1', '80', '4', '-7'],
#  ['318004-9', 'NAO SE APLICA', '3', '1', '80', '4', '-9'],
#  ['31800400', 'CONTRATACAO POR TEMPO DETERMINADO', '3', '1', '80', '4', '0'],
#  ['31803400', 'NAO SE APLICA', '3', '1', '80', '34', '0'],
#  ['31809900', 'NAO SE APLICA', '3', '1', '80', '99', '0'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '1'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '6'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '9'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '16'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '28'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '30'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '34'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '87'],
#  ['319000-7', 'CODIGO INVALIDO', '3', '1', '90', '0', '-7'],
#  ['319000-8', 'SEM INFORMACAO', '3', '1', '90', '0', '-8'],
#  ['319000-9', 'NAO SE APLICA', '3', '1', '90', '0', '-9'],
#  ['31900000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '0'],
#  ['31900002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '2'],
#  ['31900003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '3'],
#  ['31900004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '4'],
#  ['31900005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '5'],
#  ['31900007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '7'],
#  ['319000EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '-2'],
#  ['319000ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '-1'],
#  ['319001-7', 'CODIGO INVALIDO', '3', '1', '90', '1', '-7'],
#  ['319001-8', 'SEM INFORMACAO', '3', '1', '90', '1', '-8'],
#  ['319001-9', 'NAO SE APLICA', '3', '1', '90', '1', '-9'],
#  ['31900100',
#   'APOSENT.RPPS, RESER.REMUNER. E REFOR.MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '0'],
#  ['31900101', 'PROVENTOS - PESSOAL CIVIL', '3', '1', '90', '1', '1'],
#  ['31900102', 'ABONO PROVISORIO', '3', '1', '90', '1', '2'],
#  ['31900103',
#   'APOSENT.PENDENTES APROV TCU - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '3'],
#  ['31900104',
#   'PROV ORIUNDOS ADICIONAL QUALIF - PES CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '4'],
#  ['31900105',
#   'VANTAGEM PESSOAL - LEI 8.216/91 PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '5'],
#  ['31900106', '13 SALARIO - PESSOAL CIVIL', '3', '1', '90', '1', '6'],
#  ['31900107',
#   'FERIAS VENCIDAS E PROPOR A APOSENTADOS CIVIS',
#   '3',
#   '1',
#   '90',
#   '1',
#   '7'],
#  ['31900108', 'ADIANTAMENTOS PECUNIARIOS', '3', '1', '90', '1', '8'],
#  ['31900109',
#   'ADICIONAL POR TEMPO DE SERVICO PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '9'],
#  ['31900110',
#   'ADICIONAL POR TEMPO DE SERVICO PESSOAL MILIT',
#   '3',
#   '1',
#   '90',
#   '1',
#   '10'],
#  ['31900111',
#   'ADICIONAL DE DISPONIBILIDADE MILITAR - INATIVO',
#   '3',
#   '1',
#   '90',
#   '1',
#   '11'],
#  ['31900112', '-7', '3', '1', '90', '1', '12'],
#  ['31900113', '-7', '3', '1', '90', '1', '13'],
#  ['31900114', 'ADICIONAL MILITAR', '3', '1', '90', '1', '14'],
#  ['31900115',
#   'COMPL. APOSENTADORIA -  PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '15'],
#  ['31900116',
#   'APOSENT ORIGINARIA DE SUBSIDIOS - PESSOAL CIV',
#   '3',
#   '1',
#   '90',
#   '1',
#   '16'],
#  ['31900117',
#   'VANTAGEM PECUNIARIA ESPECIAL - PESSOAL MILIT',
#   '3',
#   '1',
#   '90',
#   '1',
#   '17'],
#  ['31900118', 'LICENCA PREMIO - INATIVOS CIVIS', '3', '1', '90', '1', '18'],
#  ['31900119',
#   '13 SALARIO - PESSOAL  CIVIL - ENCARGOS  PREVIDENCIARIOSDA UNIAO - EPU.',
#   '3',
#   '1',
#   '90',
#   '1',
#   '19'],
#  ['31900120',
#   '13º SALARIO - APOSENTADORIA PENDENTE DE APROVACAO TCU',
#   '3',
#   '1',
#   '90',
#   '1',
#   '20'],
#  ['31900121', 'PROVENTOS - PESSOAL MILITAR', '3', '1', '90', '1', '21'],
#  ['31900122',
#   'VANTAGENS INCORPORADAS - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '22'],
#  ['31900123',
#   'AUXILIO-INVALIDEZ - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '23'],
#  ['31900125', 'PRO-LABORE (LEI 7711/88 ARTIGO 3)', '3', '1', '90', '1', '25'],
#  ['31900126', '13 SALARIO - PESSOAL MILITAR', '3', '1', '90', '1', '26'],
#  ['31900127',
#   'GRATIFICACOES ESPECIAIS A APOSENTADOS',
#   '3',
#   '1',
#   '90',
#   '1',
#   '27'],
#  ['31900128',
#   'VANTAGENS INCORPORADAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '28'],
#  ['31900129',
#   'PROVENTOS ORIGINARIAS DE GRAT.P/EXERC/FUNCOES',
#   '3',
#   '1',
#   '90',
#   '1',
#   '29'],
#  ['31900130',
#   'PROVENTOS ORIGINARIAS DE GRAT.P/EXERC. CARGO.',
#   '3',
#   '1',
#   '90',
#   '1',
#   '30'],
#  ['31900132',
#   'INCREMENTO PLANO DE CARGOS E SALARIOS JUDIC.',
#   '3',
#   '1',
#   '90',
#   '1',
#   '32'],
#  ['31900133',
#   'ADICIONAL TAREFA TEMPO CERTO (ART.23 MP 2131)',
#   '3',
#   '1',
#   '90',
#   '1',
#   '33'],
#  ['31900134',
#   'VANTAGENS PERMANENTES SENT.TRANSIT.JULG.CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '34'],
#  ['31900135',
#   'VANTAG.PERMANENTES SENT.TRANSIT.JULG.MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '35'],
#  ['31900136',
#   'GRATIFICACAO DE ATIVIDADES EXTERNAS - GAE',
#   '3',
#   '1',
#   '90',
#   '1',
#   '36'],
#  ['31900138',
#   'BENEFICIO ESPECIAL LEI 12.618/2012 - INATIVO',
#   '3',
#   '1',
#   '90',
#   '1',
#   '38'],
#  ['31900140',
#   'GRATIFICACOES ESPECIAIS A APOSENTADOS',
#   '3',
#   '1',
#   '90',
#   '1',
#   '40'],
#  ['31900146', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '1', '46'],
#  ['31900160', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '1', '60'],
#  ['31900165',
#   'BONUS DE EFICIENCIA E PRODUTIVIDADE',
#   '3',
#   '1',
#   '90',
#   '1',
#   '65'],
#  ['31900184',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '1',
#   '84'],
#  ['31900187',
#   'COMPLEMENTACAO DE APOSENTADORIAS - PES CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '87'],
#  ['31900189', 'OUTRAS REFORMAS - PESSOAL MILITAR', '3', '1', '90', '1', '89'],
#  ['31900190',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '1',
#   '90'],
#  ['31900196',
#   'APOSENTADORIAS E REFORMAS - PAGTO. ANTECIPADO',
#   '3',
#   '1',
#   '90',
#   '1',
#   '96'],
#  ['31900198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '1', '98'],
#  ['31900199', 'OUTRAS APOSENTADORIAS - CIVIS', '3', '1', '90', '1', '99'],
#  ['319001EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '1', '-2'],
#  ['319001ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '1', '-1'],
#  ['319003-7', 'CODIGO INVALIDO', '3', '1', '90', '3', '-7'],
#  ['319003-8', 'SEM INFORMACAO', '3', '1', '90', '3', '-8'],
#  ['319003-9', 'NAO SE APLICA', '3', '1', '90', '3', '-9'],
#  ['31900300', 'PENSOES DO RPPS E DO MILITAR', '3', '1', '90', '3', '0'],
#  ['31900301', 'PENSOES CIVIS', '3', '1', '90', '3', '1'],
#  ['31900302', 'PENSOES MILITARES', '3', '1', '90', '3', '2'],
#  ['31900303', '13 SALARIO - PENSOES CIVIS', '3', '1', '90', '3', '3'],
#  ['31900304', '13 SALARIO - PENSOES MILITARES', '3', '1', '90', '3', '4'],
#  ['31900305', 'PENSOES ESPECIAIS - PESSOAL CIVIL', '3', '1', '90', '3', '5'],
#  ['31900306',
#   'LICENCA-PREMIO PARA PENSIONISTA CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '6'],
#  ['31900307', 'COMPL. PENSOES - PESSOAL MILITAR', '3', '1', '90', '3', '7'],
#  ['31900308', 'PENSOES ESPECIAIS - PESSOAL MILITAR', '3', '1', '90', '3', '8'],
#  ['31900309',
#   'PENSOES ORIUNDAS DE ADIC DE QUALIFIC - CIVIS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '9'],
#  ['31900310',
#   'VANTAGENS PERM.SENT.JUD.TRANS.JULGADO - CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '10'],
#  ['31900311',
#   'VANTAG.PERM.SENT.JUD.TRANS.JULGADO - MILITAR',
#   '3',
#   '1',
#   '90',
#   '3',
#   '11'],
#  ['31900312',
#   'PENSOES A ANISTIADOS POLITICOS - CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '12'],
#  ['31900313',
#   'PENSOES A ANISTIADOS POLITICOS - MILITAR',
#   '3',
#   '1',
#   '90',
#   '3',
#   '13'],
#  ['31900314',
#   '13 SALARIO - PENSOES  CIVIL - ENCARGOS  PREVIDENCIARIOSPREVIDENCIARIOS DA UNIAO - EPU.',
#   '3',
#   '1',
#   '90',
#   '3',
#   '14'],
#  ['31900315',
#   'ADICIONAL DE DISPONIBILIDADE MILITAR - PENSIONISTA',
#   '3',
#   '1',
#   '90',
#   '3',
#   '15'],
#  ['31900316',
#   'PENSOES ORIGINARIAS DE SUBSIDIOS - CIVIS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '16'],
#  ['31900317', 'VANTAGEM PECUNIARIA ESPECIAL - VPE', '3', '1', '90', '3', '17'],
#  ['31900319',
#   'PENSOES ORIGINARIAS DE GRATIF.P/EXERC. FUNCAO',
#   '3',
#   '1',
#   '90',
#   '3',
#   '19'],
#  ['31900320',
#   'PENSOES ORIGINARIAS DE GRATIF.P/EXERC.DE CARG',
#   '3',
#   '1',
#   '90',
#   '3',
#   '20'],
#  ['31900322',
#   'RETR.ADIC.VARIAVEL E PRO-LABORE(LEI 7711/88)',
#   '3',
#   '1',
#   '90',
#   '3',
#   '22'],
#  ['31900323',
#   'RETRIBUICAO VARIAVEL SUPERINT. SEGURO PRIVADO',
#   '3',
#   '1',
#   '90',
#   '3',
#   '23'],
#  ['31900325',
#   'GRATIFICACOES ESPECIAIS_- PENSIONISTAS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '25'],
#  ['31900328',
#   'VANTAGENS INCORPORADAS - PENSIONISTAS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '28'],
#  ['31900330', '-7', '3', '1', '90', '3', '30'],
#  ['31900331', '-7', '3', '1', '90', '3', '31'],
#  ['31900332', '-7', '3', '1', '90', '3', '32'],
#  ['31900334',
#   'GRATIFICACAO DE ATIVIDADE JUDICIARIA - GAJ',
#   '3',
#   '1',
#   '90',
#   '3',
#   '34'],
#  ['31900336',
#   'GRATIFICACAO DE ATIVIDADES EXTERNAS - GAE',
#   '3',
#   '1',
#   '90',
#   '3',
#   '36'],
#  ['31900338',
#   'BENEFICIO ESPECIAL LEI 12.618/2012 - PENSAO',
#   '3',
#   '1',
#   '90',
#   '3',
#   '38'],
#  ['31900340',
#   'GRATIFICACOES ESPECIAIS_A PENSIONISTA',
#   '3',
#   '1',
#   '90',
#   '3',
#   '40'],
#  ['31900342', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '3', '42'],
#  ['31900360', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '3', '60'],
#  ['31900365',
#   'BONUS DE EFICIENCIA E PRODUTIVIDADE',
#   '3',
#   '1',
#   '90',
#   '3',
#   '65'],
#  ['31900384',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '3',
#   '84'],
#  ['31900386',
#   'COMPLEMENTACAO DE PENSOES - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '86'],
#  ['31900387',
#   'COMPLEMENTACAO DE PENSOES - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '3',
#   '87'],
#  ['31900389', 'OUTRAS PENSOES - MILITARES', '3', '1', '90', '3', '89'],
#  ['31900390',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '3',
#   '90'],
#  ['31900396', 'PENSOES - PAGAMENTO ANTECIPADO', '3', '1', '90', '3', '96'],
#  ['31900398', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '3', '98'],
#  ['31900399', 'OUTRAS PENSOES - CIVIS', '3', '1', '90', '3', '99'],
#  ['319003EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '3', '-2'],
#  ['319003ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '3', '-1'],
#  ['319004-7', 'CODIGO INVALIDO', '3', '1', '90', '4', '-7'],
#  ['319004-8', 'SEM INFORMACAO', '3', '1', '90', '4', '-8'],
#  ['319004-9', 'NAO SE APLICA', '3', '1', '90', '4', '-9'],
#  ['31900400', 'CONTRATACAO P/TEMPO DETERMINADO', '3', '1', '90', '4', '0'],
#  ['31900401', 'SALARIO CONTRATO TEMPORARIO', '3', '1', '90', '4', '1'],
#  ['31900402', 'SALARIO-FAMILIA', '3', '1', '90', '4', '2'],
#  ['31900403',
#   'ADICIONAL NOTURNO DE CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '3'],
#  ['31900405',
#   'ADICIONAL DE PERICULOSIDADE - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '5'],
#  ['31900406',
#   'ADICIONAL DE INSALUBRIDADE - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '6'],
#  ['31900407',
#   'ADICIONAL DE ATIVIDADES PENOSAS - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '7'],
#  ['31900408',
#   'ADIC.DE IRRADIACAO IONIZANTE - CONTR.TEMPORAR',
#   '3',
#   '1',
#   '90',
#   '4',
#   '8'],
#  ['31900409',
#   'GRATIFICACAO DE RAIO-X - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '9'],
#  ['31900410',
#   'SERVICOS EXTRAORDINARIOS - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '10'],
#  ['31900411',
#   'SERV.EXTRAORD. NOTURNO - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '11'],
#  ['31900412',
#   'FERIAS VENCIDAS/PROPORCIONAIS - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '12'],
#  ['31900413', '13¤ SALARIO - CONTRATO TEMPORARIO', '3', '1', '90', '4', '13'],
#  ['31900414',
#   'FERIAS - ABONO CONSTITUCIONAL - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '14'],
#  ['31900415',
#   'OBRIGACOES PATRONAIS - CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '15'],
#  ['31900416',
#   'FERIAS PAGAMENTO ANTECIPADO - CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '16'],
#  ['31900417',
#   'INDENIZACAO ? 2º ART.12 LEI 8.745/93',
#   '3',
#   '1',
#   '90',
#   '4',
#   '17'],
#  ['31900418',
#   'ADICIONAL REMUNERACAO DO MILITAR - ART.18 LEI 13.954/19',
#   '3',
#   '1',
#   '90',
#   '4',
#   '18'],
#  ['31900420',
#   'OUTRAS VANTAGENS CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '20'],
#  ['31900421', 'SALARIO FAMILIA LEI 8.745/93', '3', '1', '90', '4', '21'],
#  ['31900422',
#   'ADICIONAL NOTURNO CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '22'],
#  ['31900423',
#   'ADICIONAL DE PERICULOSIDADE CONT. TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '23'],
#  ['31900424',
#   'ADICIONAL DE INSALUBRIDADE CONT. TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '24'],
#  ['31900425',
#   'ADICIONAL DE ATIVIDADES PENOSAS CONT. TEMP.',
#   '3',
#   '1',
#   '90',
#   '4',
#   '25'],
#  ['31900426',
#   'ADICIONAL DE IRRADIACAO IONIZANTE CONT. TEMP.',
#   '3',
#   '1',
#   '90',
#   '4',
#   '26'],
#  ['31900427',
#   'GRATIFICACAO DE RAIO-X CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '27'],
#  ['31900428',
#   'SERVICOS EXTRAORDINARIOS CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '28'],
#  ['31900429',
#   'SERVICOS EXTRAORDINARIOS NOTURNO CONT. TEMP.',
#   '3',
#   '1',
#   '90',
#   '4',
#   '29'],
#  ['31900430',
#   'FERIAS VENCIDAS/PROPORCIONAIS CONT.TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '30'],
#  ['31900431', '13º SALARIO CONTRATO TEMPORARIO', '3', '1', '90', '4', '31'],
#  ['31900432', 'FERIAS - ABONO CONSTITUCIONAL', '3', '1', '90', '4', '32'],
#  ['31900433', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '4', '33'],
#  ['31900434',
#   'INDENIZACAO ? 2º ART.12 LEI 8.745/93',
#   '3',
#   '1',
#   '90',
#   '4',
#   '34'],
#  ['31900440', '-7', '3', '1', '90', '4', '40'],
#  ['31900441', '-7', '3', '1', '90', '4', '41'],
#  ['31900453',
#   'CONTRATACAO POR TEMPO DETERMINADO - PES.CIVIL',
#   '3',
#   '1',
#   '90',
#   '4',
#   '53'],
#  ['31900498', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '4', '98'],
#  ['31900499',
#   'OUTRAS VANTAGENS - CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '99'],
#  ['319004EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '4', '-2'],
#  ['319005-7', 'CODIGO INVALIDO', '3', '1', '90', '5', '-7'],
#  ['319005-8', 'SEM INFORMACAO', '3', '1', '90', '5', '-8'],
#  ['319005-9', 'NAO SE APLICA', '3', '1', '90', '5', '-9'],
#  ['31900500',
#   'OUTROS BENEF.PREV. DO SERVIDOR OU DO MILITAR',
#   '3',
#   '1',
#   '90',
#   '5',
#   '0'],
#  ['31900501', 'AUXILIO-RECLUSAO ATIVO CIVIL', '3', '1', '90', '5', '1'],
#  ['31900502', 'AUXILIO-RECLUSAO ATIVO MILITAR', '3', '1', '90', '5', '2'],
#  ['31900503', 'SALARIO-FAMILIA ATIVO CIVIL', '3', '1', '90', '5', '3'],
#  ['31900504', 'SALARIO-FAMILIA ATIVO MILITAR', '3', '1', '90', '5', '4'],
#  ['31900505', 'SALARIO-FAMILIA INATIVO CIVIL', '3', '1', '90', '5', '5'],
#  ['31900506', 'SALARIO-FAMILIA INATIVO MILITAR', '3', '1', '90', '5', '6'],
#  ['31900507', 'SALARIO-FAMILIA PENSIONISTA CIVIL', '3', '1', '90', '5', '7'],
#  ['31900508',
#   'SALARIO-FAMILIA PENSIONIOSTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '5',
#   '8'],
#  ['31900509', 'AUXILIO-DOENCA', '3', '1', '90', '5', '9'],
#  ['31900550', '-7', '3', '1', '90', '5', '50'],
#  ['31900599',
#   'OUTROS BENEF.PREV.SERVIDOR OU MILITAR',
#   '3',
#   '1',
#   '90',
#   '5',
#   '99'],
#  ['319007-7', 'CODIGO INVALIDO', '3', '1', '90', '7', '-7'],
#  ['319007-8', 'SEM INFORMACAO', '3', '1', '90', '7', '-8'],
#  ['319007-9', 'NAO SE APLICA', '3', '1', '90', '7', '-9'],
#  ['31900700',
#   'CONTRIB. A ENTIDADES FECHADAS DE PREVIDENCIA',
#   '3',
#   '1',
#   '90',
#   '7',
#   '0'],
#  ['31900701',
#   'CONTRIBUICAO PATRONAL PREVIDENCIA PRIVADA',
#   '3',
#   '1',
#   '90',
#   '7',
#   '1'],
#  ['31900702', 'SEGUROS', '3', '1', '90', '7', '2'],
#  ['31900703', 'CONT. PATRONAL PREVIDENCIA PRIVADA', '3', '1', '90', '7', '3'],
#  ['31900704',
#   'CONTRIBUICAO PATRONAL PREVIDENCIA PRIVADA-PDV',
#   '3',
#   '1',
#   '90',
#   '7',
#   '4'],
#  ['31900705',
#   'COMPLEM DE PREVID PRORROG SALAR MATERNIDADE',
#   '3',
#   '1',
#   '90',
#   '7',
#   '5'],
#  ['31900706',
#   'CONTRIBUICAO PATRONAL - FUNPRESP LEI 12618/12',
#   '3',
#   '1',
#   '90',
#   '7',
#   '6'],
#  ['31900714',
#   'MULTAS INDEDUTIVEIS - ENTIDADES FECHADAS DE PREVIDENCIA',
#   '3',
#   '1',
#   '90',
#   '7',
#   '14'],
#  ['31900770', '-7', '3', '1', '90', '7', '70'],
#  ['31900790',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '7',
#   '90'],
#  ['31900798', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '7', '98'],
#  ['31900799', 'OUTRAS CONTRIBUICOES', '3', '1', '90', '7', '99'],
#  ['319007EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '7', '-2'],
#  ['319008-7', 'CODIGO INVALIDO', '3', '1', '90', '8', '-7'],
#  ['319008-8', 'SEM INFORMACAO', '3', '1', '90', '8', '-8'],
#  ['319008-9', 'NAO SE APLICA', '3', '1', '90', '8', '-9'],
#  ['31900800',
#   'OUTROS BENEF.ASSIST. DO SERVIDOR E DO MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '0'],
#  ['31900801', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '1'],
#  ['31900802', 'AUXILIO FUNERAL ATIVO MILITAR', '3', '1', '90', '8', '2'],
#  ['31900803', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '3'],
#  ['31900804', 'AUXILIO FUNERAL INATIVO MILITAR', '3', '1', '90', '8', '4'],
#  ['31900805', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '5'],
#  ['31900806', 'AUXILIO NATALIDADE ATIVO MILITAR', '3', '1', '90', '8', '6'],
#  ['31900807', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '7'],
#  ['31900808', 'AUXILIO NATALIDADE INATIVO MILITAR', '3', '1', '90', '8', '8'],
#  ['31900809', 'AUXILIO RECLUSAO ATIVO CIVIL', '3', '1', '90', '8', '9'],
#  ['31900810', 'AUXILIO RECLUSAO ATIVO MILITAR', '3', '1', '90', '8', '10'],
#  ['31900811', 'AUXILIO RECLUSAO INATIVO CIVIL', '3', '1', '90', '8', '11'],
#  ['31900812', 'AUXILIO RECLUSAO INATIVO MILITAR', '3', '1', '90', '8', '12'],
#  ['31900813', 'AUXILIO FUNERAL PENSIONISTA CIVIL', '3', '1', '90', '8', '13'],
#  ['31900814',
#   'AUXILIO FUNERAL PENSIONISTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '14'],
#  ['31900815', 'AUXILIO RECLUSAO PENSIONISTA CIVIL', '3', '1', '90', '8', '15'],
#  ['31900816',
#   'AUXILIO RECLUSAO PENSIONISTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '16'],
#  ['31900817',
#   'AUXILIO NATALIDADE PENSIONISTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '17'],
#  ['31900818',
#   'AUXILIO NATALIDADE PENSIONISTA CIVIL',
#   '3',
#   '1',
#   '90',
#   '8',
#   '18'],
#  ['31900819', 'AUXILIO-FAMILIAR - NO EXTERIOR', '3', '1', '90', '8', '19'],
#  ['31900851', 'AUXILIO-DOENCA MEMBROS DO MPU', '3', '1', '90', '8', '51'],
#  ['31900884',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '8',
#   '84'],
#  ['31900890',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '8',
#   '90'],
#  ['31900898', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '98'],
#  ['31900899', 'OUTROS BENEFICIOS ASSISTENCIAIS', '3', '1', '90', '8', '99'],
#  ['319008EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '8', '-2'],
#  ['319008ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '8', '-1'],
#  ['319009', 'SEM INFORMACAO', '3', '1', '90', '9', '-8'],
#  ['319009-7', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-7'],
#  ['319009-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-9'],
#  ['31900900', 'NAO SE APLICA', '3', '1', '90', '9', '0'],
#  ['31900901',
#   'SALARIO FAMILIA - ATIVO PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '9',
#   '1'],
#  ['31900902',
#   'SALARIO FAMILIA-INATIVO PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '9',
#   '2'],
#  ['31900903',
#   'SALARIO FAMILIA-ATIVO PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '9',
#   '3'],
#  ['31900904',
#   'SALARIO FAMILIA - INATIVO PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '9',
#   '4'],
#  ['31900905',
#   'SALARIO FAMILIA-PENSIONISTA PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '9',
#   '5'],
#  ['31900906',
#   'SALARIO FAMILIA - PENSIONIOSTA PESS. MILITAR',
#   '3',
#   '1',
#   '90',
#   '9',
#   '6'],
#  ['31900984',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '9',
#   '84'],
#  ['31900990',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '9',
#   '90'],
#  ['31900998', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '9', '98'],
#  ['31900999', 'OUTROS SALARIOS-FAMILIA', '3', '1', '90', '9', '99'],
#  ['319009EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-2'],
#  ['319009ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-1'],
#  ['31901000', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '0'],
#  ['31901002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '2'],
#  ['31901003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '3'],
#  ['31901004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '4'],
#  ['31901005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '5'],
#  ['31901007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '7'],
#  ['319011-7', 'CODIGO INVALIDO', '3', '1', '90', '11', '-7'],
#  ['319011-8', 'SEM INFORMACAO', '3', '1', '90', '11', '-8'],
#  ['319011-9', 'NAO SE APLICA', '3', '1', '90', '11', '-9'],
#  ['31901100',
#   'VENCIMENTOS E VANTAGENS FIXAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '0'],
#  ['31901101', 'VENCIMENTOS E SALARIOS', '3', '1', '90', '11', '1'],
#  ['31901102', 'REMUNERACAO NO PERIODO DE FERIAS', '3', '1', '90', '11', '2'],
#  ['31901103', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '3'],
#  ['31901104', 'ADICIONAL NOTURNO', '3', '1', '90', '11', '4'],
#  ['31901105', 'INCORPORACOES', '3', '1', '90', '11', '5'],
#  ['31901106',
#   'VANTAGENS PERM.SENT.JUD.TRANS.JULGADO - CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '6'],
#  ['31901107', 'ABONO DE PERMANENCIA', '3', '1', '90', '11', '7'],
#  ['31901108',
#   'AUXILIO-DOENCA (LICENCA PARA TRATAMENTO DE SAUDE)',
#   '3',
#   '1',
#   '90',
#   '11',
#   '8'],
#  ['31901109', 'ADICIONAL DE PERICULOSIDADE', '3', '1', '90', '11', '9'],
#  ['31901110', 'ADICIONAL DE INSALUBRIDADE', '3', '1', '90', '11', '10'],
#  ['31901111', 'ADICIONAL DE ATIVIDADES PENOSAS', '3', '1', '90', '11', '11'],
#  ['31901112',
#   'RETRIBUICAO BASICA NO EXTERIOR - CIVIL (LEI 5.809/1972)',
#   '3',
#   '1',
#   '90',
#   '11',
#   '12'],
#  ['31901113', 'INCENTIVO A QUALIFICACAO', '3', '1', '90', '11', '13'],
#  ['31901114',
#   'ADICIONAL DE TRANSFERENCIA - ART. 469/CLT',
#   '3',
#   '1',
#   '90',
#   '11',
#   '14'],
#  ['31901115',
#   'APRENDIZES - CONTRATACAO DIRETA (LEI 10.097/2000)',
#   '3',
#   '1',
#   '90',
#   '11',
#   '15'],
#  ['31901116',
#   'GRATIFICACAO NO EXTERIOR POR TEMPO DE SERVICO - CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '16'],
#  ['31901117', '-7', '3', '1', '90', '11', '17'],
#  ['31901118', '-7', '3', '1', '90', '11', '18'],
#  ['31901119', '-7', '3', '1', '90', '11', '19'],
#  ['31901122', 'PRO-LABORE (LEI 10549/2002)', '3', '1', '90', '11', '22'],
#  ['31901123',
#   'RETRIBUICAO VARIAVEL SUPERINT. SEGURO PRIVADO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '23'],
#  ['31901128', 'VANTAGEM PECUNIARIA INDIVIDUAL', '3', '1', '90', '11', '28'],
#  ['31901130', 'ABONO PROVISORIO - PESSOAL CIVIL', '3', '1', '90', '11', '30'],
#  ['31901131',
#   'GRATIFICACAO POR EXERCICIO DE CARGO EFETIVO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '31'],
#  ['31901132',
#   'INCREMENTO PLANO DE CARGOS E SALARIOS JUDIC.',
#   '3',
#   '1',
#   '90',
#   '11',
#   '32'],
#  ['31901133',
#   'GRAT POR EXERCICIO DE FUNCOES COMISSIONADAS',
#   '3',
#   '1',
#   '90',
#   '11',
#   '33'],
#  ['31901134',
#   'GRATIFICACAO DE ATIVIDADES JUDICIARIA - GAJ',
#   '3',
#   '1',
#   '90',
#   '11',
#   '34'],
#  ['31901135',
#   'GRATIFICACAO/ADICIONAL DE LOCALIZACAO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '35'],
#  ['31901136',
#   'GRATIFICACAO P/EXERCICIO DE CARGO EM COMISSAO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '36'],
#  ['31901137', 'GRATIFICACAO DE TEMPO DE SERVICO', '3', '1', '90', '11', '37'],
#  ['31901138',
#   'GRATIFICACAO DE ATIVIDADE DE SEGURANCA - GAS',
#   '3',
#   '1',
#   '90',
#   '11',
#   '38'],
#  ['31901139',
#   'BONUS ESPECIAL DE DESEMP. INSTIT. - BESP/DNIT',
#   '3',
#   '1',
#   '90',
#   '11',
#   '39'],
#  ['31901140', 'GRATIFICACOES ESPECIAIS', '3', '1', '90', '11', '40'],
#  ['31901141',
#   'GRATIFICACAO POR ATIVIDADES EXPOSTAS',
#   '3',
#   '1',
#   '90',
#   '11',
#   '41'],
#  ['31901142', 'FERIAS VENCIDAS E PROPORCIONAIS', '3', '1', '90', '11', '42'],
#  ['31901143', '13º SALARIO', '3', '1', '90', '11', '43'],
#  ['31901144', 'FERIAS - ABONO PECUNIARIO', '3', '1', '90', '11', '44'],
#  ['31901145', 'FERIAS - 1/3 CONSTITUCIONAL', '3', '1', '90', '11', '45'],
#  ['31901146', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '11', '46'],
#  ['31901147', 'LICENCA-PREMIO', '3', '1', '90', '11', '47'],
#  ['31901149', 'LICENCA CAPACITACAO', '3', '1', '90', '11', '49'],
#  ['31901150',
#   'VENCIM. E SAL.- PROR. SALARIO MATERNIDADE',
#   '3',
#   '1',
#   '90',
#   '11',
#   '50'],
#  ['31901160', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '11', '60'],
#  ['31901165',
#   'BONUS DE EFICIENCIA E PRODUTIVIDADE',
#   '3',
#   '1',
#   '90',
#   '11',
#   '65'],
#  ['31901171', 'REMUNERACAO DE DIRETORES', '3', '1', '90', '11', '71'],
#  ['31901173',
#   'REMUN. PARTICIP. ORGAOS DELIBERACAO  COLETIVA',
#   '3',
#   '1',
#   '90',
#   '11',
#   '73'],
#  ['31901174', 'SUBSIDIOS', '3', '1', '90', '11', '74'],
#  ['31901175', 'REPRESENTACAO MENSAL', '3', '1', '90', '11', '75'],
#  ['31901177',
#   'REMUNERACAO DE PESSOAL EM DISPONIBILIDADE',
#   '3',
#   '1',
#   '90',
#   '11',
#   '77'],
#  ['31901184',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '11',
#   '84'],
#  ['31901187',
#   'COMPLEMENTACAO SALARIAL - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '87'],
#  ['31901190',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '11',
#   '90'],
#  ['31901196',
#   'VENCIMENTOS E VANTAGENS - PAGTO. ANTECIPADO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '96'],
#  ['31901198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '11', '98'],
#  ['31901199',
#   'OUTRAS DESPESAS FIXAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '99'],
#  ['319011EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '-2'],
#  ['319011ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '-1'],
#  ['319012-7', 'CODIGO INVALIDO', '3', '1', '90', '12', '-7'],
#  ['319012-8', 'SEM INFORMACAO', '3', '1', '90', '12', '-8'],
#  ['319012-9', 'NAO SE APLICA', '3', '1', '90', '12', '-9'],
#  ['31901200',
#   'VENCIMENTOS E VANTAGENS FIXAS - PES. MILITAR',
#   '3',
#   '1',
#   '90',
#   '12',
#   '0'],
#  ['31901201', 'SOLDO', '3', '1', '90', '12', '1'],
#  ['31901202', 'ADICIONAL DE PERMANENCIA', '3', '1', '90', '12', '2'],
#  ['31901203', 'ADICIONAL DE TEMPO DE SERVICO', '3', '1', '90', '12', '3'],
#  ['31901204', 'ADICIONAL MILITAR', '3', '1', '90', '12', '4'],
#  ['31901205', 'ADICIONAL DE COMPENSACAO ORGANICA', '3', '1', '90', '12', '5'],
#  ['31901206', 'ADICIONAL DE HABILITACAO', '3', '1', '90', '12', '6'],
#  ['31901207',
#   'GRATIFICACAO DE LOCALIDADE ESPECIAL',
#   '3',
#   '1',
#   '90',
#   '12',
#   '7'],
#  ['31901208', 'GRATIFICACAO DE REPRESENTACAO', '3', '1', '90', '12', '8'],
#  ['31901209',
#   'GRATIFICACAO DE FUNCAO DE NATUREZA ESPECIAL',
#   '3',
#   '1',
#   '90',
#   '12',
#   '9'],
#  ['31901210',
#   'GRATIFICACAO DE SERVICO VOLUNTARIO.',
#   '3',
#   '1',
#   '90',
#   '12',
#   '10'],
#  ['31901211',
#   'VANTAGEM PECUNIARIA ESPECIAL - VPE.',
#   '3',
#   '1',
#   '90',
#   '12',
#   '11'],
#  ['31901212',
#   'RETRIBUICAO BASICA NO EXTERIOR - MILITAR (LEI 5.809/72)',
#   '3',
#   '1',
#   '90',
#   '12',
#   '12'],
#  ['31901213',
#   'VANTAG.PERM.SENT.JUD.TRANS.JULGADO - MILITAR',
#   '3',
#   '1',
#   '90',
#   '12',
#   '13'],
#  ['31901214',
#   'ADICIONAL DE DISPONIBILIDADE MILITAR - ATIVO',
#   '3',
#   '1',
#   '90',
#   '12',
#   '14'],
#  ['31901216',
# ...
#  ['31909198',
#   'INSCRICAO DE RESTOS A PAGAR - SENTENCAS JUDICIAIS',
#   '3',
#   '1',
#   '90',
#   '91',
#   '98'],
#  ['31909199', 'OUTRAS SENTENCAS JUDICIAIS', '3', '1', '90', '91', '99'],
#  ['319091EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '91', '-2'],
#  ['319091ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '91', '-1'],
#  ['319092-7', 'CODIGO INVALIDO', '3', '1', '90', '92', '-7'],
#  ['319092-8', 'SEM INFORMACAO', '3', '1', '90', '92', '-8'],
#  ['319092-9', 'NAO SE APLICA', '3', '1', '90', '92', '-9'],
#  ['31909200', 'DESPESAS DE EXERCICIOS ANTERIORES', '3', '1', '90', '92', '0'],
#  ['31909201',
#   'APOSENTADORIAS, RESERVA REMUNERADA E REFORMAS',
#   '3',
#   '1',
#   '90',
#   '92',
#   '1'],
#  ['31909202', 'INATIVO CIVIL', '3', '1', '90', '92', '2'],
#  ['31909203', 'PENSOES DO RPPS E DO MILITAR', '3', '1', '90', '92', '3'],
#  ['31909204', 'CONTRATACAO POR TEMPO DETERMINADO', '3', '1', '90', '92', '4'],
#  ['31909205',
#   'OUTROS BENEF.PREVID.DO SERVIDOR OU DO MILITAR',
#   '3',
#   '1',
#   '90',
#   '92',
#   '5'],
#  ['31909206',
#   'BENEFICIO MENSAL AO DEFICIENTE E AO IDOSO',
#   '3',
#   '1',
#   '90',
#   '92',
#   '6'],
#  ['31909207',
#   'CONTRIB. A ENTIDADES FECHADAS DE PREVIDENCIA',
#   '3',
#   '1',
#   '90',
#   '92',
#   '7'],
#  ['31909208',
#   'OUTROS BENEF.ASSIST DO SERVIDOR E DO MILITAR',
#   '3',
#   '1',
#   '90',
#   '92',
#   '8'],
#  ['31909209', 'SALARIO-FAMILIA', '3', '1', '90', '92', '9'],
#  ['31909210',
#   'OUTROS BENEFICIOS DE NATUREZA SOCIAL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '10'],
#  ['31909211',
#   'VENCIMENTOS E VANTAGENS FIXAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '11'],
#  ['31909212',
#   'VENCIMENTOS E VANTAGENS FIXAS-PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '92',
#   '12'],
#  ['31909213', 'OBRIGACOES PATRONAIS', '3', '1', '90', '92', '13'],
#  ['31909214', 'DIARIAS - CIVIL', '3', '1', '90', '92', '14'],
#  ['31909215', 'DIARIAS - MILITAR', '3', '1', '90', '92', '15'],
#  ['31909216',
#   'OUTRAS DESPESAS VARIAVEIS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '16'],
#  ['31909217',
#   'OUTRAS DESPESAS VARIAVEIS - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '92',
#   '17'],
#  ['31909218', 'AUXILIO FINANCEIRO A ESTUDANTES', '3', '1', '90', '92', '18'],
#  ['31909219', 'AUXILIO-FARDAMENTO', '3', '1', '90', '92', '19'],
#  ['31909220',
#   'PENSAO INDENIZ. - ANISTIADOS POLITICOS CIVIL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '20'],
#  ['31909221',
#   'PENSAO INDENIZ.ANISTIADOS POLITICOS - MILITAR',
#   '3',
#   '1',
#   '90',
#   '92',
#   '21'],
#  ['31909223',
#   'GRAT. TEMPO DE SERVICO-ANUENIO ATIVO CIVIL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '23'],
#  ['31909224',
#   'GRAT. TEMPO DE SERVICO-ANUENIO INATIVO CIVIL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '24'],
#  ['31909225',
#   'GRAT. TEMPO DE SERVICO-ANUENIO PENSION. CIVIL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '25'],
#  ['31909226',
#   'RESSARCIMENTO DE DESP. DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '90',
#   '92',
#   '26'],
#  ['31909227',
#   'GRAT. TEMPO DE SERVICO-ANUENIO ATIVO MILITAR',
#   '3',
#   '1',
#   '90',
#   '92',
#   '27'],
#  ['31909228',
#   'GRAT. TEMPO DE SERVICO-ANUENIO INAT. MILITAR',
#   '3',
#   '1',
#   '90',
#   '92',
#   '28'],
#  ['31909229', '-7', '3', '1', '90', '92', '29'],
#  ['31909230', 'ABONO PROVISORIO - ATIVO CIVIL', '3', '1', '90', '92', '30'],
#  ['31909231', 'ABONO PROVISORIO - INATIVO CIVIL', '3', '1', '90', '92', '31'],
#  ['31909232',
#   'ABONO PROVISORIO - PENSIONISTA CIVIL',
#   '3',
#   '1',
#   '90',
#   '92',
#   '32'],
#  ['31909234',
#   'OUTRAS DESP.PESSOAL DEC. CONTRATOS TERCEIRIZ.',
#   '3',
#   '1',
#   '90',
#   '92',
#   '34'],
#  ['31909236', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '92', '36'],
#  ['31909280', 'OUTROS BENEFICIOS ASSISTENCIAIS', '3', '1', '90', '92', '80'],
#  ['31909284',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '92',
#   '84'],
#  ['31909290',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '92',
#   '90'],
#  ['31909291', 'SENTENCAS JUDICIAIS', '3', '1', '90', '92', '91'],
#  ['31909293', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '92', '93'],
#  ['31909294',
#   'INDENIZACOES E RESTITUICOES TRABALHISTAS',
#   '3',
#   '1',
#   '90',
#   '92',
#   '94'],
#  ['31909296',
#   'RESSARC. DE DESPESAS DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '90',
#   '92',
#   '96'],
#  ['31909298', 'INSCRICAO DE RESTOS A PAGAR - DEA', '3', '1', '90', '92', '98'],
#  ['31909299',
#   'OUTRAS DESPESAS DE EXERCICIOS ANTERIORES',
#   '3',
#   '1',
#   '90',
#   '92',
#   '99'],
#  ['319092EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '92', '-2'],
#  ['319092ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '92', '-1'],
#  ['31909302', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '93', '2'],
#  ['319094-7', 'CODIGO INVALIDO', '3', '1', '90', '94', '-7'],
#  ['319094-8', 'SEM INFORMACAO', '3', '1', '90', '94', '-8'],
#  ['319094-9', 'NAO SE APLICA', '3', '1', '90', '94', '-9'],
#  ['31909400',
#   'INDENIZACOES E RESTITUICOES TRABALHISTAS',
#   '3',
#   '1',
#   '90',
#   '94',
#   '0'],
#  ['31909401',
#   'INDENIZACOES E RESTITUICOES TRAB. ATIVO CIVIL',
#   '3',
#   '1',
#   '90',
#   '94',
#   '1'],
#  ['31909402',
#   'INDENIZACOES E RESTITUICOES TRAB. ATIVO MIL.',
#   '3',
#   '1',
#   '90',
#   '94',
#   '2'],
#  ['31909403',
#   'INDENIZACOES E RESTITUICOES TRAB. INAT. CIVIL',
#   '3',
#   '1',
#   '90',
#   '94',
#   '3'],
#  ['31909404',
#   'INDENIZACOES E RESTITUICOES TRAB. INAT. MIL.',
#   '3',
#   '1',
#   '90',
#   '94',
#   '4'],
#  ['31909406',
#   'INDENIZACOES E RESTITUICOES TRAB.PENS.MILITAR',
#   '3',
#   '1',
#   '90',
#   '94',
#   '6'],
#  ['31909407', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '94', '7'],
#  ['31909413',
#   'INDENIZACOES E RESTITUICOES TRAB.PENS.CIVIL',
#   '3',
#   '1',
#   '90',
#   '94',
#   '13'],
#  ['31909414',
#   'COMPENSACAO PECUNIARIA - LEI 7.963/1989',
#   '3',
#   '1',
#   '90',
#   '94',
#   '14'],
#  ['31909415',
#   'IND.LIC.ESP(MP 2215-10/2001 E LEI 10486/2002)',
#   '3',
#   '1',
#   '90',
#   '94',
#   '15'],
#  ['31909416',
#   'INDENIZACAO EM DECORRENCIA DE ADESAO AO PDV - PROGRAMA DE DESLIGAMENTO E/OU DEMISSAO VOLUNTARIA',
#   '3',
#   '1',
#   '90',
#   '94',
#   '16'],
#  ['31909417',
#   'INDENIZACAO PELA CONCESSAO DE LICENCA SEM REMUNERACAO',
#   '3',
#   '1',
#   '90',
#   '94',
#   '17'],
#  ['31909440', '-7', '3', '1', '90', '94', '40'],
#  ['31909484',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '94',
#   '84'],
#  ['31909490',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '94',
#   '90'],
#  ['31909498', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '94', '98'],
#  ['31909499',
#   'DIVERSAS INDENIZACOES TRABALHISTAS',
#   '3',
#   '1',
#   '90',
#   '94',
#   '99'],
#  ['319094EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '94', '-2'],
#  ['319096-7', 'CODIGO INVALIDO', '3', '1', '90', '96', '-7'],
#  ['319096-8', 'SEM INFORMACAO', '3', '1', '90', '96', '-8'],
#  ['319096-9', 'NAO SE APLICA', '3', '1', '90', '96', '-9'],
#  ['31909600',
#   'RESSARCIMENTO DE DESP. DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '90',
#   '96',
#   '0'],
#  ['31909601',
#   'PESSOAL REQUISITADO DE OUTROS ORGAOS DA APF',
#   '3',
#   '1',
#   '90',
#   '96',
#   '1'],
#  ['31909602',
#   'PESSOAL REQUISITADO DE OUTROS ENTES',
#   '3',
#   '1',
#   '90',
#   '96',
#   '2'],
#  ['31909660', '-7', '3', '1', '90', '96', '60'],
#  ['31909698',
#   'INSCRICAO DE RP - RESSARCIMENTO DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '90',
#   '96',
#   '98'],
#  ['319096EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '96', '-2'],
#  ['319096ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '96', '-1'],
#  ['31909900', 'NAO SE APLICA', '3', '1', '90', '99', '0'],
#  ['319100',
#   'APLICACOES DIRETAS - OPERACOES INTERNAS',
#   '3',
#   '1',
#   '91',
#   '0',
#   '1'],
#  ['319100', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '0', '3'],
#  ['319100', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '0', '8'],
#  ['319100-7', 'CODIGO INVALIDO', '3', '1', '91', '0', '-7'],
#  ['319100-8', 'SEM INFORMACAO', '3', '1', '91', '0', '-8'],
#  ['319100-9', 'NAO SE APLICA', '3', '1', '91', '0', '-9'],
#  ['31910000',
#   'APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS',
#   '3',
#   '1',
#   '91',
#   '0',
#   '0'],
#  ['319100EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '0', '-2'],
#  ['319100ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '0', '-1'],
#  ['319104-7', 'CODIGO INVALIDO', '3', '1', '91', '4', '-7'],
#  ['319104-8', 'SEM INFORMACAO', '3', '1', '91', '4', '-8'],
#  ['319104-9', 'NAO SE APLICA', '3', '1', '91', '4', '-9'],
#  ['31910400', 'CONTRATACAO POR TEMPO DETERMINADO', '3', '1', '91', '4', '0'],
#  ['31910415', 'OBRIGACOES PATRONAIS', '3', '1', '91', '4', '15'],
#  ['31910498', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '91', '4', '98'],
#  ['31911002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '2'],
#  ['31911003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '3'],
#  ['31911004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '4'],
#  ['31911005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '5'],
#  ['31911007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '7'],
#  ['319111', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '11', '-9'],
#  ['319113-7', 'CODIGO INVALIDO', '3', '1', '91', '13', '-7'],
#  ['319113-8', 'SEM INFORMACAO', '3', '1', '91', '13', '-8'],
#  ['319113-9', 'NAO SE APLICA', '3', '1', '91', '13', '-9'],
#  ['31911300',
#   'OBRIGACOES PATRONAIS - OP.INTRA-ORCAMENTARIAS',
#   '3',
#   '1',
#   '91',
#   '13',
#   '0'],
#  ['31911301', 'FGTS', '3', '1', '91', '13', '1'],
#  ['31911302',
#   'CONTRIBUICOES PREVIDENCIARIAS - INSS',
#   '3',
#   '1',
#   '91',
#   '13',
#   '2'],
#  ['31911303', 'CONTRIBUICAO PATRONAL PARA O RPPS', '3', '1', '91', '13', '3'],
#  ['31911304', 'CONTRIBUICAO DE SALARIO-EDUCACAO', '3', '1', '91', '13', '4'],
#  ['31911305',
#   'CONTRIBUICOES SESI/SESC ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '13',
#   '5'],
#  ['31911306',
#   'CONTRIBUICAO PARA O PIS/PASEP SOBRE A FOLHA DE SALARIOS',
#   '3',
#   '1',
#   '91',
#   '13',
#   '6'],
#  ['31911307', 'CONTRIBUICOES INCRA - ATIVO CIVIL', '3', '1', '91', '13', '7'],
#  ['31911308',
#   'CONTRIBUICOES PARA O SEBRAE - ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '13',
#   '8'],
#  ['31911309', 'SEGUROS DE ACIDENTES DO TRABALHO', '3', '1', '91', '13', '9'],
#  ['31911310', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '10'],
#  ['31911314', 'MULTAS INDEDUTIVEIS', '3', '1', '91', '13', '14'],
#  ['31911315', 'MULTAS DEDUTIVEIS', '3', '1', '91', '13', '15'],
#  ['31911316',
#   'CONTRIB.0,5/100 S/REMUNARACAO MES ANT.-LC 101/01',
#   '3',
#   '1',
#   '91',
#   '13',
#   '16'],
#  ['31911317', 'JUROS', '3', '1', '91', '13', '17'],
#  ['31911318',
#   'CONTRIBUICAO PARA O PIS/PASEP S/FOLHA PAGTO',
#   '3',
#   '1',
#   '91',
#   '13',
#   '18'],
#  ['31911330', '-7', '3', '1', '91', '13', '30'],
#  ['31911340',
#   'ENCARGOS DE PESSOAL REQUISIT. DE OUTROS ENTES',
#   '3',
#   '1',
#   '91',
#   '13',
#   '40'],
#  ['31911376', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '76'],
#  ['31911398', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '91', '13', '98'],
#  ['31911399', 'OUTRAS OBRIGACOES PATRONAIS', '3', '1', '91', '13', '99'],
#  ['319113EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '-2'],
#  ['319113ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '-1'],
#  ['31912303', 'DESCONTOS DA DIVIDA MOBILIARIA', '3', '1', '91', '23', '3'],
#  ['31919000', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '90', '0'],
#  ['319191-7', 'CODIGO INVALIDO', '3', '1', '91', '91', '-7'],
#  ['319191-8', 'SEM INFORMACAO', '3', '1', '91', '91', '-8'],
#  ['319191-9', 'NAO SE APLICA', '3', '1', '91', '91', '-9'],
#  ['31919100', 'SENTENCAS JUDICIAIS', '3', '1', '91', '91', '0'],
#  ['31919101',
#   'OBRIGACOES PATRONAIS DE PRECATORIOS',
#   '3',
#   '1',
#   '91',
#   '91',
#   '1'],
#  ['31919102',
#   'OBRIGACOES PATRONAIS - SENT.JUD.PEQUENO VALOR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '2'],
#  ['31919103',
#   'OBRIG.PATR.SENT.JUD.PARC.UNICA - ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '3'],
#  ['31919104',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.INATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '4'],
#  ['31919105',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.PENSION.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '5'],
#  ['31919106',
#   'OBRIG.PATR.SENT.JUD.PARC.UNICA ATIVO MILITAR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '6'],
#  ['31919107',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.INATIVO MILITAR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '7'],
#  ['31919108',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.PENS.MILITAR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '8'],
#  ['31919109',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.ATIV.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '9'],
#  ['31919110',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.INAT.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '10'],
#  ['31919111',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.PENS.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '11'],
#  ['31919112',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.ATIV.MILIT',
#   '3',
#   '1',
#   '91',
#   '91',
#   '12'],
#  ['31919113',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.INAT.MILIT',
#   '3',
#   '1',
#   '91',
#   '91',
#   '13'],
#  ['31919114',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.PENS.MILIT',
#   '3',
#   '1',
#   '91',
#   '91',
#   '14'],
#  ['31919115',
#   'OBRIGACOES PATRONAIS SENT.JUD.-PESSOAL CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '15'],
#  ['31919116',
#   'OBRIGACOES PATRONAIS SENT.JUD.-PESSOAL MILITA',
#   '3',
#   '1',
#   '91',
#   '91',
#   '16'],
#  ['31919132',
#   'SENT.JUDIC.TRANS.JULG.CAR.UNICO-ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '32'],
#  ['31919198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '91', '91', '98'],
#  ['31919199', 'OUTRAS SENTENCAS JUDICIAIS', '3', '1', '91', '91', '99'],
#  ['319191EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '91', '-2'],
#  ['319192-7', 'CODIGO INVALIDO', '3', '1', '91', '92', '-7'],
#  ['319192-8', 'SEM INFORMACAO', '3', '1', '91', '92', '-8'],
#  ['319192-9', 'NAO SE APLICA', '3', '1', '91', '92', '-9'],
#  ['31919200', 'DESPESAS DE EXERCICIOS ANTERIORES', '3', '1', '91', '92', '0'],
#  ['31919203', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '92', '3'],
#  ['31919205',
#   'OUTROS BENEF.PREV.DO SERVIDOR OU DO MILITAR',
#   '3',
#   '1',
#   '91',
#   '92',
#   '5'],
#  ['31919206',
#   'BENEFICIO MENSAL AO DEFICIENTE E AO IDOSO',
#   '3',
#   '1',
#   '91',
#   '92',
#   '6'],
#  ['31919213', 'OBRIGACOES PATRONAIS', '3', '1', '91', '92', '13'],
#  ['31919226',
#   'RESSARCIMENTO DE DESP. DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '91',
#   '92',
#   '26'],
#  ['31919291', 'SENTENCAS JUDICIAIS', '3', '1', '91', '92', '91'],
#  ['31919296',
#   'RESSARC. DE DESPESAS DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '91',
#   '92',
#   '96'],
#  ['31919298',
#   'INSCRICAO DE RESTOS A PAGAR - IDENIZ.TRABALHI',
#   '3',
#   '1',
#   '91',
#   '92',
#   '98'],
#  ['319192EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '92', '-2'],
#  ['319192ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '92', '-1'],
#  ['319194-7', 'CODIGO INVALIDO', '3', '1', '91', '94', '-7'],
#  ['319194-8', 'SEM INFORMACAO', '3', '1', '91', '94', '-8'],
#  ['319194-9', 'NAO SE APLICA', '3', '1', '91', '94', '-9'],
#  ['31919400', 'INDENIZACOES TRABALHISTAS', '3', '1', '91', '94', '0'],
#  ['31919401',
#   'INDENIZACOES TRABALHISTAS - OBRIG PATRONAIS',
#   '3',
#   '1',
#   '91',
#   '94',
#   '1'],
#  ['319196-7', 'CODIGO INVALIDO', '3', '1', '91', '96', '-7'],
#  ['319196-8', 'SEM INFORMACAO', '3', '1', '91', '96', '-8'],
#  ['319196-9', 'NAO SE APLICA', '3', '1', '91', '96', '-9'],
#  ['31919600',
#   'RESSARCIMENTO DE DESP. DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '91',
#   '96',
#   '0'],
#  ['31919601',
#   'PESSOAL REQUISITADO DE OUTROS ORGAOS DA APF',
#   '3',
#   '1',
#   '91',
#   '96',
#   '1'],
#  ['319196EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '96', '-2'],
#  ['319500-7', 'CODIGO INVALIDO', '3', '1', '95', '0', '-7'],
#  ['319500-9', 'NAO SE APLICA', '3', '1', '95', '0', '-9'],
#  ['31950000',
#   'APLICACAO DIRETA - ACOES E SERVICOS DE SAUDE',
#   '3',
#   '1',
#   '95',
#   '0',
#   '0'],
#  ['319504-7', 'CODIGO INVALIDO', '3', '1', '95', '4', '-7'],
#  ['319504-9', 'NAO SE APLICA', '3', '1', '95', '4', '-9'],
#  ['31950400',
#   'CONTRATACAO POR TEMPO DETERMINADO LC 141/2012',
#   '3',
#   '1',
#   '95',
#   '4',
#   '0'],
#  ['319507-7', 'CODIGO INVALIDO', '3', '1', '95', '7', '-7'],
#  ['319507-9', 'NAO SE APLICA', '3', '1', '95', '7', '-9'],
#  ['31950700',
#   'CONTRIBUICAO A ENTIDADE FECHADA PREVIDENCIA',
#   '3',
#   '1',
#   '95',
#   '7',
#   '0'],
#  ['319511-7', 'CODIGO INVALIDO', '3', '1', '95', '11', '-7'],
#  ['319511-9', 'NAO SE APLICA', '3', '1', '95', '11', '-9'],
#  ...]

# %%
df = pd.DataFrame(NaturezaDespesaDetalhada)
print(df)
# Out:
#                                0                            1   2   3   4   5  \
# 0     Natureza Despesa Detalhada
# 1                             -7  CODIGO INEXISTENTE NO SIAFI  -7  -7  -7  -7
# 2                            -28  CODIGO INEXISTENTE NO SIAFI  -7  -7  -7  -7
# 3                            -28  CODIGO INEXISTENTE NO SIAFI  -7  -7  -7  -7
# 4                            -28  CODIGO INEXISTENTE NO SIAFI  -7  -7  -7  -7
# ...                          ...                          ...  ..  ..  ..  ..
# 9192                      999999               SEM INFORMACAO   9   9  99  99
# 9193                    999999-7              CODIGO INVALIDO   9   9  99  99
# 9194                    999999-9                NAO SE APLICA   9   9  99  99
# 9195                    99999900      RESERVA DE CONTINGENCIA   9   9  99  99
# 9196                    99999999      RESERVA DE CONTINGENCIA   9   9  99  99
#
#        6
# 0
# 1     -7
# 2     -9
# 3      1
# 4      2
# ...   ..
# 9192  -8
# 9193  -7
# 9194  -9
# 9195   0
# 9196  99
#
# [9197 rows x 7 columns]

# %%
dftolist = df.drop_duplicates(subset=[0])

# %%
NaturezaDespesaUnica = dftolist.values.tolist()

# %%
del NaturezaDespesaUnica[0]

# %%
NaturezaDespesaUnica
# Out:
# [['-7', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '-7'],
#  ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '-9'],
#  ['-8', 'SEM INFORMACAO', '-8', '-8', '-8', '-8', '-8'],
#  ['-9', 'NAO SE APLICA', '-9', '-9', '-9', '-9', '-9'],
#  ['0', 'VALOR DE ESCAPE - SIAFIWEB', '0', '0', '0', '0', '0'],
#  ['1', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '0', '1'],
#  ['14', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '0', '14'],
#  ['351', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '3', '51'],
#  ['495', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '4', '95'],
#  ['609', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '6', '9'],
#  ['699', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '6', '99'],
#  ['721', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '7', '21'],
#  ['748', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '7', '48'],
#  ['927', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '9', '27'],
#  ['972', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '9', '72'],
#  ['1781', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '17', '81'],
#  ['1992', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '19', '92'],
#  ['2650', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '26', '50'],
#  ['3390', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '33', '90'],
#  ['4105', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '41', '5'],
#  ['4364', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '43', '64'],
#  ['5850', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '58', '50'],
#  ['6842', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '68', '42'],
#  ['7112', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '71', '12'],
#  ['8082', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '0', '80', '82'],
#  ['10800', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '8', '0'],
#  ['12490', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '24', '90'],
#  ['13129', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '31', '29'],
#  ['13195', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '31', '95'],
#  ['16138', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '61', '38'],
#  ['16984', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '69', '84'],
#  ['17747', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '77', '47'],
#  ['19124', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '91', '24'],
#  ['19391', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '1', '93', '91'],
#  ['21587', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '15', '87'],
#  ['22861', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '28', '61'],
#  ['27000', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '70', '0'],
#  ['27562', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '75', '62'],
#  ['29428', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '2', '94', '28'],
#  ['31002', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '3', '10', '2'],
#  ['32823', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '3', '28', '23'],
#  ['40934', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '9', '34'],
#  ['41588', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '15', '88'],
#  ['45337', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '53', '37'],
#  ['49351', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '4', '93', '51'],
#  ['50096', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '5', '0', '96'],
#  ['54112', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '5', '41', '12'],
#  ['60876', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '8', '76'],
#  ['61329', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '13', '29'],
#  ['64019', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '40', '19'],
#  ['66150', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '6', '61', '50'],
#  ['74939', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '7', '49', '39'],
#  ['78453', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '7', '84', '53'],
#  ['104525', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '10', '45', '25'],
#  ['116949', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '11', '69', '49'],
#  ['123736', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '12', '37', '36'],
#  ['133755', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '13', '37', '55'],
#  ['148491', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '14', '84', '91'],
#  ['001788-7', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '17', '88', '-7'],
#  ['181577', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '15', '77'],
#  ['183120', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '31', '20'],
#  ['183960', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '39', '60'],
#  ['184097', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '40', '97'],
#  ['194460', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '44', '60'],
#  ['196665', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '66', '65'],
#  ['199271', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '92', '71'],
#  ['205059', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '20', '50', '59'],
#  ['206115', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '20', '61', '15'],
#  ['212990', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '21', '29', '90'],
#  ['219077', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '21', '90', '77'],
#  ['222973', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '22', '29', '73'],
#  ['249607', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '24', '96', '7'],
#  ['251729', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '25', '17', '29'],
#  ['253071', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '25', '30', '71'],
#  ['267318', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '26', '73', '18'],
#  ['283339', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '28', '33', '39'],
#  ['287861', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '28', '78', '61'],
#  ['411306', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '41', '13', '6'],
#  ['829884', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '82', '98', '84'],
#  ['1013916', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '1', '39', '16'],
#  ['1022279', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '2', '22', '79'],
#  ['1326636', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '32', '66', '36'],
#  ['1377556', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '37', '75', '56'],
#  ['1657605', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '65', '76', '5'],
#  ['2127105', 'CODIGO INEXISTENTE NO SIAFI', '0', '2', '12', '71', '5'],
#  ['3390309', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '9'],
#  ['3390363', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '63'],
#  ['3390390', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '90'],
#  ['3390391', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '91'],
#  ['3390398', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '98'],
#  ['3390399', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '3', '99'],
#  ['3390460', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '4', '60'],
#  ['3390923', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '9', '23'],
#  ['3391471', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '14', '71'],
#  ['3761577', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '76', '15', '77'],
#  ['6674266', 'CODIGO INEXISTENTE NO SIAFI', '0', '6', '67', '42', '66'],
#  ['79500', 'CODIGO INEXISTENTE NO SIAFI', '0', '7', '95', '0', '0'],
#  ['19008005', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '0', '80', '5'],
#  ['19011001', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '10', '1'],
#  ['19011301', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '13', '1'],
#  ['19011402', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '2'],
#  ['19011403', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '3'],
#  ['19011405', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '5'],
#  ['19011406', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '1', '14', '6'],
#  ['19092001', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '9', '20', '1'],
#  ['22339000', 'CODIGO INEXISTENTE NO SIAFI', '2', '2', '33', '90', '0'],
#  ['22410000', 'CODIGO INEXISTENTE NO SIAFI', '2', '2', '41', '0', '0'],
#  ['300000-7', 'CODIGO INVALIDO', '3', '0', '0', '0', '-7'],
#  ['300000-9', 'NAO SE APLICA', '3', '0', '0', '0', '-9'],
#  ['30000000', 'DESPESAS CORRENTES', '3', '0', '0', '0', '0'],
#  ['310000-7', 'CODIGO INVALIDO', '3', '1', '0', '0', '-7'],
#  ['310000-9', 'NAO SE APLICA', '3', '1', '0', '0', '-9'],
#  ['31000000', 'PESSOAL E ENCARGOS SOCIAIS', '3', '1', '0', '0', '0'],
#  ['31000001', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '1'],
#  ['31000002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '2'],
#  ['31000003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '3'],
#  ['31000005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '5'],
#  ['31000006', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '6'],
#  ['31000007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '7'],
#  ['31000008', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '8'],
#  ['31000009', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '9'],
#  ['31000010', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '10'],
#  ['31000012', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '12'],
#  ['31000013', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '13'],
#  ['31000021', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '21'],
#  ['31000026', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '26'],
#  ['31000027', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '27'],
#  ['31000032', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '32'],
#  ['31000033', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '33'],
#  ['31000040', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '40'],
#  ['31000042', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '42'],
#  ['31000043', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '43'],
#  ['31000044', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '44'],
#  ['31000045', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '45'],
#  ['31000046', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '46'],
#  ['31000099', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '0', '0', '99'],
#  ['313000-7', 'CODIGO INVALIDO', '3', '1', '30', '0', '-7'],
#  ['313000-8', 'SEM INFORMACAO', '3', '1', '30', '0', '-8'],
#  ['313000-9', 'NAO SE APLICA', '3', '1', '30', '0', '-9'],
#  ['31300000',
#   'TRANSF. A ESTADOS E AO DISTRITO FEDERAL',
#   '3',
#   '1',
#   '30',
#   '0',
#   '0'],
#  ['313041-7', 'CODIGO INVALIDO', '3', '1', '30', '41', '-7'],
#  ['313041-8', 'SEM INFORMACAO', '3', '1', '30', '41', '-8'],
#  ['313041-9', 'NAO SE APLICA', '3', '1', '30', '41', '-9'],
#  ['31304100', 'CONTRIBUICOES', '3', '1', '30', '41', '0'],
#  ['31304101', 'ACRE', '3', '1', '30', '41', '1'],
#  ['31304103', 'ALAGOAS', '3', '1', '30', '41', '3'],
#  ['31304104', 'AMAPA', '3', '1', '30', '41', '4'],
#  ['31304105', 'AMAZONAS', '3', '1', '30', '41', '5'],
#  ['31304107', 'BAHIA', '3', '1', '30', '41', '7'],
#  ['31304109', 'CEARA', '3', '1', '30', '41', '9'],
#  ['31304111', 'DISTRITO FEDERAL', '3', '1', '30', '41', '11'],
#  ['31304113', 'ESPIRITO SANTO', '3', '1', '30', '41', '13'],
#  ['31304115', 'GOIAS', '3', '1', '30', '41', '15'],
#  ['31304117', 'MARANHAO', '3', '1', '30', '41', '17'],
#  ['31304119', 'MATO GROSSO', '3', '1', '30', '41', '19'],
#  ['31304121', 'MATO GROSSO DO SUL', '3', '1', '30', '41', '21'],
#  ['31304123', 'MINAS GERAIS', '3', '1', '30', '41', '23'],
#  ['31304125', 'PARA', '3', '1', '30', '41', '25'],
#  ['31304127', 'PARAIBA', '3', '1', '30', '41', '27'],
#  ['31304129', 'PARANA', '3', '1', '30', '41', '29'],
#  ['31304131', 'PERNAMBUCO', '3', '1', '30', '41', '31'],
#  ['31304133', 'PIAUI', '3', '1', '30', '41', '33'],
#  ['31304135', 'RIO DE JANEIRO', '3', '1', '30', '41', '35'],
#  ['31304137', 'RIO GRANDE DO NORTE', '3', '1', '30', '41', '37'],
#  ['31304139', 'RIO GRANDE DO SUL', '3', '1', '30', '41', '39'],
#  ['31304141', 'RONDONIA', '3', '1', '30', '41', '41'],
#  ['31304142', 'RORAIMA', '3', '1', '30', '41', '42'],
#  ['31304143', 'SANTA CATARINA', '3', '1', '30', '41', '43'],
#  ['31304145', 'SAO PAULO', '3', '1', '30', '41', '45'],
#  ['31304147', 'SERGIPE', '3', '1', '30', '41', '47'],
#  ['31304148', 'TOCANTINS', '3', '1', '30', '41', '48'],
#  ['31304184',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '30',
#   '41',
#   '84'],
#  ['31304190',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '30',
#   '41',
#   '90'],
#  ['31304198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '30', '41', '98'],
#  ['31304199', 'OUTRAS CONTRIBUICOES', '3', '1', '30', '41', '99'],
#  ['31309900', 'NAO SE APLICA', '3', '1', '30', '99', '0'],
#  ['317000-7', 'CODIGO INVALIDO', '3', '1', '70', '0', '-7'],
#  ['317000-9', 'NAO SE APLICA', '3', '1', '70', '0', '-9'],
#  ['31700000',
#   'TRANSF. A INSTITUICOES MULTIGOVERNAMENTAIS',
#   '3',
#   '1',
#   '70',
#   '0',
#   '0'],
#  ['317041-7', 'CODIGO INVALIDO', '3', '1', '70', '41', '-7'],
#  ['317041-9', 'NAO SE APLICA', '3', '1', '70', '41', '-9'],
#  ['31704100', 'CONTRIBUICOES', '3', '1', '70', '41', '0'],
#  ['317100', 'SEM INFORMACAO', '3', '1', '71', '0', '-8'],
#  ['317100-7', 'CODIGO INVALIDO', '3', '1', '71', '0', '-7'],
#  ['317100-9', 'NAO SE APLICA', '3', '1', '71', '0', '-9'],
#  ['31710000',
#   'TRANSF.CONSOR.PUB.MEDIANTE CONTRATO DE RATEIO',
#   '3',
#   '1',
#   '71',
#   '0',
#   '0'],
#  ['317111', 'SEM INFORMACAO', '3', '1', '71', '11', '-8'],
#  ['317111-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '11', '-9'],
#  ['31711100', 'NAO SE APLICA', '3', '1', '71', '11', '0'],
#  ['31711101',
#   'TRANSFERENCIAS A CONSORCIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '11',
#   '1'],
#  ['31711133', 'VENCIMENTOS E SALARIOS', '3', '1', '71', '11', '33'],
#  ['317116', 'SEM INFORMACAO', '3', '1', '71', '16', '-8'],
#  ['317116-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '16', '-9'],
#  ['31711600', 'NAO SE APLICA', '3', '1', '71', '16', '0'],
#  ['31711601',
#   'TRANSFERENCIAS A CONSORCIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '16',
#   '1'],
#  ['317170', 'SEM INFORMACAO', '3', '1', '71', '70', '-8'],
#  ['31717000', 'NAO SE APLICA', '3', '1', '71', '70', '0'],
#  ['31717001',
#   'TRANSFERENCIA PARA CONSORICIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '70',
#   '1'],
#  ['317196', 'SEM INFORMACAO', '3', '1', '71', '96', '-8'],
#  ['317196-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '96', '-9'],
#  ['31719600', 'NAO SE APLICA', '3', '1', '71', '96', '0'],
#  ['31719601',
#   'TRANSFERENCIA A CONSORCIOS PUBLICOS',
#   '3',
#   '1',
#   '71',
#   '96',
#   '1'],
#  ['317300-7', 'CODIGO INVALIDO', '3', '1', '73', '0', '-7'],
#  ['317300-9', 'NAO SE APLICA', '3', '1', '73', '0', '-9'],
#  ['31730000',
#   'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12',
#   '3',
#   '1',
#   '73',
#   '0',
#   '0'],
#  ['317370-7', 'CODIGO INVALIDO', '3', '1', '73', '70', '-7'],
#  ['317370-9', 'NAO SE APLICA', '3', '1', '73', '70', '-9'],
#  ['31737000',
#   'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO',
#   '3',
#   '1',
#   '73',
#   '70',
#   '0'],
#  ['317400-7', 'CODIGO INVALIDO', '3', '1', '74', '0', '-7'],
#  ['317400-9', 'NAO SE APLICA', '3', '1', '74', '0', '-9'],
#  ['31740000',
#   'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12',
#   '3',
#   '1',
#   '74',
#   '0',
#   '0'],
#  ['317470-7', 'CODIGO INVALIDO', '3', '1', '74', '70', '-7'],
#  ['317470-9', 'NAO SE APLICA', '3', '1', '74', '70', '-9'],
#  ['31747000',
#   'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO',
#   '3',
#   '1',
#   '74',
#   '70',
#   '0'],
#  ['318000-7', 'CODIGO INVALIDO', '3', '1', '80', '0', '-7'],
#  ['318000-8', 'SEM INFORMACAO', '3', '1', '80', '0', '-8'],
#  ['318000-9', 'NAO SE APLICA', '3', '1', '80', '0', '-9'],
#  ['31800000', 'TRANSFEENCIAS AO EXTERIOR', '3', '1', '80', '0', '0'],
#  ['318004-7', 'CODIGO INVALIDO', '3', '1', '80', '4', '-7'],
#  ['318004-9', 'NAO SE APLICA', '3', '1', '80', '4', '-9'],
#  ['31800400', 'CONTRATACAO POR TEMPO DETERMINADO', '3', '1', '80', '4', '0'],
#  ['31803400', 'NAO SE APLICA', '3', '1', '80', '34', '0'],
#  ['31809900', 'NAO SE APLICA', '3', '1', '80', '99', '0'],
#  ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '1'],
#  ['319000-7', 'CODIGO INVALIDO', '3', '1', '90', '0', '-7'],
#  ['319000-8', 'SEM INFORMACAO', '3', '1', '90', '0', '-8'],
#  ['319000-9', 'NAO SE APLICA', '3', '1', '90', '0', '-9'],
#  ['31900000', 'APLICACOES DIRETAS', '3', '1', '90', '0', '0'],
#  ['31900002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '2'],
#  ['31900003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '3'],
#  ['31900004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '4'],
#  ['31900005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '5'],
#  ['31900007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '7'],
#  ['319000EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '-2'],
#  ['319000ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '0', '-1'],
#  ['319001-7', 'CODIGO INVALIDO', '3', '1', '90', '1', '-7'],
#  ['319001-8', 'SEM INFORMACAO', '3', '1', '90', '1', '-8'],
#  ['319001-9', 'NAO SE APLICA', '3', '1', '90', '1', '-9'],
#  ['31900100',
#   'APOSENT.RPPS, RESER.REMUNER. E REFOR.MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '0'],
#  ['31900101', 'PROVENTOS - PESSOAL CIVIL', '3', '1', '90', '1', '1'],
#  ['31900102', 'ABONO PROVISORIO', '3', '1', '90', '1', '2'],
#  ['31900103',
#   'APOSENT.PENDENTES APROV TCU - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '3'],
#  ['31900104',
#   'PROV ORIUNDOS ADICIONAL QUALIF - PES CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '4'],
#  ['31900105',
#   'VANTAGEM PESSOAL - LEI 8.216/91 PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '5'],
#  ['31900106', '13 SALARIO - PESSOAL CIVIL', '3', '1', '90', '1', '6'],
#  ['31900107',
#   'FERIAS VENCIDAS E PROPOR A APOSENTADOS CIVIS',
#   '3',
#   '1',
#   '90',
#   '1',
#   '7'],
#  ['31900108', 'ADIANTAMENTOS PECUNIARIOS', '3', '1', '90', '1', '8'],
#  ['31900109',
#   'ADICIONAL POR TEMPO DE SERVICO PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '9'],
#  ['31900110',
#   'ADICIONAL POR TEMPO DE SERVICO PESSOAL MILIT',
#   '3',
#   '1',
#   '90',
#   '1',
#   '10'],
#  ['31900111',
#   'ADICIONAL DE DISPONIBILIDADE MILITAR - INATIVO',
#   '3',
#   '1',
#   '90',
#   '1',
#   '11'],
#  ['31900112', '-7', '3', '1', '90', '1', '12'],
#  ['31900113', '-7', '3', '1', '90', '1', '13'],
#  ['31900114', 'ADICIONAL MILITAR', '3', '1', '90', '1', '14'],
#  ['31900115',
#   'COMPL. APOSENTADORIA -  PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '15'],
#  ['31900116',
#   'APOSENT ORIGINARIA DE SUBSIDIOS - PESSOAL CIV',
#   '3',
#   '1',
#   '90',
#   '1',
#   '16'],
#  ['31900117',
#   'VANTAGEM PECUNIARIA ESPECIAL - PESSOAL MILIT',
#   '3',
#   '1',
#   '90',
#   '1',
#   '17'],
#  ['31900118', 'LICENCA PREMIO - INATIVOS CIVIS', '3', '1', '90', '1', '18'],
#  ['31900119',
#   '13 SALARIO - PESSOAL  CIVIL - ENCARGOS  PREVIDENCIARIOSDA UNIAO - EPU.',
#   '3',
#   '1',
#   '90',
#   '1',
#   '19'],
#  ['31900120',
#   '13º SALARIO - APOSENTADORIA PENDENTE DE APROVACAO TCU',
#   '3',
#   '1',
#   '90',
#   '1',
#   '20'],
#  ['31900121', 'PROVENTOS - PESSOAL MILITAR', '3', '1', '90', '1', '21'],
#  ['31900122',
#   'VANTAGENS INCORPORADAS - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '22'],
#  ['31900123',
#   'AUXILIO-INVALIDEZ - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '23'],
#  ['31900125', 'PRO-LABORE (LEI 7711/88 ARTIGO 3)', '3', '1', '90', '1', '25'],
#  ['31900126', '13 SALARIO - PESSOAL MILITAR', '3', '1', '90', '1', '26'],
#  ['31900127',
#   'GRATIFICACOES ESPECIAIS A APOSENTADOS',
#   '3',
#   '1',
#   '90',
#   '1',
#   '27'],
#  ['31900128',
#   'VANTAGENS INCORPORADAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '28'],
#  ['31900129',
#   'PROVENTOS ORIGINARIAS DE GRAT.P/EXERC/FUNCOES',
#   '3',
#   '1',
#   '90',
#   '1',
#   '29'],
#  ['31900130',
#   'PROVENTOS ORIGINARIAS DE GRAT.P/EXERC. CARGO.',
#   '3',
#   '1',
#   '90',
#   '1',
#   '30'],
#  ['31900132',
#   'INCREMENTO PLANO DE CARGOS E SALARIOS JUDIC.',
#   '3',
#   '1',
#   '90',
#   '1',
#   '32'],
#  ['31900133',
#   'ADICIONAL TAREFA TEMPO CERTO (ART.23 MP 2131)',
#   '3',
#   '1',
#   '90',
#   '1',
#   '33'],
#  ['31900134',
#   'VANTAGENS PERMANENTES SENT.TRANSIT.JULG.CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '34'],
#  ['31900135',
#   'VANTAG.PERMANENTES SENT.TRANSIT.JULG.MILITAR',
#   '3',
#   '1',
#   '90',
#   '1',
#   '35'],
#  ['31900136',
#   'GRATIFICACAO DE ATIVIDADES EXTERNAS - GAE',
#   '3',
#   '1',
#   '90',
#   '1',
#   '36'],
#  ['31900138',
#   'BENEFICIO ESPECIAL LEI 12.618/2012 - INATIVO',
#   '3',
#   '1',
#   '90',
#   '1',
#   '38'],
#  ['31900140',
#   'GRATIFICACOES ESPECIAIS A APOSENTADOS',
#   '3',
#   '1',
#   '90',
#   '1',
#   '40'],
#  ['31900146', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '1', '46'],
#  ['31900160', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '1', '60'],
#  ['31900165',
#   'BONUS DE EFICIENCIA E PRODUTIVIDADE',
#   '3',
#   '1',
#   '90',
#   '1',
#   '65'],
#  ['31900184',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '1',
#   '84'],
#  ['31900187',
#   'COMPLEMENTACAO DE APOSENTADORIAS - PES CIVIL',
#   '3',
#   '1',
#   '90',
#   '1',
#   '87'],
#  ['31900189', 'OUTRAS REFORMAS - PESSOAL MILITAR', '3', '1', '90', '1', '89'],
#  ['31900190',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '1',
#   '90'],
#  ['31900196',
#   'APOSENTADORIAS E REFORMAS - PAGTO. ANTECIPADO',
#   '3',
#   '1',
#   '90',
#   '1',
#   '96'],
#  ['31900198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '1', '98'],
#  ['31900199', 'OUTRAS APOSENTADORIAS - CIVIS', '3', '1', '90', '1', '99'],
#  ['319001EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '1', '-2'],
#  ['319001ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '1', '-1'],
#  ['319003-7', 'CODIGO INVALIDO', '3', '1', '90', '3', '-7'],
#  ['319003-8', 'SEM INFORMACAO', '3', '1', '90', '3', '-8'],
#  ['319003-9', 'NAO SE APLICA', '3', '1', '90', '3', '-9'],
#  ['31900300', 'PENSOES DO RPPS E DO MILITAR', '3', '1', '90', '3', '0'],
#  ['31900301', 'PENSOES CIVIS', '3', '1', '90', '3', '1'],
#  ['31900302', 'PENSOES MILITARES', '3', '1', '90', '3', '2'],
#  ['31900303', '13 SALARIO - PENSOES CIVIS', '3', '1', '90', '3', '3'],
#  ['31900304', '13 SALARIO - PENSOES MILITARES', '3', '1', '90', '3', '4'],
#  ['31900305', 'PENSOES ESPECIAIS - PESSOAL CIVIL', '3', '1', '90', '3', '5'],
#  ['31900306',
#   'LICENCA-PREMIO PARA PENSIONISTA CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '6'],
#  ['31900307', 'COMPL. PENSOES - PESSOAL MILITAR', '3', '1', '90', '3', '7'],
#  ['31900308', 'PENSOES ESPECIAIS - PESSOAL MILITAR', '3', '1', '90', '3', '8'],
#  ['31900309',
#   'PENSOES ORIUNDAS DE ADIC DE QUALIFIC - CIVIS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '9'],
#  ['31900310',
#   'VANTAGENS PERM.SENT.JUD.TRANS.JULGADO - CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '10'],
#  ['31900311',
#   'VANTAG.PERM.SENT.JUD.TRANS.JULGADO - MILITAR',
#   '3',
#   '1',
#   '90',
#   '3',
#   '11'],
#  ['31900312',
#   'PENSOES A ANISTIADOS POLITICOS - CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '12'],
#  ['31900313',
#   'PENSOES A ANISTIADOS POLITICOS - MILITAR',
#   '3',
#   '1',
#   '90',
#   '3',
#   '13'],
#  ['31900314',
#   '13 SALARIO - PENSOES  CIVIL - ENCARGOS  PREVIDENCIARIOSPREVIDENCIARIOS DA UNIAO - EPU.',
#   '3',
#   '1',
#   '90',
#   '3',
#   '14'],
#  ['31900315',
#   'ADICIONAL DE DISPONIBILIDADE MILITAR - PENSIONISTA',
#   '3',
#   '1',
#   '90',
#   '3',
#   '15'],
#  ['31900316',
#   'PENSOES ORIGINARIAS DE SUBSIDIOS - CIVIS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '16'],
#  ['31900317', 'VANTAGEM PECUNIARIA ESPECIAL - VPE', '3', '1', '90', '3', '17'],
#  ['31900319',
#   'PENSOES ORIGINARIAS DE GRATIF.P/EXERC. FUNCAO',
#   '3',
#   '1',
#   '90',
#   '3',
#   '19'],
#  ['31900320',
#   'PENSOES ORIGINARIAS DE GRATIF.P/EXERC.DE CARG',
#   '3',
#   '1',
#   '90',
#   '3',
#   '20'],
#  ['31900322',
#   'RETR.ADIC.VARIAVEL E PRO-LABORE(LEI 7711/88)',
#   '3',
#   '1',
#   '90',
#   '3',
#   '22'],
#  ['31900323',
#   'RETRIBUICAO VARIAVEL SUPERINT. SEGURO PRIVADO',
#   '3',
#   '1',
#   '90',
#   '3',
#   '23'],
#  ['31900325',
#   'GRATIFICACOES ESPECIAIS_- PENSIONISTAS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '25'],
#  ['31900328',
#   'VANTAGENS INCORPORADAS - PENSIONISTAS',
#   '3',
#   '1',
#   '90',
#   '3',
#   '28'],
#  ['31900330', '-7', '3', '1', '90', '3', '30'],
#  ['31900331', '-7', '3', '1', '90', '3', '31'],
#  ['31900332', '-7', '3', '1', '90', '3', '32'],
#  ['31900334',
#   'GRATIFICACAO DE ATIVIDADE JUDICIARIA - GAJ',
#   '3',
#   '1',
#   '90',
#   '3',
#   '34'],
#  ['31900336',
#   'GRATIFICACAO DE ATIVIDADES EXTERNAS - GAE',
#   '3',
#   '1',
#   '90',
#   '3',
#   '36'],
#  ['31900338',
#   'BENEFICIO ESPECIAL LEI 12.618/2012 - PENSAO',
#   '3',
#   '1',
#   '90',
#   '3',
#   '38'],
#  ['31900340',
#   'GRATIFICACOES ESPECIAIS_A PENSIONISTA',
#   '3',
#   '1',
#   '90',
#   '3',
#   '40'],
#  ['31900342', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '3', '42'],
#  ['31900360', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '3', '60'],
#  ['31900365',
#   'BONUS DE EFICIENCIA E PRODUTIVIDADE',
#   '3',
#   '1',
#   '90',
#   '3',
#   '65'],
#  ['31900384',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '3',
#   '84'],
#  ['31900386',
#   'COMPLEMENTACAO DE PENSOES - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '3',
#   '86'],
#  ['31900387',
#   'COMPLEMENTACAO DE PENSOES - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '3',
#   '87'],
#  ['31900389', 'OUTRAS PENSOES - MILITARES', '3', '1', '90', '3', '89'],
#  ['31900390',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '3',
#   '90'],
#  ['31900396', 'PENSOES - PAGAMENTO ANTECIPADO', '3', '1', '90', '3', '96'],
#  ['31900398', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '3', '98'],
#  ['31900399', 'OUTRAS PENSOES - CIVIS', '3', '1', '90', '3', '99'],
#  ['319003EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '3', '-2'],
#  ['319003ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '3', '-1'],
#  ['319004-7', 'CODIGO INVALIDO', '3', '1', '90', '4', '-7'],
#  ['319004-8', 'SEM INFORMACAO', '3', '1', '90', '4', '-8'],
#  ['319004-9', 'NAO SE APLICA', '3', '1', '90', '4', '-9'],
#  ['31900400', 'CONTRATACAO P/TEMPO DETERMINADO', '3', '1', '90', '4', '0'],
#  ['31900401', 'SALARIO CONTRATO TEMPORARIO', '3', '1', '90', '4', '1'],
#  ['31900402', 'SALARIO-FAMILIA', '3', '1', '90', '4', '2'],
#  ['31900403',
#   'ADICIONAL NOTURNO DE CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '3'],
#  ['31900405',
#   'ADICIONAL DE PERICULOSIDADE - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '5'],
#  ['31900406',
#   'ADICIONAL DE INSALUBRIDADE - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '6'],
#  ['31900407',
#   'ADICIONAL DE ATIVIDADES PENOSAS - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '7'],
#  ['31900408',
#   'ADIC.DE IRRADIACAO IONIZANTE - CONTR.TEMPORAR',
#   '3',
#   '1',
#   '90',
#   '4',
#   '8'],
#  ['31900409',
#   'GRATIFICACAO DE RAIO-X - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '9'],
#  ['31900410',
#   'SERVICOS EXTRAORDINARIOS - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '10'],
#  ['31900411',
#   'SERV.EXTRAORD. NOTURNO - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '11'],
#  ['31900412',
#   'FERIAS VENCIDAS/PROPORCIONAIS - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '12'],
#  ['31900413', '13¤ SALARIO - CONTRATO TEMPORARIO', '3', '1', '90', '4', '13'],
#  ['31900414',
#   'FERIAS - ABONO CONSTITUCIONAL - CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '14'],
#  ['31900415',
#   'OBRIGACOES PATRONAIS - CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '15'],
#  ['31900416',
#   'FERIAS PAGAMENTO ANTECIPADO - CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '16'],
#  ['31900417',
#   'INDENIZACAO ? 2º ART.12 LEI 8.745/93',
#   '3',
#   '1',
#   '90',
#   '4',
#   '17'],
#  ['31900418',
#   'ADICIONAL REMUNERACAO DO MILITAR - ART.18 LEI 13.954/19',
#   '3',
#   '1',
#   '90',
#   '4',
#   '18'],
#  ['31900420',
#   'OUTRAS VANTAGENS CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '20'],
#  ['31900421', 'SALARIO FAMILIA LEI 8.745/93', '3', '1', '90', '4', '21'],
#  ['31900422',
#   'ADICIONAL NOTURNO CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '22'],
#  ['31900423',
#   'ADICIONAL DE PERICULOSIDADE CONT. TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '23'],
#  ['31900424',
#   'ADICIONAL DE INSALUBRIDADE CONT. TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '24'],
#  ['31900425',
#   'ADICIONAL DE ATIVIDADES PENOSAS CONT. TEMP.',
#   '3',
#   '1',
#   '90',
#   '4',
#   '25'],
#  ['31900426',
#   'ADICIONAL DE IRRADIACAO IONIZANTE CONT. TEMP.',
#   '3',
#   '1',
#   '90',
#   '4',
#   '26'],
#  ['31900427',
#   'GRATIFICACAO DE RAIO-X CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '27'],
#  ['31900428',
#   'SERVICOS EXTRAORDINARIOS CONTRATO TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '28'],
#  ['31900429',
#   'SERVICOS EXTRAORDINARIOS NOTURNO CONT. TEMP.',
#   '3',
#   '1',
#   '90',
#   '4',
#   '29'],
#  ['31900430',
#   'FERIAS VENCIDAS/PROPORCIONAIS CONT.TEMPORARIO',
#   '3',
#   '1',
#   '90',
#   '4',
#   '30'],
#  ['31900431', '13º SALARIO CONTRATO TEMPORARIO', '3', '1', '90', '4', '31'],
#  ['31900432', 'FERIAS - ABONO CONSTITUCIONAL', '3', '1', '90', '4', '32'],
#  ['31900433', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '4', '33'],
#  ['31900434',
#   'INDENIZACAO ? 2º ART.12 LEI 8.745/93',
#   '3',
#   '1',
#   '90',
#   '4',
#   '34'],
#  ['31900440', '-7', '3', '1', '90', '4', '40'],
#  ['31900441', '-7', '3', '1', '90', '4', '41'],
#  ['31900453',
#   'CONTRATACAO POR TEMPO DETERMINADO - PES.CIVIL',
#   '3',
#   '1',
#   '90',
#   '4',
#   '53'],
#  ['31900498', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '4', '98'],
#  ['31900499',
#   'OUTRAS VANTAGENS - CONTRATOS TEMPORARIOS',
#   '3',
#   '1',
#   '90',
#   '4',
#   '99'],
#  ['319004EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '4', '-2'],
#  ['319005-7', 'CODIGO INVALIDO', '3', '1', '90', '5', '-7'],
#  ['319005-8', 'SEM INFORMACAO', '3', '1', '90', '5', '-8'],
#  ['319005-9', 'NAO SE APLICA', '3', '1', '90', '5', '-9'],
#  ['31900500',
#   'OUTROS BENEF.PREV. DO SERVIDOR OU DO MILITAR',
#   '3',
#   '1',
#   '90',
#   '5',
#   '0'],
#  ['31900501', 'AUXILIO-RECLUSAO ATIVO CIVIL', '3', '1', '90', '5', '1'],
#  ['31900502', 'AUXILIO-RECLUSAO ATIVO MILITAR', '3', '1', '90', '5', '2'],
#  ['31900503', 'SALARIO-FAMILIA ATIVO CIVIL', '3', '1', '90', '5', '3'],
#  ['31900504', 'SALARIO-FAMILIA ATIVO MILITAR', '3', '1', '90', '5', '4'],
#  ['31900505', 'SALARIO-FAMILIA INATIVO CIVIL', '3', '1', '90', '5', '5'],
#  ['31900506', 'SALARIO-FAMILIA INATIVO MILITAR', '3', '1', '90', '5', '6'],
#  ['31900507', 'SALARIO-FAMILIA PENSIONISTA CIVIL', '3', '1', '90', '5', '7'],
#  ['31900508',
#   'SALARIO-FAMILIA PENSIONIOSTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '5',
#   '8'],
#  ['31900509', 'AUXILIO-DOENCA', '3', '1', '90', '5', '9'],
#  ['31900550', '-7', '3', '1', '90', '5', '50'],
#  ['31900599',
#   'OUTROS BENEF.PREV.SERVIDOR OU MILITAR',
#   '3',
#   '1',
#   '90',
#   '5',
#   '99'],
#  ['319007-7', 'CODIGO INVALIDO', '3', '1', '90', '7', '-7'],
#  ['319007-8', 'SEM INFORMACAO', '3', '1', '90', '7', '-8'],
#  ['319007-9', 'NAO SE APLICA', '3', '1', '90', '7', '-9'],
#  ['31900700',
#   'CONTRIB. A ENTIDADES FECHADAS DE PREVIDENCIA',
#   '3',
#   '1',
#   '90',
#   '7',
#   '0'],
#  ['31900701',
#   'CONTRIBUICAO PATRONAL PREVIDENCIA PRIVADA',
#   '3',
#   '1',
#   '90',
#   '7',
#   '1'],
#  ['31900702', 'SEGUROS', '3', '1', '90', '7', '2'],
#  ['31900703', 'CONT. PATRONAL PREVIDENCIA PRIVADA', '3', '1', '90', '7', '3'],
#  ['31900704',
#   'CONTRIBUICAO PATRONAL PREVIDENCIA PRIVADA-PDV',
#   '3',
#   '1',
#   '90',
#   '7',
#   '4'],
#  ['31900705',
#   'COMPLEM DE PREVID PRORROG SALAR MATERNIDADE',
#   '3',
#   '1',
#   '90',
#   '7',
#   '5'],
#  ['31900706',
#   'CONTRIBUICAO PATRONAL - FUNPRESP LEI 12618/12',
#   '3',
#   '1',
#   '90',
#   '7',
#   '6'],
#  ['31900714',
#   'MULTAS INDEDUTIVEIS - ENTIDADES FECHADAS DE PREVIDENCIA',
#   '3',
#   '1',
#   '90',
#   '7',
#   '14'],
#  ['31900770', '-7', '3', '1', '90', '7', '70'],
#  ['31900790',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '7',
#   '90'],
#  ['31900798', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '7', '98'],
#  ['31900799', 'OUTRAS CONTRIBUICOES', '3', '1', '90', '7', '99'],
#  ['319007EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '7', '-2'],
#  ['319008-7', 'CODIGO INVALIDO', '3', '1', '90', '8', '-7'],
#  ['319008-8', 'SEM INFORMACAO', '3', '1', '90', '8', '-8'],
#  ['319008-9', 'NAO SE APLICA', '3', '1', '90', '8', '-9'],
#  ['31900800',
#   'OUTROS BENEF.ASSIST. DO SERVIDOR E DO MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '0'],
#  ['31900801', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '1'],
#  ['31900802', 'AUXILIO FUNERAL ATIVO MILITAR', '3', '1', '90', '8', '2'],
#  ['31900803', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '3'],
#  ['31900804', 'AUXILIO FUNERAL INATIVO MILITAR', '3', '1', '90', '8', '4'],
#  ['31900805', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '5'],
#  ['31900806', 'AUXILIO NATALIDADE ATIVO MILITAR', '3', '1', '90', '8', '6'],
#  ['31900807', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '7'],
#  ['31900808', 'AUXILIO NATALIDADE INATIVO MILITAR', '3', '1', '90', '8', '8'],
#  ['31900809', 'AUXILIO RECLUSAO ATIVO CIVIL', '3', '1', '90', '8', '9'],
#  ['31900810', 'AUXILIO RECLUSAO ATIVO MILITAR', '3', '1', '90', '8', '10'],
#  ['31900811', 'AUXILIO RECLUSAO INATIVO CIVIL', '3', '1', '90', '8', '11'],
#  ['31900812', 'AUXILIO RECLUSAO INATIVO MILITAR', '3', '1', '90', '8', '12'],
#  ['31900813', 'AUXILIO FUNERAL PENSIONISTA CIVIL', '3', '1', '90', '8', '13'],
#  ['31900814',
#   'AUXILIO FUNERAL PENSIONISTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '14'],
#  ['31900815', 'AUXILIO RECLUSAO PENSIONISTA CIVIL', '3', '1', '90', '8', '15'],
#  ['31900816',
#   'AUXILIO RECLUSAO PENSIONISTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '16'],
#  ['31900817',
#   'AUXILIO NATALIDADE PENSIONISTA MILITAR',
#   '3',
#   '1',
#   '90',
#   '8',
#   '17'],
#  ['31900818',
#   'AUXILIO NATALIDADE PENSIONISTA CIVIL',
#   '3',
#   '1',
#   '90',
#   '8',
#   '18'],
#  ['31900819', 'AUXILIO-FAMILIAR - NO EXTERIOR', '3', '1', '90', '8', '19'],
#  ['31900851', 'AUXILIO-DOENCA MEMBROS DO MPU', '3', '1', '90', '8', '51'],
#  ['31900884',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '8',
#   '84'],
#  ['31900890',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '8',
#   '90'],
#  ['31900898', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '8', '98'],
#  ['31900899', 'OUTROS BENEFICIOS ASSISTENCIAIS', '3', '1', '90', '8', '99'],
#  ['319008EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '8', '-2'],
#  ['319008ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '8', '-1'],
#  ['319009', 'SEM INFORMACAO', '3', '1', '90', '9', '-8'],
#  ['319009-7', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-7'],
#  ['319009-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-9'],
#  ['31900900', 'NAO SE APLICA', '3', '1', '90', '9', '0'],
#  ['31900901',
#   'SALARIO FAMILIA - ATIVO PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '9',
#   '1'],
#  ['31900902',
#   'SALARIO FAMILIA-INATIVO PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '9',
#   '2'],
#  ['31900903',
#   'SALARIO FAMILIA-ATIVO PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '9',
#   '3'],
#  ['31900904',
#   'SALARIO FAMILIA - INATIVO PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '9',
#   '4'],
#  ['31900905',
#   'SALARIO FAMILIA-PENSIONISTA PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '9',
#   '5'],
#  ['31900906',
#   'SALARIO FAMILIA - PENSIONIOSTA PESS. MILITAR',
#   '3',
#   '1',
#   '90',
#   '9',
#   '6'],
#  ['31900984',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '9',
#   '84'],
#  ['31900990',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '9',
#   '90'],
#  ['31900998', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '9', '98'],
#  ['31900999', 'OUTROS SALARIOS-FAMILIA', '3', '1', '90', '9', '99'],
#  ['319009EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-2'],
#  ['319009ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '9', '-1'],
#  ['31901000', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '0'],
#  ['31901002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '2'],
#  ['31901003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '3'],
#  ['31901004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '4'],
#  ['31901005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '5'],
#  ['31901007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '7'],
#  ['319011-7', 'CODIGO INVALIDO', '3', '1', '90', '11', '-7'],
#  ['319011-8', 'SEM INFORMACAO', '3', '1', '90', '11', '-8'],
#  ['319011-9', 'NAO SE APLICA', '3', '1', '90', '11', '-9'],
#  ['31901100',
#   'VENCIMENTOS E VANTAGENS FIXAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '0'],
#  ['31901101', 'VENCIMENTOS E SALARIOS', '3', '1', '90', '11', '1'],
#  ['31901102', 'REMUNERACAO NO PERIODO DE FERIAS', '3', '1', '90', '11', '2'],
#  ['31901103', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '3'],
#  ['31901104', 'ADICIONAL NOTURNO', '3', '1', '90', '11', '4'],
#  ['31901105', 'INCORPORACOES', '3', '1', '90', '11', '5'],
#  ['31901106',
#   'VANTAGENS PERM.SENT.JUD.TRANS.JULGADO - CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '6'],
#  ['31901107', 'ABONO DE PERMANENCIA', '3', '1', '90', '11', '7'],
#  ['31901108',
#   'AUXILIO-DOENCA (LICENCA PARA TRATAMENTO DE SAUDE)',
#   '3',
#   '1',
#   '90',
#   '11',
#   '8'],
#  ['31901109', 'ADICIONAL DE PERICULOSIDADE', '3', '1', '90', '11', '9'],
#  ['31901110', 'ADICIONAL DE INSALUBRIDADE', '3', '1', '90', '11', '10'],
#  ['31901111', 'ADICIONAL DE ATIVIDADES PENOSAS', '3', '1', '90', '11', '11'],
#  ['31901112',
#   'RETRIBUICAO BASICA NO EXTERIOR - CIVIL (LEI 5.809/1972)',
#   '3',
#   '1',
#   '90',
#   '11',
#   '12'],
#  ['31901113', 'INCENTIVO A QUALIFICACAO', '3', '1', '90', '11', '13'],
#  ['31901114',
#   'ADICIONAL DE TRANSFERENCIA - ART. 469/CLT',
#   '3',
#   '1',
#   '90',
#   '11',
#   '14'],
#  ['31901115',
#   'APRENDIZES - CONTRATACAO DIRETA (LEI 10.097/2000)',
#   '3',
#   '1',
#   '90',
#   '11',
#   '15'],
#  ['31901116',
#   'GRATIFICACAO NO EXTERIOR POR TEMPO DE SERVICO - CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '16'],
#  ['31901117', '-7', '3', '1', '90', '11', '17'],
#  ['31901118', '-7', '3', '1', '90', '11', '18'],
#  ['31901119', '-7', '3', '1', '90', '11', '19'],
#  ['31901122', 'PRO-LABORE (LEI 10549/2002)', '3', '1', '90', '11', '22'],
#  ['31901123',
#   'RETRIBUICAO VARIAVEL SUPERINT. SEGURO PRIVADO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '23'],
#  ['31901128', 'VANTAGEM PECUNIARIA INDIVIDUAL', '3', '1', '90', '11', '28'],
#  ['31901130', 'ABONO PROVISORIO - PESSOAL CIVIL', '3', '1', '90', '11', '30'],
#  ['31901131',
#   'GRATIFICACAO POR EXERCICIO DE CARGO EFETIVO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '31'],
#  ['31901132',
#   'INCREMENTO PLANO DE CARGOS E SALARIOS JUDIC.',
#   '3',
#   '1',
#   '90',
#   '11',
#   '32'],
#  ['31901133',
#   'GRAT POR EXERCICIO DE FUNCOES COMISSIONADAS',
#   '3',
#   '1',
#   '90',
#   '11',
#   '33'],
#  ['31901134',
#   'GRATIFICACAO DE ATIVIDADES JUDICIARIA - GAJ',
#   '3',
#   '1',
#   '90',
#   '11',
#   '34'],
#  ['31901135',
#   'GRATIFICACAO/ADICIONAL DE LOCALIZACAO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '35'],
#  ['31901136',
#   'GRATIFICACAO P/EXERCICIO DE CARGO EM COMISSAO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '36'],
#  ['31901137', 'GRATIFICACAO DE TEMPO DE SERVICO', '3', '1', '90', '11', '37'],
#  ['31901138',
#   'GRATIFICACAO DE ATIVIDADE DE SEGURANCA - GAS',
#   '3',
#   '1',
#   '90',
#   '11',
#   '38'],
#  ['31901139',
#   'BONUS ESPECIAL DE DESEMP. INSTIT. - BESP/DNIT',
#   '3',
#   '1',
#   '90',
#   '11',
#   '39'],
#  ['31901140', 'GRATIFICACOES ESPECIAIS', '3', '1', '90', '11', '40'],
#  ['31901141',
#   'GRATIFICACAO POR ATIVIDADES EXPOSTAS',
#   '3',
#   '1',
#   '90',
#   '11',
#   '41'],
#  ['31901142', 'FERIAS VENCIDAS E PROPORCIONAIS', '3', '1', '90', '11', '42'],
#  ['31901143', '13º SALARIO', '3', '1', '90', '11', '43'],
#  ['31901144', 'FERIAS - ABONO PECUNIARIO', '3', '1', '90', '11', '44'],
#  ['31901145', 'FERIAS - 1/3 CONSTITUCIONAL', '3', '1', '90', '11', '45'],
#  ['31901146', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '11', '46'],
#  ['31901147', 'LICENCA-PREMIO', '3', '1', '90', '11', '47'],
#  ['31901149', 'LICENCA CAPACITACAO', '3', '1', '90', '11', '49'],
#  ['31901150',
#   'VENCIM. E SAL.- PROR. SALARIO MATERNIDADE',
#   '3',
#   '1',
#   '90',
#   '11',
#   '50'],
#  ['31901160', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '11', '60'],
#  ['31901165',
#   'BONUS DE EFICIENCIA E PRODUTIVIDADE',
#   '3',
#   '1',
#   '90',
#   '11',
#   '65'],
#  ['31901171', 'REMUNERACAO DE DIRETORES', '3', '1', '90', '11', '71'],
#  ['31901173',
#   'REMUN. PARTICIP. ORGAOS DELIBERACAO  COLETIVA',
#   '3',
#   '1',
#   '90',
#   '11',
#   '73'],
#  ['31901174', 'SUBSIDIOS', '3', '1', '90', '11', '74'],
#  ['31901175', 'REPRESENTACAO MENSAL', '3', '1', '90', '11', '75'],
#  ['31901177',
#   'REMUNERACAO DE PESSOAL EM DISPONIBILIDADE',
#   '3',
#   '1',
#   '90',
#   '11',
#   '77'],
#  ['31901184',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '11',
#   '84'],
#  ['31901187',
#   'COMPLEMENTACAO SALARIAL - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '87'],
#  ['31901190',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '11',
#   '90'],
#  ['31901196',
#   'VENCIMENTOS E VANTAGENS - PAGTO. ANTECIPADO',
#   '3',
#   '1',
#   '90',
#   '11',
#   '96'],
#  ['31901198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '11', '98'],
#  ['31901199',
#   'OUTRAS DESPESAS FIXAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '11',
#   '99'],
#  ['319011EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '-2'],
#  ['319011ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '-1'],
#  ['319012-7', 'CODIGO INVALIDO', '3', '1', '90', '12', '-7'],
#  ['319012-8', 'SEM INFORMACAO', '3', '1', '90', '12', '-8'],
#  ['319012-9', 'NAO SE APLICA', '3', '1', '90', '12', '-9'],
#  ['31901200',
#   'VENCIMENTOS E VANTAGENS FIXAS - PES. MILITAR',
#   '3',
#   '1',
#   '90',
#   '12',
#   '0'],
#  ['31901201', 'SOLDO', '3', '1', '90', '12', '1'],
#  ['31901202', 'ADICIONAL DE PERMANENCIA', '3', '1', '90', '12', '2'],
#  ['31901203', 'ADICIONAL DE TEMPO DE SERVICO', '3', '1', '90', '12', '3'],
#  ['31901204', 'ADICIONAL MILITAR', '3', '1', '90', '12', '4'],
#  ['31901205', 'ADICIONAL DE COMPENSACAO ORGANICA', '3', '1', '90', '12', '5'],
#  ['31901206', 'ADICIONAL DE HABILITACAO', '3', '1', '90', '12', '6'],
#  ['31901207',
#   'GRATIFICACAO DE LOCALIDADE ESPECIAL',
#   '3',
#   '1',
#   '90',
#   '12',
#   '7'],
#  ['31901208', 'GRATIFICACAO DE REPRESENTACAO', '3', '1', '90', '12', '8'],
#  ['31901209',
#   'GRATIFICACAO DE FUNCAO DE NATUREZA ESPECIAL',
#   '3',
#   '1',
#   '90',
#   '12',
#   '9'],
#  ['31901210',
#   'GRATIFICACAO DE SERVICO VOLUNTARIO.',
#   '3',
#   '1',
#   '90',
#   '12',
#   '10'],
#  ['31901211',
#   'VANTAGEM PECUNIARIA ESPECIAL - VPE.',
#   '3',
#   '1',
#   '90',
#   '12',
#   '11'],
#  ['31901212',
#   'RETRIBUICAO BASICA NO EXTERIOR - MILITAR (LEI 5.809/72)',
#   '3',
#   '1',
#   '90',
#   '12',
#   '12'],
#  ['31901213',
#   'VANTAG.PERM.SENT.JUD.TRANS.JULGADO - MILITAR',
#   '3',
#   '1',
#   '90',
#   '12',
#   '13'],
#  ['31901214',
#   'ADICIONAL DE DISPONIBILIDADE MILITAR - ATIVO',
#   '3',
#   '1',
#   '90',
#   '12',
#   '14'],
#  ['31901216',
#   'GRATIFICACAO NO EXTERIOR POR TEMPO DE SERVICO - MILITARCONFORME ARTIGO 8º, INCISO II, DA LEI 5.809/1972.',
#   '3',
#   '1',
#   '90',
#   '12',
#   '16'],
#  ['31901220', '-7', '3', '1', '90', '12', '20'],
#  ['31901223', '-7', '3', '1', '90', '12', '23'],
#  ['31901224', '-7', '3', '1', '90', '12', '24'],
#  ['31901228', '-7', '3', '1', '90', '12', '28'],
#  ['31901231',
#   'GRATIFICACAO DE EXERCICIOS DE CARGOS.',
#   '3',
#   '1',
#   '90',
#   '12',
#   '31'],
#  ['31901242', 'FERIAS VENCIDAS E PROPORCIONAIS', '3', '1', '90', '12', '42'],
#  ['31901243', 'ADICIONAL NATALINO', '3', '1', '90', '12', '43'],
#  ['31901244', 'FERIAS - ABONO PECUNIARIO', '3', '1', '90', '12', '44'],
#  ['31901245', 'FERIAS - ABONO CONSTITUCIONAL', '3', '1', '90', '12', '45'],
#  ['31901246', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '12', '46'],
#  ['31901275', 'INDENIZACAO DE REPRESENTACAO.', '3', '1', '90', '12', '75'],
#  ['31901284',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '12',
#   '84'],
#  ['31901287',
#   'COMPLEMENTACAO SALARIAL - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '12',
#   '87'],
#  ['31901290',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '12',
#   '90'],
#  ['31901298', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '12', '98'],
#  ['31901299',
#   'OUTRAS DESPESAS FIXAS - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '12',
#   '99'],
#  ['319012EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '12', '-2'],
#  ['319013-7', 'CODIGO INVALIDO', '3', '1', '90', '13', '-7'],
#  ['319013-8', 'SEM INFORMACAO', '3', '1', '90', '13', '-8'],
#  ['319013-9', 'NAO SE APLICA', '3', '1', '90', '13', '-9'],
#  ['31901300', 'OBRIGACOES PATRONAIS', '3', '1', '90', '13', '0'],
#  ['31901301', 'FGTS', '3', '1', '90', '13', '1'],
#  ['31901302',
#   'CONTRIBUICOES PREVIDENCIARIAS - INSS',
#   '3',
#   '1',
#   '90',
#   '13',
#   '2'],
#  ['31901303',
#   'CONTRIBUICOES PREVIDENCIARIAS - NO EXTERIOR',
#   '3',
#   '1',
#   '90',
#   '13',
#   '3'],
#  ['31901304', 'CONTRIBUICAO DE SALARIO-EDUCACAO', '3', '1', '90', '13', '4'],
#  ['31901305',
#   'ENCARGOS PATRONAIS - PESSOAL REQUISITADO DE OUTRO ENTE.',
#   '3',
#   '1',
#   '90',
#   '13',
#   '5'],
#  ['31901306',
#   'CONTRIBUICAO PARA O PIS/PASEP SOBRE A FOLHA DE SALARIOS',
#   '3',
#   '1',
#   '90',
#   '13',
#   '6'],
#  ['31901307',
#   'FGTS-PRORROGACAO DO SALARIO MATERNIDADE',
#   '3',
#   '1',
#   '90',
#   '13',
#   '7'],
#  ['31901308',
#   'PLANO DE SEG. SOC. DO SERVIDOR - PES. ATIVO',
#   '3',
#   '1',
#   '90',
#   '13',
#   '8'],
#  ['31901309', 'SEGUROS DE ACIDENTES DO TRABALHO', '3', '1', '90', '13', '9'],
#  ['31901310',
#   'CONTRIB DE SALAR-EDUC PRORRO SALAR MATERN.',
#   '3',
#   '1',
#   '90',
#   '13',
#   '10'],
#  ['31901311', 'FGTS - PDV', '3', '1', '90', '13', '11'],
#  ['31901313', 'SESI/SESC ATIVO CIVIL', '3', '1', '90', '13', '13'],
#  ['31901314', 'MULTAS INDEDUTIVEIS', '3', '1', '90', '13', '14'],
#  ['31901315', 'MULTAS DEDUTIVEIS', '3', '1', '90', '13', '15'],
#  ['31901316',
#   'CONTRIB.0,5/100 S/REMUNARACAO MES ANT.-LC 101/01',
#   '3',
#   '1',
#   '90',
#   '13',
#   '16'],
#  ['31901317', 'JUROS', '3', '1', '90', '13', '17'],
#  ['31901318',
#   'CONTRIBUICAO PARA O PIS/PASEP S/FOLHA PAGTO',
#   '3',
#   '1',
#   '90',
#   '13',
#   '18'],
#  ['31901319', 'SENAI/SENAC ATIVO CIVIL', '3', '1', '90', '13', '19'],
#  ['31901320', 'SEBRAE ATIVO CIVIL', '3', '1', '90', '13', '20'],
#  ['31901336', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '13', '36'],
#  ['31901340',
#   'ENCARGOS DE PESSOAL REQUISIT. DE OUTROS ENTES',
#   '3',
#   '1',
#   '90',
#   '13',
#   '40'],
#  ['31901384',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '13',
#   '84'],
#  ['31901390',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '13',
#   '90'],
#  ['31901398', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '13', '98'],
#  ['31901399', 'OUTRAS OBRIGACOES PATRONAIS', '3', '1', '90', '13', '99'],
#  ['319013EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '13', '-2'],
#  ['319013ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '13', '-1'],
#  ['319016-7', 'CODIGO INVALIDO', '3', '1', '90', '16', '-7'],
#  ['319016-8', 'SEM INFORMACAO', '3', '1', '90', '16', '-8'],
#  ['319016-9', 'NAO SE APLICA', '3', '1', '90', '16', '-9'],
#  ['31901600',
#   'OUTRAS DESPESAS VARIAVEIS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '16',
#   '0'],
#  ['31901601',
#   'BONUS DE DESEMPENHO INSTITUCIONAL POR ANALISE DE BENEFICIOS - INSS',
#   '3',
#   '1',
#   '90',
#   '16',
#   '1'],
#  ['31901602', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '16', '2'],
#  ['31901604',
#   'CONVOCACAO EXTRAORDINARIA LEGISLATIVA',
#   '3',
#   '1',
#   '90',
#   '16',
#   '4'],
#  ['31901608', 'GRATIFICACAO ELEITORAL', '3', '1', '90', '16', '8'],
#  ['31901610',
#   'LICENCA SEM REMUNERACAO INCENTIVADA',
#   '3',
#   '1',
#   '90',
#   '16',
#   '10'],
#  ['31901632', 'SUBSTITUICOES', '3', '1', '90', '16', '32'],
#  ['31901633',
#   'GRATIFICACAO POR EXRCICIO CUMULATIVO DE OFICIOS OU  JU-RISDICAO',
#   '3',
#   '1',
#   '90',
#   '16',
#   '33'],
#  ['31901634', 'AVISO PREVIO.', '3', '1', '90', '16', '34'],
#  ['31901635', 'ADICIONAL VARIAVEL', '3', '1', '90', '16', '35'],
#  ['31901636', 'ADICIONAL POR PLANTAO HOSPITALAR', '3', '1', '90', '16', '36'],
#  ['31901639',
#   'GRATIFICACAO P / ENCARGO DE CURSO OU CONCURSO',
#   '3',
#   '1',
#   '90',
#   '16',
#   '39'],
#  ['31901644', 'SERVICOS EXTRAORDINARIOS', '3', '1', '90', '16', '44'],
#  ['31901645',
#   'PARTICIPACAO A EMPREGADOS E ADMINISTRADORES',
#   '3',
#   '1',
#   '90',
#   '16',
#   '45'],
#  ['31901663', '-7', '3', '1', '90', '16', '63'],
#  ['31901664', '-7', '3', '1', '90', '16', '64'],
#  ['31901676', 'AUXILIO MORADIA', '3', '1', '90', '16', '76'],
#  ['31901684',
#   'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM',
#   '3',
#   '1',
#   '90',
#   '16',
#   '84'],
#  ['31901690',
#   'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI',
#   '3',
#   '1',
#   '90',
#   '16',
#   '90'],
#  ['31901696',
#   'OUTRAS DESP.VARIAV.PESS. CIV.-PAGMTO ANTECIP.',
#   '3',
#   '1',
#   '90',
#   '16',
#   '96'],
#  ['31901698', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '16', '98'],
#  ['31901699',
#   'OUTRAS DESPESAS VARIAVEIS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '90',
#   '16',
#   '99'],
#  ['319016EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '16', '-2'],
#  ['319016ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '16', '-1'],
#  ['319017-7', 'CODIGO INVALIDO', '3', '1', '90', '17', '-7'],
#  ['319017-8', 'SEM INFORMACAO', '3', '1', '90', '17', '-8'],
#  ['319017-9', 'NAO SE APLICA', '3', '1', '90', '17', '-9'],
#  ['31901700',
#   'OUTRAS DESPESAS VARIAVEIS - PESSOAL MILITAR',
#   '3',
#   '1',
#   '90',
#   '17',
#   '0'],
#  ['31901701',
#   'MOVIMENTACAO DE MILITARES (EXERCICIO 2013)',
#   '3',
#   '1',
#   '90',
#   '17',
#   '1'],
# ...
#  ['319096-7', 'CODIGO INVALIDO', '3', '1', '90', '96', '-7'],
#  ['319096-8', 'SEM INFORMACAO', '3', '1', '90', '96', '-8'],
#  ['319096-9', 'NAO SE APLICA', '3', '1', '90', '96', '-9'],
#  ['31909600',
#   'RESSARCIMENTO DE DESP. DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '90',
#   '96',
#   '0'],
#  ['31909601',
#   'PESSOAL REQUISITADO DE OUTROS ORGAOS DA APF',
#   '3',
#   '1',
#   '90',
#   '96',
#   '1'],
#  ['31909602',
#   'PESSOAL REQUISITADO DE OUTROS ENTES',
#   '3',
#   '1',
#   '90',
#   '96',
#   '2'],
#  ['31909660', '-7', '3', '1', '90', '96', '60'],
#  ['31909698',
#   'INSCRICAO DE RP - RESSARCIMENTO DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '90',
#   '96',
#   '98'],
#  ['319096EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '96', '-2'],
#  ['319096ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '96', '-1'],
#  ['31909900', 'NAO SE APLICA', '3', '1', '90', '99', '0'],
#  ['319100',
#   'APLICACOES DIRETAS - OPERACOES INTERNAS',
#   '3',
#   '1',
#   '91',
#   '0',
#   '1'],
#  ['319100-7', 'CODIGO INVALIDO', '3', '1', '91', '0', '-7'],
#  ['319100-8', 'SEM INFORMACAO', '3', '1', '91', '0', '-8'],
#  ['319100-9', 'NAO SE APLICA', '3', '1', '91', '0', '-9'],
#  ['31910000',
#   'APLICACOES DIRETAS - OPER.INTRA-ORCAMENTARIAS',
#   '3',
#   '1',
#   '91',
#   '0',
#   '0'],
#  ['319100EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '0', '-2'],
#  ['319100ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '0', '-1'],
#  ['319104-7', 'CODIGO INVALIDO', '3', '1', '91', '4', '-7'],
#  ['319104-8', 'SEM INFORMACAO', '3', '1', '91', '4', '-8'],
#  ['319104-9', 'NAO SE APLICA', '3', '1', '91', '4', '-9'],
#  ['31910400', 'CONTRATACAO POR TEMPO DETERMINADO', '3', '1', '91', '4', '0'],
#  ['31910415', 'OBRIGACOES PATRONAIS', '3', '1', '91', '4', '15'],
#  ['31910498', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '91', '4', '98'],
#  ['31911002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '2'],
#  ['31911003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '3'],
#  ['31911004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '4'],
#  ['31911005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '5'],
#  ['31911007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '10', '7'],
#  ['319111', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '11', '-9'],
#  ['319113-7', 'CODIGO INVALIDO', '3', '1', '91', '13', '-7'],
#  ['319113-8', 'SEM INFORMACAO', '3', '1', '91', '13', '-8'],
#  ['319113-9', 'NAO SE APLICA', '3', '1', '91', '13', '-9'],
#  ['31911300',
#   'OBRIGACOES PATRONAIS - OP.INTRA-ORCAMENTARIAS',
#   '3',
#   '1',
#   '91',
#   '13',
#   '0'],
#  ['31911301', 'FGTS', '3', '1', '91', '13', '1'],
#  ['31911302',
#   'CONTRIBUICOES PREVIDENCIARIAS - INSS',
#   '3',
#   '1',
#   '91',
#   '13',
#   '2'],
#  ['31911303', 'CONTRIBUICAO PATRONAL PARA O RPPS', '3', '1', '91', '13', '3'],
#  ['31911304', 'CONTRIBUICAO DE SALARIO-EDUCACAO', '3', '1', '91', '13', '4'],
#  ['31911305',
#   'CONTRIBUICOES SESI/SESC ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '13',
#   '5'],
#  ['31911306',
#   'CONTRIBUICAO PARA O PIS/PASEP SOBRE A FOLHA DE SALARIOS',
#   '3',
#   '1',
#   '91',
#   '13',
#   '6'],
#  ['31911307', 'CONTRIBUICOES INCRA - ATIVO CIVIL', '3', '1', '91', '13', '7'],
#  ['31911308',
#   'CONTRIBUICOES PARA O SEBRAE - ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '13',
#   '8'],
#  ['31911309', 'SEGUROS DE ACIDENTES DO TRABALHO', '3', '1', '91', '13', '9'],
#  ['31911310', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '10'],
#  ['31911314', 'MULTAS INDEDUTIVEIS', '3', '1', '91', '13', '14'],
#  ['31911315', 'MULTAS DEDUTIVEIS', '3', '1', '91', '13', '15'],
#  ['31911316',
#   'CONTRIB.0,5/100 S/REMUNARACAO MES ANT.-LC 101/01',
#   '3',
#   '1',
#   '91',
#   '13',
#   '16'],
#  ['31911317', 'JUROS', '3', '1', '91', '13', '17'],
#  ['31911318',
#   'CONTRIBUICAO PARA O PIS/PASEP S/FOLHA PAGTO',
#   '3',
#   '1',
#   '91',
#   '13',
#   '18'],
#  ['31911330', '-7', '3', '1', '91', '13', '30'],
#  ['31911340',
#   'ENCARGOS DE PESSOAL REQUISIT. DE OUTROS ENTES',
#   '3',
#   '1',
#   '91',
#   '13',
#   '40'],
#  ['31911376', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '76'],
#  ['31911398', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '91', '13', '98'],
#  ['31911399', 'OUTRAS OBRIGACOES PATRONAIS', '3', '1', '91', '13', '99'],
#  ['319113EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '-2'],
#  ['319113ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '13', '-1'],
#  ['31912303', 'DESCONTOS DA DIVIDA MOBILIARIA', '3', '1', '91', '23', '3'],
#  ['31919000', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '90', '0'],
#  ['319191-7', 'CODIGO INVALIDO', '3', '1', '91', '91', '-7'],
#  ['319191-8', 'SEM INFORMACAO', '3', '1', '91', '91', '-8'],
#  ['319191-9', 'NAO SE APLICA', '3', '1', '91', '91', '-9'],
#  ['31919100', 'SENTENCAS JUDICIAIS', '3', '1', '91', '91', '0'],
#  ['31919101',
#   'OBRIGACOES PATRONAIS DE PRECATORIOS',
#   '3',
#   '1',
#   '91',
#   '91',
#   '1'],
#  ['31919102',
#   'OBRIGACOES PATRONAIS - SENT.JUD.PEQUENO VALOR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '2'],
#  ['31919103',
#   'OBRIG.PATR.SENT.JUD.PARC.UNICA - ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '3'],
#  ['31919104',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.INATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '4'],
#  ['31919105',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.PENSION.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '5'],
#  ['31919106',
#   'OBRIG.PATR.SENT.JUD.PARC.UNICA ATIVO MILITAR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '6'],
#  ['31919107',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.INATIVO MILITAR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '7'],
#  ['31919108',
#   'OBRIG.PATR.SENT.JUD.PARC.UNIC.PENS.MILITAR',
#   '3',
#   '1',
#   '91',
#   '91',
#   '8'],
#  ['31919109',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.ATIV.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '9'],
#  ['31919110',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.INAT.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '10'],
#  ['31919111',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.PENS.CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '11'],
#  ['31919112',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.ATIV.MILIT',
#   '3',
#   '1',
#   '91',
#   '91',
#   '12'],
#  ['31919113',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.INAT.MILIT',
#   '3',
#   '1',
#   '91',
#   '91',
#   '13'],
#  ['31919114',
#   'OBRIG.PATR.SENT.JUD.NAO.TRANS.JULG.PENS.MILIT',
#   '3',
#   '1',
#   '91',
#   '91',
#   '14'],
#  ['31919115',
#   'OBRIGACOES PATRONAIS SENT.JUD.-PESSOAL CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '15'],
#  ['31919116',
#   'OBRIGACOES PATRONAIS SENT.JUD.-PESSOAL MILITA',
#   '3',
#   '1',
#   '91',
#   '91',
#   '16'],
#  ['31919132',
#   'SENT.JUDIC.TRANS.JULG.CAR.UNICO-ATIVO CIVIL',
#   '3',
#   '1',
#   '91',
#   '91',
#   '32'],
#  ['31919198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '91', '91', '98'],
#  ['31919199', 'OUTRAS SENTENCAS JUDICIAIS', '3', '1', '91', '91', '99'],
#  ['319191EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '91', '-2'],
#  ['319192-7', 'CODIGO INVALIDO', '3', '1', '91', '92', '-7'],
#  ['319192-8', 'SEM INFORMACAO', '3', '1', '91', '92', '-8'],
#  ['319192-9', 'NAO SE APLICA', '3', '1', '91', '92', '-9'],
#  ['31919200', 'DESPESAS DE EXERCICIOS ANTERIORES', '3', '1', '91', '92', '0'],
#  ['31919203', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '92', '3'],
#  ['31919205',
#   'OUTROS BENEF.PREV.DO SERVIDOR OU DO MILITAR',
#   '3',
#   '1',
#   '91',
#   '92',
#   '5'],
#  ['31919206',
#   'BENEFICIO MENSAL AO DEFICIENTE E AO IDOSO',
#   '3',
#   '1',
#   '91',
#   '92',
#   '6'],
#  ['31919213', 'OBRIGACOES PATRONAIS', '3', '1', '91', '92', '13'],
#  ['31919226',
#   'RESSARCIMENTO DE DESP. DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '91',
#   '92',
#   '26'],
#  ['31919291', 'SENTENCAS JUDICIAIS', '3', '1', '91', '92', '91'],
#  ['31919296',
#   'RESSARC. DE DESPESAS DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '91',
#   '92',
#   '96'],
#  ['31919298',
#   'INSCRICAO DE RESTOS A PAGAR - IDENIZ.TRABALHI',
#   '3',
#   '1',
#   '91',
#   '92',
#   '98'],
#  ['319192EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '92', '-2'],
#  ['319192ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '92', '-1'],
#  ['319194-7', 'CODIGO INVALIDO', '3', '1', '91', '94', '-7'],
#  ['319194-8', 'SEM INFORMACAO', '3', '1', '91', '94', '-8'],
#  ['319194-9', 'NAO SE APLICA', '3', '1', '91', '94', '-9'],
#  ['31919400', 'INDENIZACOES TRABALHISTAS', '3', '1', '91', '94', '0'],
#  ['31919401',
#   'INDENIZACOES TRABALHISTAS - OBRIG PATRONAIS',
#   '3',
#   '1',
#   '91',
#   '94',
#   '1'],
#  ['319196-7', 'CODIGO INVALIDO', '3', '1', '91', '96', '-7'],
#  ['319196-8', 'SEM INFORMACAO', '3', '1', '91', '96', '-8'],
#  ['319196-9', 'NAO SE APLICA', '3', '1', '91', '96', '-9'],
#  ['31919600',
#   'RESSARCIMENTO DE DESP. DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '91',
#   '96',
#   '0'],
#  ['31919601',
#   'PESSOAL REQUISITADO DE OUTROS ORGAOS DA APF',
#   '3',
#   '1',
#   '91',
#   '96',
#   '1'],
#  ['319196EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '91', '96', '-2'],
#  ['319500-7', 'CODIGO INVALIDO', '3', '1', '95', '0', '-7'],
#  ['319500-9', 'NAO SE APLICA', '3', '1', '95', '0', '-9'],
#  ['31950000',
#   'APLICACAO DIRETA - ACOES E SERVICOS DE SAUDE',
#   '3',
#   '1',
#   '95',
#   '0',
#   '0'],
#  ['319504-7', 'CODIGO INVALIDO', '3', '1', '95', '4', '-7'],
#  ['319504-9', 'NAO SE APLICA', '3', '1', '95', '4', '-9'],
#  ['31950400',
#   'CONTRATACAO POR TEMPO DETERMINADO LC 141/2012',
#   '3',
#   '1',
#   '95',
#   '4',
#   '0'],
#  ['319507-7', 'CODIGO INVALIDO', '3', '1', '95', '7', '-7'],
#  ['319507-9', 'NAO SE APLICA', '3', '1', '95', '7', '-9'],
#  ['31950700',
#   'CONTRIBUICAO A ENTIDADE FECHADA PREVIDENCIA',
#   '3',
#   '1',
#   '95',
#   '7',
#   '0'],
#  ['319511-7', 'CODIGO INVALIDO', '3', '1', '95', '11', '-7'],
#  ['319511-9', 'NAO SE APLICA', '3', '1', '95', '11', '-9'],
#  ['31951100',
#   'VENCIMENTOS E VANTAGENS FIXAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '95',
#   '11',
#   '0'],
#  ['319513-7', 'CODIGO INVALIDO', '3', '1', '95', '13', '-7'],
#  ['319513-9', 'NAO SE APLICA', '3', '1', '95', '13', '-9'],
#  ['31951300', 'OBRIGACOES PATRONAIS', '3', '1', '95', '13', '0'],
#  ['319516-7', 'CODIGO INVALIDO', '3', '1', '95', '16', '-7'],
#  ['319516-9', 'NAO SE APLICA', '3', '1', '95', '16', '-9'],
#  ['31951600',
#   'OUTRAS DESPESAS VARIAVEIS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '95',
#   '16',
#   '0'],
#  ['319567-7', 'CODIGO INVALIDO', '3', '1', '95', '67', '-7'],
#  ['319567-9', 'NAO SE APLICA', '3', '1', '95', '67', '-9'],
#  ['31956700', 'DEPOSITOS COMPULSORIOS', '3', '1', '95', '67', '0'],
#  ['319591-7', 'CODIGO INVALIDO', '3', '1', '95', '91', '-7'],
#  ['319591-9', 'NAO SE APLICA', '3', '1', '95', '91', '-9'],
#  ['31959100', 'SENTENCAS JUDICIAIS', '3', '1', '95', '91', '0'],
#  ['319592', 'SEM INFORMACAO', '3', '1', '95', '92', '-8'],
#  ['319592-7', 'CODIGO INVALIDO', '3', '1', '95', '92', '-7'],
#  ['319592-9', 'NAO SE APLICA', '3', '1', '95', '92', '-9'],
#  ['31959200', 'DESPESAS DE EXERCICIOS ANTERIORES', '3', '1', '95', '92', '0'],
#  ['319594-7', 'CODIGO INVALIDO', '3', '1', '95', '94', '-7'],
#  ['319594-9', 'NAO SE APLICA', '3', '1', '95', '94', '-9'],
#  ['31959400',
#   'INDENIZACOES E RESTITUICOES TRABALHISTAS',
#   '3',
#   '1',
#   '95',
#   '94',
#   '0'],
#  ['319596-7', 'CODIGO INVALIDO', '3', '1', '95', '96', '-7'],
#  ['319596-9', 'NAO SE APLICA', '3', '1', '95', '96', '-9'],
#  ['31959600',
#   'RESSARCIMENTO DESPESAS DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '95',
#   '96',
#   '0'],
#  ['319600-7', 'CODIGO INVALIDO', '3', '1', '96', '0', '-7'],
#  ['319600-8', 'SEM INFORMACAO', '3', '1', '96', '0', '-8'],
#  ['319600-9', 'NAO SE APLICA', '3', '1', '96', '0', '-9'],
#  ['31960000',
#   'APLICACAO DIRETA - ACOES E SERVICOS DE SAUDE',
#   '3',
#   '1',
#   '96',
#   '0',
#   '0'],
#  ['319604-7', 'CODIGO INVALIDO', '3', '1', '96', '4', '-7'],
#  ['319604-9', 'NAO SE APLICA', '3', '1', '96', '4', '-9'],
#  ['31960400',
#   'CONTRATACAO POR TEMPO DETERMINADO LC 141/2012',
#   '3',
#   '1',
#   '96',
#   '4',
#   '0'],
#  ['319607-7', 'CODIGO INVALIDO', '3', '1', '96', '7', '-7'],
#  ['319607-9', 'NAO SE APLICA', '3', '1', '96', '7', '-9'],
#  ['31960700',
#   'CONTRIBUICAO A ENTIDADE FECHADA PREVIDENCIA',
#   '3',
#   '1',
#   '96',
#   '7',
#   '0'],
#  ['319611-7', 'CODIGO INVALIDO', '3', '1', '96', '11', '-7'],
#  ['319611-9', 'NAO SE APLICA', '3', '1', '96', '11', '-9'],
#  ['31961100',
#   'VENCIMENTOS E VANTAGENS FIXAS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '96',
#   '11',
#   '0'],
#  ['319613-7', 'CODIGO INVALIDO', '3', '1', '96', '13', '-7'],
#  ['319613-9', 'NAO SE APLICA', '3', '1', '96', '13', '-9'],
#  ['31961300', 'OBRIGACOES PATRONAIS', '3', '1', '96', '13', '0'],
#  ['319616-7', 'CODIGO INVALIDO', '3', '1', '96', '16', '-7'],
#  ['319616-9', 'NAO SE APLICA', '3', '1', '96', '16', '-9'],
#  ['31961600',
#   'OUTRAS DESPESAS VARIAVEIS - PESSOAL CIVIL',
#   '3',
#   '1',
#   '96',
#   '16',
#   '0'],
#  ['319667-7', 'CODIGO INVALIDO', '3', '1', '96', '67', '-7'],
#  ['319667-9', 'NAO SE APLICA', '3', '1', '96', '67', '-9'],
#  ['31966700', 'DEPOSITOS COMPULSORIOS', '3', '1', '96', '67', '0'],
#  ['319691-7', 'CODIGO INVALIDO', '3', '1', '96', '91', '-7'],
#  ['319691-9', 'NAO SE APLICA', '3', '1', '96', '91', '-9'],
#  ['31969100', 'SENTENCAS JUDICIAIS', '3', '1', '96', '91', '0'],
#  ['319692-7', 'CODIGO INVALIDO', '3', '1', '96', '92', '-7'],
#  ['319692-8', 'SEM INFORMACAO', '3', '1', '96', '92', '-8'],
#  ['319692-9', 'NAO SE APLICA', '3', '1', '96', '92', '-9'],
#  ['31969200', 'DESPESAS DE EXERCICIOS ANTERIORES', '3', '1', '96', '92', '0'],
#  ['319694-7', 'CODIGO INVALIDO', '3', '1', '96', '94', '-7'],
#  ['319694-9', 'NAO SE APLICA', '3', '1', '96', '94', '-9'],
#  ['31969400',
#   'INDENIZACOES E RESTITUICOES TRABALHISTAS',
#   '3',
#   '1',
#   '96',
#   '94',
#   '0'],
#  ['319696', 'SEM INFORMACAO', '3', '1', '96', '96', '-8'],
#  ['319696-7', 'CODIGO INVALIDO', '3', '1', '96', '96', '-7'],
#  ['319696-9', 'NAO SE APLICA', '3', '1', '96', '96', '-9'],
#  ['31969600',
#   'RESSARCIMENTO DESPESAS DE PESSOAL REQUISITADO',
#   '3',
#   '1',
#   '96',
#   '96',
#   '0'],
#  ['320000-7', 'CODIGO INVALIDO', '3', '2', '0', '0', '-7'],
#  ['320000-9', 'NAO SE APLICA', '3', '2', '0', '0', '-9'],
#  ['32000000', 'JUROS E ENCARGOS DA DIVIDA', '3', '2', '0', '0', '0'],
#  ['323000', 'SEM INFORMACAO', '3', '2', '30', '0', '-8'],
#  ['32300000', 'NAO SE APLICA', '3', '2', '30', '0', '0'],
#  ['327000-7', 'CODIGO INVALIDO', '3', '2', '70', '0', '-7'],
#  ['327000-9', 'NAO SE APLICA', '3', '2', '70', '0', '-9'],
#  ['32700000',
#   'TRANSF. A INSTITUICOES MULTIGOVERNAMENTAIS',
#   '3',
#   '2',
#   '70',
#   '0',
#   '0'],
#  ['327100-7', 'CODIGO INVALIDO', '3', '2', '71', '0', '-7'],
#  ['327100-9', 'NAO SE APLICA', '3', '2', '71', '0', '-9'],
#  ['32710000',
#   'TRANSF.CONSORC.PUB.MEDIANTE CONTRATO RATEIO',
#   '3',
#   '2',
#   '71',
#   '0',
#   '0'],
#  ['32717000', 'NAO SE APLICA', '3', '2', '71', '70', '0'],
#  ['327300-7', 'CODIGO INVALIDO', '3', '2', '73', '0', '-7'],
#  ['327300-9', 'NAO SE APLICA', '3', '2', '73', '0', '-9'],
#  ['32730000',
#   'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12',
#   '3',
#   '2',
#   '73',
#   '0',
#   '0'],
#  ['327370-7', 'CODIGO INVALIDO', '3', '2', '73', '70', '-7'],
#  ['327370-9', 'NAO SE APLICA', '3', '2', '73', '70', '-9'],
#  ['32737000',
#   'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO',
#   '3',
#   '2',
#   '73',
#   '70',
#   '0'],
#  ['327400-7', 'CODIGO INVALIDO', '3', '2', '74', '0', '-7'],
#  ['327400-9', 'NAO SE APLICA', '3', '2', '74', '0', '-9'],
#  ['32740000',
#   'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12',
#   '3',
#   '2',
#   '74',
#   '0',
#   '0'],
#  ['327470-7', 'CODIGO INVALIDO', '3', '2', '74', '70', '-7'],
#  ['327470-9', 'NAO SE APLICA', '3', '2', '74', '70', '-9'],
#  ['32747000',
#   'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO',
#   '3',
#   '2',
#   '74',
#   '70',
#   '0'],
#  ['329000-7', 'CODIGO INVALIDO', '3', '2', '90', '0', '-7'],
#  ['329000-8', 'SEM INFORMACAO', '3', '2', '90', '0', '-8'],
#  ['329000-9', 'NAO SE APLICA', '3', '2', '90', '0', '-9'],
#  ['32900000', 'APLICACOES DIRETAS', '3', '2', '90', '0', '0'],
#  ['329000EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '2', '90', '0', '-2'],
#  ['32902003', 'CODIGO INEXISTENTE NO SIAFI', '3', '2', '90', '20', '3'],
#  ['329021-7', 'CODIGO INVALIDO', '3', '2', '90', '21', '-7'],
#  ['329021-8', 'SEM INFORMACAO', '3', '2', '90', '21', '-8'],
#  ['329021-9', 'NAO SE APLICA', '3', '2', '90', '21', '-9'],
#  ['32902100', 'JUROS SOBRE A DIVIDA POR CONTRATO', '3', '2', '90', '21', '0'],
#  ['32902101', 'JUROS DA DIVIDA CONTRATUAL', '3', '2', '90', '21', '1'],
#  ['32902102',
#   'VARIACAO CAMBIAL JUROS DA DIVIDA CONTRATUAL',
#   '3',
#   '2',
#   '90',
#   '21',
#   '2'],
#  ...]

# %%
NaturezaDespesaDetalhadaLimpa = []
for listaLista in NaturezaDespesaUnica:
    if len(listaLista[4]) == 1:
        aux = listaLista[4]
        listaLista[4] = '0' + aux
    if len(listaLista[5]) == 1:
        aux = listaLista[5]
        listaLista[5] = '0' + aux
    if len(listaLista[6]) == 1:
        aux = listaLista[6]
        listaLista[6] = '0' + aux
    NaturezaDespesaDetalhadaLimpa.append(listaLista) 
            #codigo = linha[0].strip("ï»¿'")
            #descricao = linha[1].strip("'")
            #categoriaEconomica = linha[2].strip("'")
            #grupoDespesa = linha[3].strip("'")
            #modalidadeAplicacao = linha[4].strip("'")
            #elementoDespesa = linha[5].strip("'")
            #listaLimpa.append(codigo)
            #listaLimpa.append(descricao)
            #listaLimpa.append(categoriaEconomica)
            #listaLimpa.append(grupoDespesa)
            #listaLimpa.append(modalidadeAplicacao)
            #listaLimpa.append(elementoDespesa)
    
contador = 0
for chave in NaturezaDespesaDetalhadaLimpa:
    print(contador,chave)
    contador += 1
# Out:
# 0 ['-7', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '-7']
# 1 ['-28', 'CODIGO INEXISTENTE NO SIAFI', '-7', '-7', '-7', '-7', '-9']
# 2 ['-8', 'SEM INFORMACAO', '-8', '-8', '-8', '-8', '-8']
# 3 ['-9', 'NAO SE APLICA', '-9', '-9', '-9', '-9', '-9']
# 4 ['0', 'VALOR DE ESCAPE - SIAFIWEB', '0', '0', '00', '00', '00']
# 5 ['1', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '00', '01']
# 6 ['14', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '00', '14']
# 7 ['351', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '03', '51']
# 8 ['495', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '04', '95']
# 9 ['609', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '06', '09']
# 10 ['699', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '06', '99']
# 11 ['721', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '07', '21']
# 12 ['748', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '07', '48']
# 13 ['927', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '09', '27']
# 14 ['972', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '09', '72']
# 15 ['1781', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '17', '81']
# 16 ['1992', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '19', '92']
# 17 ['2650', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '26', '50']
# 18 ['3390', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '33', '90']
# 19 ['4105', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '41', '05']
# 20 ['4364', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '43', '64']
# 21 ['5850', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '58', '50']
# 22 ['6842', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '68', '42']
# 23 ['7112', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '71', '12']
# 24 ['8082', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '00', '80', '82']
# 25 ['10800', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '08', '00']
# 26 ['12490', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '24', '90']
# 27 ['13129', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '31', '29']
# 28 ['13195', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '31', '95']
# 29 ['16138', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '61', '38']
# 30 ['16984', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '69', '84']
# 31 ['17747', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '77', '47']
# 32 ['19124', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '91', '24']
# 33 ['19391', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '01', '93', '91']
# 34 ['21587', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '02', '15', '87']
# 35 ['22861', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '02', '28', '61']
# 36 ['27000', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '02', '70', '00']
# 37 ['27562', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '02', '75', '62']
# 38 ['29428', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '02', '94', '28']
# 39 ['31002', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '03', '10', '02']
# 40 ['32823', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '03', '28', '23']
# 41 ['40934', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '04', '09', '34']
# 42 ['41588', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '04', '15', '88']
# 43 ['45337', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '04', '53', '37']
# 44 ['49351', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '04', '93', '51']
# 45 ['50096', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '05', '00', '96']
# 46 ['54112', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '05', '41', '12']
# 47 ['60876', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '06', '08', '76']
# 48 ['61329', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '06', '13', '29']
# 49 ['64019', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '06', '40', '19']
# 50 ['66150', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '06', '61', '50']
# 51 ['74939', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '07', '49', '39']
# 52 ['78453', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '07', '84', '53']
# 53 ['104525', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '10', '45', '25']
# 54 ['116949', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '11', '69', '49']
# 55 ['123736', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '12', '37', '36']
# 56 ['133755', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '13', '37', '55']
# 57 ['148491', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '14', '84', '91']
# 58 ['001788-7', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '17', '88', '-7']
# 59 ['181577', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '15', '77']
# 60 ['183120', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '31', '20']
# 61 ['183960', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '39', '60']
# 62 ['184097', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '18', '40', '97']
# 63 ['194460', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '44', '60']
# 64 ['196665', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '66', '65']
# 65 ['199271', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '19', '92', '71']
# 66 ['205059', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '20', '50', '59']
# 67 ['206115', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '20', '61', '15']
# 68 ['212990', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '21', '29', '90']
# 69 ['219077', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '21', '90', '77']
# 70 ['222973', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '22', '29', '73']
# 71 ['249607', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '24', '96', '07']
# 72 ['251729', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '25', '17', '29']
# 73 ['253071', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '25', '30', '71']
# 74 ['267318', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '26', '73', '18']
# 75 ['283339', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '28', '33', '39']
# 76 ['287861', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '28', '78', '61']
# 77 ['411306', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '41', '13', '06']
# 78 ['829884', 'CODIGO INEXISTENTE NO SIAFI', '0', '0', '82', '98', '84']
# 79 ['1013916', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '01', '39', '16']
# 80 ['1022279', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '02', '22', '79']
# 81 ['1326636', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '32', '66', '36']
# 82 ['1377556', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '37', '75', '56']
# 83 ['1657605', 'CODIGO INEXISTENTE NO SIAFI', '0', '1', '65', '76', '05']
# 84 ['2127105', 'CODIGO INEXISTENTE NO SIAFI', '0', '2', '12', '71', '05']
# 85 ['3390309', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '03', '09']
# 86 ['3390363', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '03', '63']
# 87 ['3390390', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '03', '90']
# 88 ['3390391', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '03', '91']
# 89 ['3390398', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '03', '98']
# 90 ['3390399', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '03', '99']
# 91 ['3390460', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '04', '60']
# 92 ['3390923', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '09', '23']
# 93 ['3391471', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '39', '14', '71']
# 94 ['3761577', 'CODIGO INEXISTENTE NO SIAFI', '0', '3', '76', '15', '77']
# 95 ['6674266', 'CODIGO INEXISTENTE NO SIAFI', '0', '6', '67', '42', '66']
# 96 ['79500', 'CODIGO INEXISTENTE NO SIAFI', '0', '7', '95', '00', '00']
# 97 ['19008005', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '00', '80', '05']
# 98 ['19011001', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '01', '10', '01']
# 99 ['19011301', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '01', '13', '01']
# 100 ['19011402', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '01', '14', '02']
# 101 ['19011403', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '01', '14', '03']
# 102 ['19011405', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '01', '14', '05']
# 103 ['19011406', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '01', '14', '06']
# 104 ['19092001', 'CODIGO INEXISTENTE NO SIAFI', '1', '9', '09', '20', '01']
# 105 ['22339000', 'CODIGO INEXISTENTE NO SIAFI', '2', '2', '33', '90', '00']
# 106 ['22410000', 'CODIGO INEXISTENTE NO SIAFI', '2', '2', '41', '00', '00']
# 107 ['300000-7', 'CODIGO INVALIDO', '3', '0', '00', '00', '-7']
# 108 ['300000-9', 'NAO SE APLICA', '3', '0', '00', '00', '-9']
# 109 ['30000000', 'DESPESAS CORRENTES', '3', '0', '00', '00', '00']
# 110 ['310000-7', 'CODIGO INVALIDO', '3', '1', '00', '00', '-7']
# 111 ['310000-9', 'NAO SE APLICA', '3', '1', '00', '00', '-9']
# 112 ['31000000', 'PESSOAL E ENCARGOS SOCIAIS', '3', '1', '00', '00', '00']
# 113 ['31000001', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '01']
# 114 ['31000002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '02']
# 115 ['31000003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '03']
# 116 ['31000005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '05']
# 117 ['31000006', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '06']
# 118 ['31000007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '07']
# 119 ['31000008', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '08']
# 120 ['31000009', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '09']
# 121 ['31000010', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '10']
# 122 ['31000012', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '12']
# 123 ['31000013', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '13']
# 124 ['31000021', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '21']
# 125 ['31000026', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '26']
# 126 ['31000027', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '27']
# 127 ['31000032', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '32']
# 128 ['31000033', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '33']
# 129 ['31000040', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '40']
# 130 ['31000042', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '42']
# 131 ['31000043', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '43']
# 132 ['31000044', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '44']
# 133 ['31000045', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '45']
# 134 ['31000046', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '46']
# 135 ['31000099', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '00', '00', '99']
# 136 ['313000-7', 'CODIGO INVALIDO', '3', '1', '30', '00', '-7']
# 137 ['313000-8', 'SEM INFORMACAO', '3', '1', '30', '00', '-8']
# 138 ['313000-9', 'NAO SE APLICA', '3', '1', '30', '00', '-9']
# 139 ['31300000', 'TRANSF. A ESTADOS E AO DISTRITO FEDERAL', '3', '1', '30', '00', '00']
# 140 ['313041-7', 'CODIGO INVALIDO', '3', '1', '30', '41', '-7']
# 141 ['313041-8', 'SEM INFORMACAO', '3', '1', '30', '41', '-8']
# 142 ['313041-9', 'NAO SE APLICA', '3', '1', '30', '41', '-9']
# 143 ['31304100', 'CONTRIBUICOES', '3', '1', '30', '41', '00']
# 144 ['31304101', 'ACRE', '3', '1', '30', '41', '01']
# 145 ['31304103', 'ALAGOAS', '3', '1', '30', '41', '03']
# 146 ['31304104', 'AMAPA', '3', '1', '30', '41', '04']
# 147 ['31304105', 'AMAZONAS', '3', '1', '30', '41', '05']
# 148 ['31304107', 'BAHIA', '3', '1', '30', '41', '07']
# 149 ['31304109', 'CEARA', '3', '1', '30', '41', '09']
# 150 ['31304111', 'DISTRITO FEDERAL', '3', '1', '30', '41', '11']
# 151 ['31304113', 'ESPIRITO SANTO', '3', '1', '30', '41', '13']
# 152 ['31304115', 'GOIAS', '3', '1', '30', '41', '15']
# 153 ['31304117', 'MARANHAO', '3', '1', '30', '41', '17']
# 154 ['31304119', 'MATO GROSSO', '3', '1', '30', '41', '19']
# 155 ['31304121', 'MATO GROSSO DO SUL', '3', '1', '30', '41', '21']
# 156 ['31304123', 'MINAS GERAIS', '3', '1', '30', '41', '23']
# 157 ['31304125', 'PARA', '3', '1', '30', '41', '25']
# 158 ['31304127', 'PARAIBA', '3', '1', '30', '41', '27']
# 159 ['31304129', 'PARANA', '3', '1', '30', '41', '29']
# 160 ['31304131', 'PERNAMBUCO', '3', '1', '30', '41', '31']
# 161 ['31304133', 'PIAUI', '3', '1', '30', '41', '33']
# 162 ['31304135', 'RIO DE JANEIRO', '3', '1', '30', '41', '35']
# 163 ['31304137', 'RIO GRANDE DO NORTE', '3', '1', '30', '41', '37']
# 164 ['31304139', 'RIO GRANDE DO SUL', '3', '1', '30', '41', '39']
# 165 ['31304141', 'RONDONIA', '3', '1', '30', '41', '41']
# 166 ['31304142', 'RORAIMA', '3', '1', '30', '41', '42']
# 167 ['31304143', 'SANTA CATARINA', '3', '1', '30', '41', '43']
# 168 ['31304145', 'SAO PAULO', '3', '1', '30', '41', '45']
# 169 ['31304147', 'SERGIPE', '3', '1', '30', '41', '47']
# 170 ['31304148', 'TOCANTINS', '3', '1', '30', '41', '48']
# 171 ['31304184', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '30', '41', '84']
# 172 ['31304190', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '30', '41', '90']
# 173 ['31304198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '30', '41', '98']
# 174 ['31304199', 'OUTRAS CONTRIBUICOES', '3', '1', '30', '41', '99']
# 175 ['31309900', 'NAO SE APLICA', '3', '1', '30', '99', '00']
# 176 ['317000-7', 'CODIGO INVALIDO', '3', '1', '70', '00', '-7']
# 177 ['317000-9', 'NAO SE APLICA', '3', '1', '70', '00', '-9']
# 178 ['31700000', 'TRANSF. A INSTITUICOES MULTIGOVERNAMENTAIS', '3', '1', '70', '00', '00']
# 179 ['317041-7', 'CODIGO INVALIDO', '3', '1', '70', '41', '-7']
# 180 ['317041-9', 'NAO SE APLICA', '3', '1', '70', '41', '-9']
# 181 ['31704100', 'CONTRIBUICOES', '3', '1', '70', '41', '00']
# 182 ['317100', 'SEM INFORMACAO', '3', '1', '71', '00', '-8']
# 183 ['317100-7', 'CODIGO INVALIDO', '3', '1', '71', '00', '-7']
# 184 ['317100-9', 'NAO SE APLICA', '3', '1', '71', '00', '-9']
# 185 ['31710000', 'TRANSF.CONSOR.PUB.MEDIANTE CONTRATO DE RATEIO', '3', '1', '71', '00', '00']
# 186 ['317111', 'SEM INFORMACAO', '3', '1', '71', '11', '-8']
# 187 ['317111-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '11', '-9']
# 188 ['31711100', 'NAO SE APLICA', '3', '1', '71', '11', '00']
# 189 ['31711101', 'TRANSFERENCIAS A CONSORCIOS PUBLICOS', '3', '1', '71', '11', '01']
# 190 ['31711133', 'VENCIMENTOS E SALARIOS', '3', '1', '71', '11', '33']
# 191 ['317116', 'SEM INFORMACAO', '3', '1', '71', '16', '-8']
# 192 ['317116-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '16', '-9']
# 193 ['31711600', 'NAO SE APLICA', '3', '1', '71', '16', '00']
# 194 ['31711601', 'TRANSFERENCIAS A CONSORCIOS PUBLICOS', '3', '1', '71', '16', '01']
# 195 ['317170', 'SEM INFORMACAO', '3', '1', '71', '70', '-8']
# 196 ['31717000', 'NAO SE APLICA', '3', '1', '71', '70', '00']
# 197 ['31717001', 'TRANSFERENCIA PARA CONSORICIOS PUBLICOS', '3', '1', '71', '70', '01']
# 198 ['317196', 'SEM INFORMACAO', '3', '1', '71', '96', '-8']
# 199 ['317196-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '71', '96', '-9']
# 200 ['31719600', 'NAO SE APLICA', '3', '1', '71', '96', '00']
# 201 ['31719601', 'TRANSFERENCIA A CONSORCIOS PUBLICOS', '3', '1', '71', '96', '01']
# 202 ['317300-7', 'CODIGO INVALIDO', '3', '1', '73', '00', '-7']
# 203 ['317300-9', 'NAO SE APLICA', '3', '1', '73', '00', '-9']
# 204 ['31730000', 'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12', '3', '1', '73', '00', '00']
# 205 ['317370-7', 'CODIGO INVALIDO', '3', '1', '73', '70', '-7']
# 206 ['317370-9', 'NAO SE APLICA', '3', '1', '73', '70', '-9']
# 207 ['31737000', 'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO', '3', '1', '73', '70', '00']
# 208 ['317400-7', 'CODIGO INVALIDO', '3', '1', '74', '00', '-7']
# 209 ['317400-9', 'NAO SE APLICA', '3', '1', '74', '00', '-9']
# 210 ['31740000', 'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12', '3', '1', '74', '00', '00']
# 211 ['317470-7', 'CODIGO INVALIDO', '3', '1', '74', '70', '-7']
# 212 ['317470-9', 'NAO SE APLICA', '3', '1', '74', '70', '-9']
# 213 ['31747000', 'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO', '3', '1', '74', '70', '00']
# 214 ['318000-7', 'CODIGO INVALIDO', '3', '1', '80', '00', '-7']
# 215 ['318000-8', 'SEM INFORMACAO', '3', '1', '80', '00', '-8']
# 216 ['318000-9', 'NAO SE APLICA', '3', '1', '80', '00', '-9']
# 217 ['31800000', 'TRANSFEENCIAS AO EXTERIOR', '3', '1', '80', '00', '00']
# 218 ['318004-7', 'CODIGO INVALIDO', '3', '1', '80', '04', '-7']
# 219 ['318004-9', 'NAO SE APLICA', '3', '1', '80', '04', '-9']
# 220 ['31800400', 'CONTRATACAO POR TEMPO DETERMINADO', '3', '1', '80', '04', '00']
# 221 ['31803400', 'NAO SE APLICA', '3', '1', '80', '34', '00']
# 222 ['31809900', 'NAO SE APLICA', '3', '1', '80', '99', '00']
# 223 ['319000', 'APLICACOES DIRETAS', '3', '1', '90', '00', '01']
# 224 ['319000-7', 'CODIGO INVALIDO', '3', '1', '90', '00', '-7']
# 225 ['319000-8', 'SEM INFORMACAO', '3', '1', '90', '00', '-8']
# 226 ['319000-9', 'NAO SE APLICA', '3', '1', '90', '00', '-9']
# 227 ['31900000', 'APLICACOES DIRETAS', '3', '1', '90', '00', '00']
# 228 ['31900002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '00', '02']
# 229 ['31900003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '00', '03']
# 230 ['31900004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '00', '04']
# 231 ['31900005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '00', '05']
# 232 ['31900007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '00', '07']
# 233 ['319000EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '00', '-2']
# 234 ['319000ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '00', '-1']
# 235 ['319001-7', 'CODIGO INVALIDO', '3', '1', '90', '01', '-7']
# 236 ['319001-8', 'SEM INFORMACAO', '3', '1', '90', '01', '-8']
# 237 ['319001-9', 'NAO SE APLICA', '3', '1', '90', '01', '-9']
# 238 ['31900100', 'APOSENT.RPPS, RESER.REMUNER. E REFOR.MILITAR', '3', '1', '90', '01', '00']
# 239 ['31900101', 'PROVENTOS - PESSOAL CIVIL', '3', '1', '90', '01', '01']
# 240 ['31900102', 'ABONO PROVISORIO', '3', '1', '90', '01', '02']
# 241 ['31900103', 'APOSENT.PENDENTES APROV TCU - PESSOAL CIVIL', '3', '1', '90', '01', '03']
# 242 ['31900104', 'PROV ORIUNDOS ADICIONAL QUALIF - PES CIVIL', '3', '1', '90', '01', '04']
# 243 ['31900105', 'VANTAGEM PESSOAL - LEI 8.216/91 PESSOAL CIVIL', '3', '1', '90', '01', '05']
# 244 ['31900106', '13 SALARIO - PESSOAL CIVIL', '3', '1', '90', '01', '06']
# 245 ['31900107', 'FERIAS VENCIDAS E PROPOR A APOSENTADOS CIVIS', '3', '1', '90', '01', '07']
# 246 ['31900108', 'ADIANTAMENTOS PECUNIARIOS', '3', '1', '90', '01', '08']
# 247 ['31900109', 'ADICIONAL POR TEMPO DE SERVICO PESSOAL CIVIL', '3', '1', '90', '01', '09']
# 248 ['31900110', 'ADICIONAL POR TEMPO DE SERVICO PESSOAL MILIT', '3', '1', '90', '01', '10']
# 249 ['31900111', 'ADICIONAL DE DISPONIBILIDADE MILITAR - INATIVO', '3', '1', '90', '01', '11']
# 250 ['31900112', '-7', '3', '1', '90', '01', '12']
# 251 ['31900113', '-7', '3', '1', '90', '01', '13']
# 252 ['31900114', 'ADICIONAL MILITAR', '3', '1', '90', '01', '14']
# 253 ['31900115', 'COMPL. APOSENTADORIA -  PESSOAL MILITAR', '3', '1', '90', '01', '15']
# 254 ['31900116', 'APOSENT ORIGINARIA DE SUBSIDIOS - PESSOAL CIV', '3', '1', '90', '01', '16']
# 255 ['31900117', 'VANTAGEM PECUNIARIA ESPECIAL - PESSOAL MILIT', '3', '1', '90', '01', '17']
# 256 ['31900118', 'LICENCA PREMIO - INATIVOS CIVIS', '3', '1', '90', '01', '18']
# 257 ['31900119', '13 SALARIO - PESSOAL  CIVIL - ENCARGOS  PREVIDENCIARIOSDA UNIAO - EPU.', '3', '1', '90', '01', '19']
# 258 ['31900120', '13º SALARIO - APOSENTADORIA PENDENTE DE APROVACAO TCU', '3', '1', '90', '01', '20']
# 259 ['31900121', 'PROVENTOS - PESSOAL MILITAR', '3', '1', '90', '01', '21']
# 260 ['31900122', 'VANTAGENS INCORPORADAS - PESSOAL MILITAR', '3', '1', '90', '01', '22']
# 261 ['31900123', 'AUXILIO-INVALIDEZ - PESSOAL MILITAR', '3', '1', '90', '01', '23']
# 262 ['31900125', 'PRO-LABORE (LEI 7711/88 ARTIGO 3)', '3', '1', '90', '01', '25']
# 263 ['31900126', '13 SALARIO - PESSOAL MILITAR', '3', '1', '90', '01', '26']
# 264 ['31900127', 'GRATIFICACOES ESPECIAIS A APOSENTADOS', '3', '1', '90', '01', '27']
# 265 ['31900128', 'VANTAGENS INCORPORADAS - PESSOAL CIVIL', '3', '1', '90', '01', '28']
# 266 ['31900129', 'PROVENTOS ORIGINARIAS DE GRAT.P/EXERC/FUNCOES', '3', '1', '90', '01', '29']
# 267 ['31900130', 'PROVENTOS ORIGINARIAS DE GRAT.P/EXERC. CARGO.', '3', '1', '90', '01', '30']
# 268 ['31900132', 'INCREMENTO PLANO DE CARGOS E SALARIOS JUDIC.', '3', '1', '90', '01', '32']
# 269 ['31900133', 'ADICIONAL TAREFA TEMPO CERTO (ART.23 MP 2131)', '3', '1', '90', '01', '33']
# 270 ['31900134', 'VANTAGENS PERMANENTES SENT.TRANSIT.JULG.CIVIL', '3', '1', '90', '01', '34']
# 271 ['31900135', 'VANTAG.PERMANENTES SENT.TRANSIT.JULG.MILITAR', '3', '1', '90', '01', '35']
# 272 ['31900136', 'GRATIFICACAO DE ATIVIDADES EXTERNAS - GAE', '3', '1', '90', '01', '36']
# 273 ['31900138', 'BENEFICIO ESPECIAL LEI 12.618/2012 - INATIVO', '3', '1', '90', '01', '38']
# 274 ['31900140', 'GRATIFICACOES ESPECIAIS A APOSENTADOS', '3', '1', '90', '01', '40']
# 275 ['31900146', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '01', '46']
# 276 ['31900160', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '01', '60']
# 277 ['31900165', 'BONUS DE EFICIENCIA E PRODUTIVIDADE', '3', '1', '90', '01', '65']
# 278 ['31900184', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '01', '84']
# 279 ['31900187', 'COMPLEMENTACAO DE APOSENTADORIAS - PES CIVIL', '3', '1', '90', '01', '87']
# 280 ['31900189', 'OUTRAS REFORMAS - PESSOAL MILITAR', '3', '1', '90', '01', '89']
# 281 ['31900190', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '01', '90']
# 282 ['31900196', 'APOSENTADORIAS E REFORMAS - PAGTO. ANTECIPADO', '3', '1', '90', '01', '96']
# 283 ['31900198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '01', '98']
# 284 ['31900199', 'OUTRAS APOSENTADORIAS - CIVIS', '3', '1', '90', '01', '99']
# 285 ['319001EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '01', '-2']
# 286 ['319001ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '01', '-1']
# 287 ['319003-7', 'CODIGO INVALIDO', '3', '1', '90', '03', '-7']
# 288 ['319003-8', 'SEM INFORMACAO', '3', '1', '90', '03', '-8']
# 289 ['319003-9', 'NAO SE APLICA', '3', '1', '90', '03', '-9']
# 290 ['31900300', 'PENSOES DO RPPS E DO MILITAR', '3', '1', '90', '03', '00']
# 291 ['31900301', 'PENSOES CIVIS', '3', '1', '90', '03', '01']
# 292 ['31900302', 'PENSOES MILITARES', '3', '1', '90', '03', '02']
# 293 ['31900303', '13 SALARIO - PENSOES CIVIS', '3', '1', '90', '03', '03']
# 294 ['31900304', '13 SALARIO - PENSOES MILITARES', '3', '1', '90', '03', '04']
# 295 ['31900305', 'PENSOES ESPECIAIS - PESSOAL CIVIL', '3', '1', '90', '03', '05']
# 296 ['31900306', 'LICENCA-PREMIO PARA PENSIONISTA CIVIL', '3', '1', '90', '03', '06']
# 297 ['31900307', 'COMPL. PENSOES - PESSOAL MILITAR', '3', '1', '90', '03', '07']
# 298 ['31900308', 'PENSOES ESPECIAIS - PESSOAL MILITAR', '3', '1', '90', '03', '08']
# 299 ['31900309', 'PENSOES ORIUNDAS DE ADIC DE QUALIFIC - CIVIS', '3', '1', '90', '03', '09']
# 300 ['31900310', 'VANTAGENS PERM.SENT.JUD.TRANS.JULGADO - CIVIL', '3', '1', '90', '03', '10']
# 301 ['31900311', 'VANTAG.PERM.SENT.JUD.TRANS.JULGADO - MILITAR', '3', '1', '90', '03', '11']
# 302 ['31900312', 'PENSOES A ANISTIADOS POLITICOS - CIVIL', '3', '1', '90', '03', '12']
# 303 ['31900313', 'PENSOES A ANISTIADOS POLITICOS - MILITAR', '3', '1', '90', '03', '13']
# 304 ['31900314', '13 SALARIO - PENSOES  CIVIL - ENCARGOS  PREVIDENCIARIOSPREVIDENCIARIOS DA UNIAO - EPU.', '3', '1', '90', '03', '14']
# 305 ['31900315', 'ADICIONAL DE DISPONIBILIDADE MILITAR - PENSIONISTA', '3', '1', '90', '03', '15']
# 306 ['31900316', 'PENSOES ORIGINARIAS DE SUBSIDIOS - CIVIS', '3', '1', '90', '03', '16']
# 307 ['31900317', 'VANTAGEM PECUNIARIA ESPECIAL - VPE', '3', '1', '90', '03', '17']
# 308 ['31900319', 'PENSOES ORIGINARIAS DE GRATIF.P/EXERC. FUNCAO', '3', '1', '90', '03', '19']
# 309 ['31900320', 'PENSOES ORIGINARIAS DE GRATIF.P/EXERC.DE CARG', '3', '1', '90', '03', '20']
# 310 ['31900322', 'RETR.ADIC.VARIAVEL E PRO-LABORE(LEI 7711/88)', '3', '1', '90', '03', '22']
# 311 ['31900323', 'RETRIBUICAO VARIAVEL SUPERINT. SEGURO PRIVADO', '3', '1', '90', '03', '23']
# 312 ['31900325', 'GRATIFICACOES ESPECIAIS_- PENSIONISTAS', '3', '1', '90', '03', '25']
# 313 ['31900328', 'VANTAGENS INCORPORADAS - PENSIONISTAS', '3', '1', '90', '03', '28']
# 314 ['31900330', '-7', '3', '1', '90', '03', '30']
# 315 ['31900331', '-7', '3', '1', '90', '03', '31']
# 316 ['31900332', '-7', '3', '1', '90', '03', '32']
# 317 ['31900334', 'GRATIFICACAO DE ATIVIDADE JUDICIARIA - GAJ', '3', '1', '90', '03', '34']
# 318 ['31900336', 'GRATIFICACAO DE ATIVIDADES EXTERNAS - GAE', '3', '1', '90', '03', '36']
# 319 ['31900338', 'BENEFICIO ESPECIAL LEI 12.618/2012 - PENSAO', '3', '1', '90', '03', '38']
# 320 ['31900340', 'GRATIFICACOES ESPECIAIS_A PENSIONISTA', '3', '1', '90', '03', '40']
# 321 ['31900342', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '03', '42']
# 322 ['31900360', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '03', '60']
# 323 ['31900365', 'BONUS DE EFICIENCIA E PRODUTIVIDADE', '3', '1', '90', '03', '65']
# 324 ['31900384', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '03', '84']
# 325 ['31900386', 'COMPLEMENTACAO DE PENSOES - PESSOAL CIVIL', '3', '1', '90', '03', '86']
# 326 ['31900387', 'COMPLEMENTACAO DE PENSOES - PESSOAL MILITAR', '3', '1', '90', '03', '87']
# 327 ['31900389', 'OUTRAS PENSOES - MILITARES', '3', '1', '90', '03', '89']
# 328 ['31900390', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '03', '90']
# 329 ['31900396', 'PENSOES - PAGAMENTO ANTECIPADO', '3', '1', '90', '03', '96']
# 330 ['31900398', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '03', '98']
# 331 ['31900399', 'OUTRAS PENSOES - CIVIS', '3', '1', '90', '03', '99']
# 332 ['319003EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '03', '-2']
# 333 ['319003ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '03', '-1']
# 334 ['319004-7', 'CODIGO INVALIDO', '3', '1', '90', '04', '-7']
# 335 ['319004-8', 'SEM INFORMACAO', '3', '1', '90', '04', '-8']
# 336 ['319004-9', 'NAO SE APLICA', '3', '1', '90', '04', '-9']
# 337 ['31900400', 'CONTRATACAO P/TEMPO DETERMINADO', '3', '1', '90', '04', '00']
# 338 ['31900401', 'SALARIO CONTRATO TEMPORARIO', '3', '1', '90', '04', '01']
# 339 ['31900402', 'SALARIO-FAMILIA', '3', '1', '90', '04', '02']
# 340 ['31900403', 'ADICIONAL NOTURNO DE CONTRATO TEMPORARIO', '3', '1', '90', '04', '03']
# 341 ['31900405', 'ADICIONAL DE PERICULOSIDADE - CONTRATO TEMPORARIO', '3', '1', '90', '04', '05']
# 342 ['31900406', 'ADICIONAL DE INSALUBRIDADE - CONTRATO TEMPORARIO', '3', '1', '90', '04', '06']
# 343 ['31900407', 'ADICIONAL DE ATIVIDADES PENOSAS - CONTRATO TEMPORARIO', '3', '1', '90', '04', '07']
# 344 ['31900408', 'ADIC.DE IRRADIACAO IONIZANTE - CONTR.TEMPORAR', '3', '1', '90', '04', '08']
# 345 ['31900409', 'GRATIFICACAO DE RAIO-X - CONTRATO TEMPORARIO', '3', '1', '90', '04', '09']
# 346 ['31900410', 'SERVICOS EXTRAORDINARIOS - CONTRATO TEMPORARIO', '3', '1', '90', '04', '10']
# 347 ['31900411', 'SERV.EXTRAORD. NOTURNO - CONTRATO TEMPORARIO', '3', '1', '90', '04', '11']
# 348 ['31900412', 'FERIAS VENCIDAS/PROPORCIONAIS - CONTRATO TEMPORARIO', '3', '1', '90', '04', '12']
# 349 ['31900413', '13¤ SALARIO - CONTRATO TEMPORARIO', '3', '1', '90', '04', '13']
# 350 ['31900414', 'FERIAS - ABONO CONSTITUCIONAL - CONTRATO TEMPORARIO', '3', '1', '90', '04', '14']
# 351 ['31900415', 'OBRIGACOES PATRONAIS - CONTRATOS TEMPORARIOS', '3', '1', '90', '04', '15']
# 352 ['31900416', 'FERIAS PAGAMENTO ANTECIPADO - CONTRATOS TEMPORARIOS', '3', '1', '90', '04', '16']
# 353 ['31900417', 'INDENIZACAO ? 2º ART.12 LEI 8.745/93', '3', '1', '90', '04', '17']
# 354 ['31900418', 'ADICIONAL REMUNERACAO DO MILITAR - ART.18 LEI 13.954/19', '3', '1', '90', '04', '18']
# 355 ['31900420', 'OUTRAS VANTAGENS CONTRATOS TEMPORARIOS', '3', '1', '90', '04', '20']
# 356 ['31900421', 'SALARIO FAMILIA LEI 8.745/93', '3', '1', '90', '04', '21']
# 357 ['31900422', 'ADICIONAL NOTURNO CONTRATO TEMPORARIO', '3', '1', '90', '04', '22']
# 358 ['31900423', 'ADICIONAL DE PERICULOSIDADE CONT. TEMPORARIO', '3', '1', '90', '04', '23']
# 359 ['31900424', 'ADICIONAL DE INSALUBRIDADE CONT. TEMPORARIO', '3', '1', '90', '04', '24']
# 360 ['31900425', 'ADICIONAL DE ATIVIDADES PENOSAS CONT. TEMP.', '3', '1', '90', '04', '25']
# 361 ['31900426', 'ADICIONAL DE IRRADIACAO IONIZANTE CONT. TEMP.', '3', '1', '90', '04', '26']
# 362 ['31900427', 'GRATIFICACAO DE RAIO-X CONTRATO TEMPORARIO', '3', '1', '90', '04', '27']
# 363 ['31900428', 'SERVICOS EXTRAORDINARIOS CONTRATO TEMPORARIO', '3', '1', '90', '04', '28']
# 364 ['31900429', 'SERVICOS EXTRAORDINARIOS NOTURNO CONT. TEMP.', '3', '1', '90', '04', '29']
# 365 ['31900430', 'FERIAS VENCIDAS/PROPORCIONAIS CONT.TEMPORARIO', '3', '1', '90', '04', '30']
# 366 ['31900431', '13º SALARIO CONTRATO TEMPORARIO', '3', '1', '90', '04', '31']
# 367 ['31900432', 'FERIAS - ABONO CONSTITUCIONAL', '3', '1', '90', '04', '32']
# 368 ['31900433', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '04', '33']
# 369 ['31900434', 'INDENIZACAO ? 2º ART.12 LEI 8.745/93', '3', '1', '90', '04', '34']
# 370 ['31900440', '-7', '3', '1', '90', '04', '40']
# 371 ['31900441', '-7', '3', '1', '90', '04', '41']
# 372 ['31900453', 'CONTRATACAO POR TEMPO DETERMINADO - PES.CIVIL', '3', '1', '90', '04', '53']
# 373 ['31900498', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '04', '98']
# 374 ['31900499', 'OUTRAS VANTAGENS - CONTRATOS TEMPORARIOS', '3', '1', '90', '04', '99']
# 375 ['319004EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '04', '-2']
# 376 ['319005-7', 'CODIGO INVALIDO', '3', '1', '90', '05', '-7']
# 377 ['319005-8', 'SEM INFORMACAO', '3', '1', '90', '05', '-8']
# 378 ['319005-9', 'NAO SE APLICA', '3', '1', '90', '05', '-9']
# 379 ['31900500', 'OUTROS BENEF.PREV. DO SERVIDOR OU DO MILITAR', '3', '1', '90', '05', '00']
# 380 ['31900501', 'AUXILIO-RECLUSAO ATIVO CIVIL', '3', '1', '90', '05', '01']
# 381 ['31900502', 'AUXILIO-RECLUSAO ATIVO MILITAR', '3', '1', '90', '05', '02']
# 382 ['31900503', 'SALARIO-FAMILIA ATIVO CIVIL', '3', '1', '90', '05', '03']
# 383 ['31900504', 'SALARIO-FAMILIA ATIVO MILITAR', '3', '1', '90', '05', '04']
# 384 ['31900505', 'SALARIO-FAMILIA INATIVO CIVIL', '3', '1', '90', '05', '05']
# 385 ['31900506', 'SALARIO-FAMILIA INATIVO MILITAR', '3', '1', '90', '05', '06']
# 386 ['31900507', 'SALARIO-FAMILIA PENSIONISTA CIVIL', '3', '1', '90', '05', '07']
# 387 ['31900508', 'SALARIO-FAMILIA PENSIONIOSTA MILITAR', '3', '1', '90', '05', '08']
# 388 ['31900509', 'AUXILIO-DOENCA', '3', '1', '90', '05', '09']
# 389 ['31900550', '-7', '3', '1', '90', '05', '50']
# 390 ['31900599', 'OUTROS BENEF.PREV.SERVIDOR OU MILITAR', '3', '1', '90', '05', '99']
# 391 ['319007-7', 'CODIGO INVALIDO', '3', '1', '90', '07', '-7']
# 392 ['319007-8', 'SEM INFORMACAO', '3', '1', '90', '07', '-8']
# 393 ['319007-9', 'NAO SE APLICA', '3', '1', '90', '07', '-9']
# 394 ['31900700', 'CONTRIB. A ENTIDADES FECHADAS DE PREVIDENCIA', '3', '1', '90', '07', '00']
# 395 ['31900701', 'CONTRIBUICAO PATRONAL PREVIDENCIA PRIVADA', '3', '1', '90', '07', '01']
# 396 ['31900702', 'SEGUROS', '3', '1', '90', '07', '02']
# 397 ['31900703', 'CONT. PATRONAL PREVIDENCIA PRIVADA', '3', '1', '90', '07', '03']
# 398 ['31900704', 'CONTRIBUICAO PATRONAL PREVIDENCIA PRIVADA-PDV', '3', '1', '90', '07', '04']
# 399 ['31900705', 'COMPLEM DE PREVID PRORROG SALAR MATERNIDADE', '3', '1', '90', '07', '05']
# 400 ['31900706', 'CONTRIBUICAO PATRONAL - FUNPRESP LEI 12618/12', '3', '1', '90', '07', '06']
# 401 ['31900714', 'MULTAS INDEDUTIVEIS - ENTIDADES FECHADAS DE PREVIDENCIA', '3', '1', '90', '07', '14']
# 402 ['31900770', '-7', '3', '1', '90', '07', '70']
# 403 ['31900790', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '07', '90']
# 404 ['31900798', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '07', '98']
# 405 ['31900799', 'OUTRAS CONTRIBUICOES', '3', '1', '90', '07', '99']
# 406 ['319007EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '07', '-2']
# 407 ['319008-7', 'CODIGO INVALIDO', '3', '1', '90', '08', '-7']
# 408 ['319008-8', 'SEM INFORMACAO', '3', '1', '90', '08', '-8']
# 409 ['319008-9', 'NAO SE APLICA', '3', '1', '90', '08', '-9']
# 410 ['31900800', 'OUTROS BENEF.ASSIST. DO SERVIDOR E DO MILITAR', '3', '1', '90', '08', '00']
# 411 ['31900801', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '08', '01']
# 412 ['31900802', 'AUXILIO FUNERAL ATIVO MILITAR', '3', '1', '90', '08', '02']
# 413 ['31900803', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '08', '03']
# 414 ['31900804', 'AUXILIO FUNERAL INATIVO MILITAR', '3', '1', '90', '08', '04']
# 415 ['31900805', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '08', '05']
# 416 ['31900806', 'AUXILIO NATALIDADE ATIVO MILITAR', '3', '1', '90', '08', '06']
# 417 ['31900807', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '08', '07']
# 418 ['31900808', 'AUXILIO NATALIDADE INATIVO MILITAR', '3', '1', '90', '08', '08']
# 419 ['31900809', 'AUXILIO RECLUSAO ATIVO CIVIL', '3', '1', '90', '08', '09']
# 420 ['31900810', 'AUXILIO RECLUSAO ATIVO MILITAR', '3', '1', '90', '08', '10']
# 421 ['31900811', 'AUXILIO RECLUSAO INATIVO CIVIL', '3', '1', '90', '08', '11']
# 422 ['31900812', 'AUXILIO RECLUSAO INATIVO MILITAR', '3', '1', '90', '08', '12']
# 423 ['31900813', 'AUXILIO FUNERAL PENSIONISTA CIVIL', '3', '1', '90', '08', '13']
# 424 ['31900814', 'AUXILIO FUNERAL PENSIONISTA MILITAR', '3', '1', '90', '08', '14']
# 425 ['31900815', 'AUXILIO RECLUSAO PENSIONISTA CIVIL', '3', '1', '90', '08', '15']
# 426 ['31900816', 'AUXILIO RECLUSAO PENSIONISTA MILITAR', '3', '1', '90', '08', '16']
# 427 ['31900817', 'AUXILIO NATALIDADE PENSIONISTA MILITAR', '3', '1', '90', '08', '17']
# 428 ['31900818', 'AUXILIO NATALIDADE PENSIONISTA CIVIL', '3', '1', '90', '08', '18']
# 429 ['31900819', 'AUXILIO-FAMILIAR - NO EXTERIOR', '3', '1', '90', '08', '19']
# 430 ['31900851', 'AUXILIO-DOENCA MEMBROS DO MPU', '3', '1', '90', '08', '51']
# 431 ['31900884', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '08', '84']
# 432 ['31900890', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '08', '90']
# 433 ['31900898', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '08', '98']
# 434 ['31900899', 'OUTROS BENEFICIOS ASSISTENCIAIS', '3', '1', '90', '08', '99']
# 435 ['319008EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '08', '-2']
# 436 ['319008ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '08', '-1']
# 437 ['319009', 'SEM INFORMACAO', '3', '1', '90', '09', '-8']
# 438 ['319009-7', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '09', '-7']
# 439 ['319009-9', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '09', '-9']
# 440 ['31900900', 'NAO SE APLICA', '3', '1', '90', '09', '00']
# 441 ['31900901', 'SALARIO FAMILIA - ATIVO PESSOAL CIVIL', '3', '1', '90', '09', '01']
# 442 ['31900902', 'SALARIO FAMILIA-INATIVO PESSOAL CIVIL', '3', '1', '90', '09', '02']
# 443 ['31900903', 'SALARIO FAMILIA-ATIVO PESSOAL MILITAR', '3', '1', '90', '09', '03']
# 444 ['31900904', 'SALARIO FAMILIA - INATIVO PESSOAL MILITAR', '3', '1', '90', '09', '04']
# 445 ['31900905', 'SALARIO FAMILIA-PENSIONISTA PESSOAL CIVIL', '3', '1', '90', '09', '05']
# 446 ['31900906', 'SALARIO FAMILIA - PENSIONIOSTA PESS. MILITAR', '3', '1', '90', '09', '06']
# 447 ['31900984', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '09', '84']
# 448 ['31900990', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '09', '90']
# 449 ['31900998', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '09', '98']
# 450 ['31900999', 'OUTROS SALARIOS-FAMILIA', '3', '1', '90', '09', '99']
# 451 ['319009EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '09', '-2']
# 452 ['319009ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '09', '-1']
# 453 ['31901000', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '00']
# 454 ['31901002', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '02']
# 455 ['31901003', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '03']
# 456 ['31901004', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '04']
# 457 ['31901005', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '05']
# 458 ['31901007', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '10', '07']
# 459 ['319011-7', 'CODIGO INVALIDO', '3', '1', '90', '11', '-7']
# 460 ['319011-8', 'SEM INFORMACAO', '3', '1', '90', '11', '-8']
# 461 ['319011-9', 'NAO SE APLICA', '3', '1', '90', '11', '-9']
# 462 ['31901100', 'VENCIMENTOS E VANTAGENS FIXAS - PESSOAL CIVIL', '3', '1', '90', '11', '00']
# 463 ['31901101', 'VENCIMENTOS E SALARIOS', '3', '1', '90', '11', '01']
# 464 ['31901102', 'REMUNERACAO NO PERIODO DE FERIAS', '3', '1', '90', '11', '02']
# 465 ['31901103', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '03']
# 466 ['31901104', 'ADICIONAL NOTURNO', '3', '1', '90', '11', '04']
# 467 ['31901105', 'INCORPORACOES', '3', '1', '90', '11', '05']
# 468 ['31901106', 'VANTAGENS PERM.SENT.JUD.TRANS.JULGADO - CIVIL', '3', '1', '90', '11', '06']
# 469 ['31901107', 'ABONO DE PERMANENCIA', '3', '1', '90', '11', '07']
# 470 ['31901108', 'AUXILIO-DOENCA (LICENCA PARA TRATAMENTO DE SAUDE)', '3', '1', '90', '11', '08']
# 471 ['31901109', 'ADICIONAL DE PERICULOSIDADE', '3', '1', '90', '11', '09']
# 472 ['31901110', 'ADICIONAL DE INSALUBRIDADE', '3', '1', '90', '11', '10']
# 473 ['31901111', 'ADICIONAL DE ATIVIDADES PENOSAS', '3', '1', '90', '11', '11']
# 474 ['31901112', 'RETRIBUICAO BASICA NO EXTERIOR - CIVIL (LEI 5.809/1972)', '3', '1', '90', '11', '12']
# 475 ['31901113', 'INCENTIVO A QUALIFICACAO', '3', '1', '90', '11', '13']
# 476 ['31901114', 'ADICIONAL DE TRANSFERENCIA - ART. 469/CLT', '3', '1', '90', '11', '14']
# 477 ['31901115', 'APRENDIZES - CONTRATACAO DIRETA (LEI 10.097/2000)', '3', '1', '90', '11', '15']
# 478 ['31901116', 'GRATIFICACAO NO EXTERIOR POR TEMPO DE SERVICO - CIVIL', '3', '1', '90', '11', '16']
# 479 ['31901117', '-7', '3', '1', '90', '11', '17']
# 480 ['31901118', '-7', '3', '1', '90', '11', '18']
# 481 ['31901119', '-7', '3', '1', '90', '11', '19']
# 482 ['31901122', 'PRO-LABORE (LEI 10549/2002)', '3', '1', '90', '11', '22']
# 483 ['31901123', 'RETRIBUICAO VARIAVEL SUPERINT. SEGURO PRIVADO', '3', '1', '90', '11', '23']
# 484 ['31901128', 'VANTAGEM PECUNIARIA INDIVIDUAL', '3', '1', '90', '11', '28']
# 485 ['31901130', 'ABONO PROVISORIO - PESSOAL CIVIL', '3', '1', '90', '11', '30']
# 486 ['31901131', 'GRATIFICACAO POR EXERCICIO DE CARGO EFETIVO', '3', '1', '90', '11', '31']
# 487 ['31901132', 'INCREMENTO PLANO DE CARGOS E SALARIOS JUDIC.', '3', '1', '90', '11', '32']
# 488 ['31901133', 'GRAT POR EXERCICIO DE FUNCOES COMISSIONADAS', '3', '1', '90', '11', '33']
# 489 ['31901134', 'GRATIFICACAO DE ATIVIDADES JUDICIARIA - GAJ', '3', '1', '90', '11', '34']
# 490 ['31901135', 'GRATIFICACAO/ADICIONAL DE LOCALIZACAO', '3', '1', '90', '11', '35']
# 491 ['31901136', 'GRATIFICACAO P/EXERCICIO DE CARGO EM COMISSAO', '3', '1', '90', '11', '36']
# 492 ['31901137', 'GRATIFICACAO DE TEMPO DE SERVICO', '3', '1', '90', '11', '37']
# 493 ['31901138', 'GRATIFICACAO DE ATIVIDADE DE SEGURANCA - GAS', '3', '1', '90', '11', '38']
# 494 ['31901139', 'BONUS ESPECIAL DE DESEMP. INSTIT. - BESP/DNIT', '3', '1', '90', '11', '39']
# 495 ['31901140', 'GRATIFICACOES ESPECIAIS', '3', '1', '90', '11', '40']
# 496 ['31901141', 'GRATIFICACAO POR ATIVIDADES EXPOSTAS', '3', '1', '90', '11', '41']
# 497 ['31901142', 'FERIAS VENCIDAS E PROPORCIONAIS', '3', '1', '90', '11', '42']
# 498 ['31901143', '13º SALARIO', '3', '1', '90', '11', '43']
# 499 ['31901144', 'FERIAS - ABONO PECUNIARIO', '3', '1', '90', '11', '44']
# 500 ['31901145', 'FERIAS - 1/3 CONSTITUCIONAL', '3', '1', '90', '11', '45']
# 501 ['31901146', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '11', '46']
# 502 ['31901147', 'LICENCA-PREMIO', '3', '1', '90', '11', '47']
# 503 ['31901149', 'LICENCA CAPACITACAO', '3', '1', '90', '11', '49']
# 504 ['31901150', 'VENCIM. E SAL.- PROR. SALARIO MATERNIDADE', '3', '1', '90', '11', '50']
# 505 ['31901160', 'ADICIONAL - TETO PARLAMENTAR', '3', '1', '90', '11', '60']
# 506 ['31901165', 'BONUS DE EFICIENCIA E PRODUTIVIDADE', '3', '1', '90', '11', '65']
# 507 ['31901171', 'REMUNERACAO DE DIRETORES', '3', '1', '90', '11', '71']
# 508 ['31901173', 'REMUN. PARTICIP. ORGAOS DELIBERACAO  COLETIVA', '3', '1', '90', '11', '73']
# 509 ['31901174', 'SUBSIDIOS', '3', '1', '90', '11', '74']
# 510 ['31901175', 'REPRESENTACAO MENSAL', '3', '1', '90', '11', '75']
# 511 ['31901177', 'REMUNERACAO DE PESSOAL EM DISPONIBILIDADE', '3', '1', '90', '11', '77']
# 512 ['31901184', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '11', '84']
# 513 ['31901187', 'COMPLEMENTACAO SALARIAL - PESSOAL CIVIL', '3', '1', '90', '11', '87']
# 514 ['31901190', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '11', '90']
# 515 ['31901196', 'VENCIMENTOS E VANTAGENS - PAGTO. ANTECIPADO', '3', '1', '90', '11', '96']
# 516 ['31901198', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '11', '98']
# 517 ['31901199', 'OUTRAS DESPESAS FIXAS - PESSOAL CIVIL', '3', '1', '90', '11', '99']
# 518 ['319011EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '-2']
# 519 ['319011ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '11', '-1']
# 520 ['319012-7', 'CODIGO INVALIDO', '3', '1', '90', '12', '-7']
# 521 ['319012-8', 'SEM INFORMACAO', '3', '1', '90', '12', '-8']
# 522 ['319012-9', 'NAO SE APLICA', '3', '1', '90', '12', '-9']
# 523 ['31901200', 'VENCIMENTOS E VANTAGENS FIXAS - PES. MILITAR', '3', '1', '90', '12', '00']
# 524 ['31901201', 'SOLDO', '3', '1', '90', '12', '01']
# 525 ['31901202', 'ADICIONAL DE PERMANENCIA', '3', '1', '90', '12', '02']
# 526 ['31901203', 'ADICIONAL DE TEMPO DE SERVICO', '3', '1', '90', '12', '03']
# 527 ['31901204', 'ADICIONAL MILITAR', '3', '1', '90', '12', '04']
# 528 ['31901205', 'ADICIONAL DE COMPENSACAO ORGANICA', '3', '1', '90', '12', '05']
# 529 ['31901206', 'ADICIONAL DE HABILITACAO', '3', '1', '90', '12', '06']
# 530 ['31901207', 'GRATIFICACAO DE LOCALIDADE ESPECIAL', '3', '1', '90', '12', '07']
# 531 ['31901208', 'GRATIFICACAO DE REPRESENTACAO', '3', '1', '90', '12', '08']
# 532 ['31901209', 'GRATIFICACAO DE FUNCAO DE NATUREZA ESPECIAL', '3', '1', '90', '12', '09']
# 533 ['31901210', 'GRATIFICACAO DE SERVICO VOLUNTARIO.', '3', '1', '90', '12', '10']
# 534 ['31901211', 'VANTAGEM PECUNIARIA ESPECIAL - VPE.', '3', '1', '90', '12', '11']
# 535 ['31901212', 'RETRIBUICAO BASICA NO EXTERIOR - MILITAR (LEI 5.809/72)', '3', '1', '90', '12', '12']
# 536 ['31901213', 'VANTAG.PERM.SENT.JUD.TRANS.JULGADO - MILITAR', '3', '1', '90', '12', '13']
# 537 ['31901214', 'ADICIONAL DE DISPONIBILIDADE MILITAR - ATIVO', '3', '1', '90', '12', '14']
# 538 ['31901216', 'GRATIFICACAO NO EXTERIOR POR TEMPO DE SERVICO - MILITARCONFORME ARTIGO 8º, INCISO II, DA LEI 5.809/1972.', '3', '1', '90', '12', '16']
# 539 ['31901220', '-7', '3', '1', '90', '12', '20']
# 540 ['31901223', '-7', '3', '1', '90', '12', '23']
# 541 ['31901224', '-7', '3', '1', '90', '12', '24']
# 542 ['31901228', '-7', '3', '1', '90', '12', '28']
# 543 ['31901231', 'GRATIFICACAO DE EXERCICIOS DE CARGOS.', '3', '1', '90', '12', '31']
# 544 ['31901242', 'FERIAS VENCIDAS E PROPORCIONAIS', '3', '1', '90', '12', '42']
# 545 ['31901243', 'ADICIONAL NATALINO', '3', '1', '90', '12', '43']
# 546 ['31901244', 'FERIAS - ABONO PECUNIARIO', '3', '1', '90', '12', '44']
# 547 ['31901245', 'FERIAS - ABONO CONSTITUCIONAL', '3', '1', '90', '12', '45']
# 548 ['31901246', 'FERIAS - PAGAMENTO ANTECIPADO', '3', '1', '90', '12', '46']
# 549 ['31901275', 'INDENIZACAO DE REPRESENTACAO.', '3', '1', '90', '12', '75']
# 550 ['31901284', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '12', '84']
# 551 ['31901287', 'COMPLEMENTACAO SALARIAL - PESSOAL MILITAR', '3', '1', '90', '12', '87']
# 552 ['31901290', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '12', '90']
# 553 ['31901298', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '12', '98']
# 554 ['31901299', 'OUTRAS DESPESAS FIXAS - PESSOAL MILITAR', '3', '1', '90', '12', '99']
# 555 ['319012EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '12', '-2']
# 556 ['319013-7', 'CODIGO INVALIDO', '3', '1', '90', '13', '-7']
# 557 ['319013-8', 'SEM INFORMACAO', '3', '1', '90', '13', '-8']
# 558 ['319013-9', 'NAO SE APLICA', '3', '1', '90', '13', '-9']
# 559 ['31901300', 'OBRIGACOES PATRONAIS', '3', '1', '90', '13', '00']
# 560 ['31901301', 'FGTS', '3', '1', '90', '13', '01']
# 561 ['31901302', 'CONTRIBUICOES PREVIDENCIARIAS - INSS', '3', '1', '90', '13', '02']
# 562 ['31901303', 'CONTRIBUICOES PREVIDENCIARIAS - NO EXTERIOR', '3', '1', '90', '13', '03']
# 563 ['31901304', 'CONTRIBUICAO DE SALARIO-EDUCACAO', '3', '1', '90', '13', '04']
# 564 ['31901305', 'ENCARGOS PATRONAIS - PESSOAL REQUISITADO DE OUTRO ENTE.', '3', '1', '90', '13', '05']
# 565 ['31901306', 'CONTRIBUICAO PARA O PIS/PASEP SOBRE A FOLHA DE SALARIOS', '3', '1', '90', '13', '06']
# 566 ['31901307', 'FGTS-PRORROGACAO DO SALARIO MATERNIDADE', '3', '1', '90', '13', '07']
# 567 ['31901308', 'PLANO DE SEG. SOC. DO SERVIDOR - PES. ATIVO', '3', '1', '90', '13', '08']
# 568 ['31901309', 'SEGUROS DE ACIDENTES DO TRABALHO', '3', '1', '90', '13', '09']
# 569 ['31901310', 'CONTRIB DE SALAR-EDUC PRORRO SALAR MATERN.', '3', '1', '90', '13', '10']
# 570 ['31901311', 'FGTS - PDV', '3', '1', '90', '13', '11']
# 571 ['31901313', 'SESI/SESC ATIVO CIVIL', '3', '1', '90', '13', '13']
# 572 ['31901314', 'MULTAS INDEDUTIVEIS', '3', '1', '90', '13', '14']
# 573 ['31901315', 'MULTAS DEDUTIVEIS', '3', '1', '90', '13', '15']
# 574 ['31901316', 'CONTRIB.0,5/100 S/REMUNARACAO MES ANT.-LC 101/01', '3', '1', '90', '13', '16']
# 575 ['31901317', 'JUROS', '3', '1', '90', '13', '17']
# 576 ['31901318', 'CONTRIBUICAO PARA O PIS/PASEP S/FOLHA PAGTO', '3', '1', '90', '13', '18']
# 577 ['31901319', 'SENAI/SENAC ATIVO CIVIL', '3', '1', '90', '13', '19']
# 578 ['31901320', 'SEBRAE ATIVO CIVIL', '3', '1', '90', '13', '20']
# 579 ['31901336', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '13', '36']
# 580 ['31901340', 'ENCARGOS DE PESSOAL REQUISIT. DE OUTROS ENTES', '3', '1', '90', '13', '40']
# 581 ['31901384', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '13', '84']
# 582 ['31901390', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '13', '90']
# 583 ['31901398', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '13', '98']
# 584 ['31901399', 'OUTRAS OBRIGACOES PATRONAIS', '3', '1', '90', '13', '99']
# 585 ['319013EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '13', '-2']
# 586 ['319013ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '13', '-1']
# 587 ['319016-7', 'CODIGO INVALIDO', '3', '1', '90', '16', '-7']
# 588 ['319016-8', 'SEM INFORMACAO', '3', '1', '90', '16', '-8']
# 589 ['319016-9', 'NAO SE APLICA', '3', '1', '90', '16', '-9']
# 590 ['31901600', 'OUTRAS DESPESAS VARIAVEIS - PESSOAL CIVIL', '3', '1', '90', '16', '00']
# 591 ['31901601', 'BONUS DE DESEMPENHO INSTITUCIONAL POR ANALISE DE BENEFICIOS - INSS', '3', '1', '90', '16', '01']
# 592 ['31901602', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '16', '02']
# 593 ['31901604', 'CONVOCACAO EXTRAORDINARIA LEGISLATIVA', '3', '1', '90', '16', '04']
# 594 ['31901608', 'GRATIFICACAO ELEITORAL', '3', '1', '90', '16', '08']
# 595 ['31901610', 'LICENCA SEM REMUNERACAO INCENTIVADA', '3', '1', '90', '16', '10']
# 596 ['31901632', 'SUBSTITUICOES', '3', '1', '90', '16', '32']
# 597 ['31901633', 'GRATIFICACAO POR EXRCICIO CUMULATIVO DE OFICIOS OU  JU-RISDICAO', '3', '1', '90', '16', '33']
# 598 ['31901634', 'AVISO PREVIO.', '3', '1', '90', '16', '34']
# 599 ['31901635', 'ADICIONAL VARIAVEL', '3', '1', '90', '16', '35']
# 600 ['31901636', 'ADICIONAL POR PLANTAO HOSPITALAR', '3', '1', '90', '16', '36']
# 601 ['31901639', 'GRATIFICACAO P / ENCARGO DE CURSO OU CONCURSO', '3', '1', '90', '16', '39']
# 602 ['31901644', 'SERVICOS EXTRAORDINARIOS', '3', '1', '90', '16', '44']
# 603 ['31901645', 'PARTICIPACAO A EMPREGADOS E ADMINISTRADORES', '3', '1', '90', '16', '45']
# 604 ['31901663', '-7', '3', '1', '90', '16', '63']
# 605 ['31901664', '-7', '3', '1', '90', '16', '64']
# 606 ['31901676', 'AUXILIO MORADIA', '3', '1', '90', '16', '76']
# 607 ['31901684', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '3', '1', '90', '16', '84']
# 608 ['31901690', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '3', '1', '90', '16', '90']
# 609 ['31901696', 'OUTRAS DESP.VARIAV.PESS. CIV.-PAGMTO ANTECIP.', '3', '1', '90', '16', '96']
# 610 ['31901698', 'INSCRICAO DE RESTOS A PAGAR', '3', '1', '90', '16', '98']
# 611 ['31901699', 'OUTRAS DESPESAS VARIAVEIS - PESSOAL CIVIL', '3', '1', '90', '16', '99']
# 612 ['319016EN', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '16', '-2']
# 613 ['319016ES', 'CODIGO INEXISTENTE NO SIAFI', '3', '1', '90', '16', '-1']
# 614 ['319017-7', 'CODIGO INVALIDO', '3', '1', '90', '17', '-7']
# 615 ['319017-8', 'SEM INFORMACAO', '3', '1', '90', '17', '-8']
# 616 ['319017-9', 'NAO SE APLICA', '3', '1', '90', '17', '-9']
# 617 ['31901700', 'OUTRAS DESPESAS VARIAVEIS - PESSOAL MILITAR', '3', '1', '90', '17', '00']
# 618 ['31901701', 'MOVIMENTACAO DE MILITARES (EXERCICIO 2013)', '3', '1', '90', '17', '01']
# 619 ['31901702', 'AJUDA DE CUSTO TRANF.ATIV.MILI. P/INAT REMUNE', '3', '1', '90', '17', '02']
# 620 ['31901703', 'INDENIZACAO DE MILITARES', '3', '1', '90', '17', '03']
# 621 ['31901733', 'INDENIZACOES/MILITAR', '3', '1', '90', '17', '33']
# 622 ['31901734', 'DIREITO REMUN. PES. MILITAR-TRANSPORTE', '3', '1', '90', '17', '34']
# 623 ['31901736', 'DIREITO REMUN. PES. MILITAR-ETAPA ALIMENTACAO', '3', '1', '90', '17', '36']
# 624 ['31901737', 'ADICIONAL TAREFA TEMPO CERTO(ART. 23 MP 2131)', '3', '1', '90', '17', '37']
# ...
# 8852 ['467300-7', 'CODIGO INVALIDO', '4', '6', '73', '00', '-7']
# 8853 ['467300-9', 'NAO SE APLICA', '4', '6', '73', '00', '-9']
# 8854 ['46730000', 'TRANSF.CONSOR.PUB.ART.24 LC 141/12 ?? 1º E 2º', '4', '6', '73', '00', '00']
# 8855 ['467370-7', 'CODIGO INVALIDO', '4', '6', '73', '70', '-7']
# 8856 ['467370-9', 'NAO SE APLICA', '4', '6', '73', '70', '-9']
# 8857 ['46737000', 'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO', '4', '6', '73', '70', '00']
# 8858 ['467400-7', 'CODIGO INVALIDO', '4', '6', '74', '00', '-7']
# 8859 ['467400-9', 'NAO SE APLICA', '4', '6', '74', '00', '-9']
# 8860 ['46740000', 'TRANSFERENCIA A CONSORCIOS PULBICOS LC 141/12', '4', '6', '74', '00', '00']
# 8861 ['467470-7', 'CODIGO INVALIDO', '4', '6', '74', '70', '-7']
# 8862 ['467470-9', 'NAO SE APLICA', '4', '6', '74', '70', '-9']
# 8863 ['46747000', 'RATEIO PELA PARTICIPACAO EM CONSORCIO PUBLICO', '4', '6', '74', '70', '00']
# 8864 ['469000-7', 'CODIGO INVALIDO', '4', '6', '90', '00', '-7']
# 8865 ['469000-8', 'SEM INFORMACAO', '4', '6', '90', '00', '-8']
# 8866 ['469000-9', 'NAO SE APLICA', '4', '6', '90', '00', '-9']
# 8867 ['46900000', 'APLICACOES DIRETAS', '4', '6', '90', '00', '00']
# 8868 ['469000EN', 'CODIGO INEXISTENTE NO SIAFI', '4', '6', '90', '00', '-2']
# 8869 ['469026', 'SEM INFORMACAO', '4', '6', '90', '26', '-8']
# 8870 ['469026-7', 'CODIGO INVALIDO', '4', '6', '90', '26', '-7']
# 8871 ['469026-9', 'NAO SE APLICA', '4', '6', '90', '26', '-9']
# 8872 ['46902600', 'OBRIGACOES DECORRENTES DE POLITICA MONETARIA', '4', '6', '90', '26', '00']
# 8873 ['46902601', 'COBERTURA DO RESULTADO NEGATIVO DO BANCO CENTRAL DO BRASIL (LRF, ART. 7º, ?1º)', '4', '6', '90', '26', '01']
# 8874 ['46907003', 'CODIGO INEXISTENTE NO SIAFI', '4', '6', '90', '70', '03']
# 8875 ['469071-7', 'CODIGO INVALIDO', '4', '6', '90', '71', '-7']
# 8876 ['469071-8', 'SEM INFORMACAO', '4', '6', '90', '71', '-8']
# 8877 ['469071-9', 'NAO SE APLICA', '4', '6', '90', '71', '-9']
# 8878 ['46907100', 'PRINCIPAL DA DIVIDA CONTRATUAL RESGATADO', '4', '6', '90', '71', '00']
# 8879 ['46907101', 'AMORTIZACAO DA DIVIDA CONTRATUAL', '4', '6', '90', '71', '01']
# 8880 ['46907102', 'VARIACAO CAMBIAL DA DIVIDA CONTRATUAL', '4', '6', '90', '71', '02']
# 8881 ['46907103', 'ATUALIZACAO MONETARIA DA DIVIDA CONTRATUAL', '4', '6', '90', '71', '03']
# 8882 ['46907104', 'VARIACAO CAMBIAL DA DIVIDA CONTRATUAL', '4', '6', '90', '71', '04']
# 8883 ['46907105', 'ATUALIZACAO MONETARIA DA DIVIDA CONTRATUAL', '4', '6', '90', '71', '05']
# 8884 ['46907110', '-7', '4', '6', '90', '71', '10']
# 8885 ['46907184', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '4', '6', '90', '71', '84']
# 8886 ['46907190', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '4', '6', '90', '71', '90']
# 8887 ['46907198', 'INSCRICAO DE RESTOS A PAGAR', '4', '6', '90', '71', '98']
# 8888 ['46907199', 'OUTRAS AMORTIZACOES DA DIVIDA CONTRATADA', '4', '6', '90', '71', '99']
# 8889 ['469071EN', 'CODIGO INEXISTENTE NO SIAFI', '4', '6', '90', '71', '-2']
# 8890 ['469072-7', 'CODIGO INVALIDO', '4', '6', '90', '72', '-7']
# 8891 ['469072-8', 'SEM INFORMACAO', '4', '6', '90', '72', '-8']
# 8892 ['469072-9', 'NAO SE APLICA', '4', '6', '90', '72', '-9']
# 8893 ['46907200', 'PRINCIPAL DA DIVIDA MOBILIARIA RESGATADO', '4', '6', '90', '72', '00']
# 8894 ['46907201', 'RESGATE DA DIVIDA MOBILIARIA', '4', '6', '90', '72', '01']
# 8895 ['46907202', 'VARIACAO CAMBIAL DIVIDA MOBILIARIA RESGATADA', '4', '6', '90', '72', '02']
# 8896 ['46907203', 'ATUALIZACAO MONETARIA DA DIV.MOB.RESGATADA', '4', '6', '90', '72', '03']
# 8897 ['46907284', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '4', '6', '90', '72', '84']
# 8898 ['46907290', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '4', '6', '90', '72', '90']
# 8899 ['46907298', 'INSCRICAO DE RESTOS A PAGAR', '4', '6', '90', '72', '98']
# 8900 ['46907300', 'NAO SE APLICA', '4', '6', '90', '73', '00']
# 8901 ['46907301', 'DIVIDA CONTRATADA', '4', '6', '90', '73', '01']
# 8902 ['46907384', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '4', '6', '90', '73', '84']
# 8903 ['46907390', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '4', '6', '90', '73', '90']
# 8904 ['46907399', 'CORRECAO MONET.E CAMBIAL DA DIVIDA CONTRATADA', '4', '6', '90', '73', '99']
# 8905 ['469074', 'SEM INFORMACAO', '4', '6', '90', '74', '-8']
# 8906 ['469074-7', 'CODIGO INEXISTENTE NO SIAFI', '4', '6', '90', '74', '-7']
# 8907 ['469074-9', 'CODIGO INEXISTENTE NO SIAFI', '4', '6', '90', '74', '-9']
# 8908 ['46907400', 'NAO SE APLICA', '4', '6', '90', '74', '00']
# 8909 ['46907401', 'DIVIDA MOBILIARIA', '4', '6', '90', '74', '01']
# 8910 ['46907484', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '4', '6', '90', '74', '84']
# 8911 ['46907490', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '4', '6', '90', '74', '90']
# 8912 ['46907498', 'INSCRICAO DE RESTOS A PAGAR', '4', '6', '90', '74', '98']
# 8913 ['469075-7', 'CODIGO INVALIDO', '4', '6', '90', '75', '-7']
# 8914 ['469075-9', 'NAO SE APLICA', '4', '6', '90', '75', '-9']
# 8915 ['46907500', 'COR.MONET.OPER.DE CRED.POR ANTEC.DA RECEITA', '4', '6', '90', '75', '00']
# 8916 ['46907584', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '4', '6', '90', '75', '84']
# 8917 ['46907590', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '4', '6', '90', '75', '90']
# 8918 ['46907599', 'DIVERSAS COR.MON.OPER.CRED.P/ANTEC.DA RECEITA', '4', '6', '90', '75', '99']
# 8919 ['469076-7', 'CODIGO INVALIDO', '4', '6', '90', '76', '-7']
# 8920 ['469076-8', 'SEM INFORMACAO', '4', '6', '90', '76', '-8']
# 8921 ['469076-9', 'NAO SE APLICA', '4', '6', '90', '76', '-9']
# 8922 ['46907600', 'PRINCIPAL CORRIGIDO DA DIV.MOB.REFINANCIADO', '4', '6', '90', '76', '00']
# 8923 ['46907601', 'REFINANCIAMENTO PRINCIPAL DIVIDA MOBILIARIA', '4', '6', '90', '76', '01']
# 8924 ['46907602', 'VARIACAO CAMBIAL DIV.MOBILIARIA REFINANCIADA', '4', '6', '90', '76', '02']
# 8925 ['46907603', 'ATUALIZACAO MONETARIA DIVIDA MOB.REFINANCIADA', '4', '6', '90', '76', '03']
# 8926 ['46907698', 'INSCRICAO DE RESTOS A PAGAR', '4', '6', '90', '76', '98']
# 8927 ['46907699', 'OUTROS REFINANCIAMENTOS DA DIVIDA MOBILIARIA', '4', '6', '90', '76', '99']
# 8928 ['469077-7', 'CODIGO INVALIDO', '4', '6', '90', '77', '-7']
# 8929 ['469077-8', 'SEM INFORMACAO', '4', '6', '90', '77', '-8']
# 8930 ['469077-9', 'NAO SE APLICA', '4', '6', '90', '77', '-9']
# 8931 ['46907700', 'PRINCIPAL CORRIGIDO DIVIDA CONTR.REFINANCIADO', '4', '6', '90', '77', '00']
# 8932 ['46907701', 'REFINANCIAMENTO DO PRINCIPAL - DIV.CONTRATUAL', '4', '6', '90', '77', '01']
# 8933 ['46907702', 'VARIACAO CAMBIAL DIV.CONTRATUAL REFINANCIADA', '4', '6', '90', '77', '02']
# 8934 ['46907703', 'ATUALIZ.MONET.DA DIV.CONTRATUAL REFINANCIADA', '4', '6', '90', '77', '03']
# 8935 ['46907704', 'VARIACAO CAMBIAL DIV.CONTRATUAL REFINANCIADA', '4', '6', '90', '77', '04']
# 8936 ['46907705', 'ATUALIZ.MONET.DA DIV.CONTRATUAL REFINANCIADA', '4', '6', '90', '77', '05']
# 8937 ['46907784', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '4', '6', '90', '77', '84']
# 8938 ['46907798', 'INSCRICAO DE RESTOS A PAGAR', '4', '6', '90', '77', '98']
# 8939 ['46907799', 'OUTROS VALORES DIVIDA CONTRATUAL REFINANCIADA', '4', '6', '90', '77', '99']
# 8940 ['46909100', 'NAO SE APLICA', '4', '6', '90', '91', '00']
# 8941 ['46909184', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS - SAFEM', '4', '6', '90', '91', '84']
# 8942 ['46909190', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '4', '6', '90', '91', '90']
# 8943 ['46909199', 'DIVERSAS SENTENCAS', '4', '6', '90', '91', '99']
# 8944 ['469092', 'CODIGO INEXISTENTE NO SIAFI', '4', '6', '90', '92', '-8']
# 8945 ['469092-7', 'CODIGO INVALIDO', '4', '6', '90', '92', '-7']
# 8946 ['469092-9', 'NAO SE APLICA', '4', '6', '90', '92', '-9']
# 8947 ['46909200', 'DESPESAS DE EXERCICIOS ANTERIORES', '4', '6', '90', '92', '00']
# 8948 ['46909201', 'PRINCIPAL DA DIVIDA POR CONTRATO', '4', '6', '90', '92', '01']
# 8949 ['46909202', 'PRINCIPAL DA DIVIDA MOBILIARIA', '4', '6', '90', '92', '02']
# 8950 ['46909203', 'COR.MONET.E CAMBIAL DA DIVIDA POR CONTRATO', '4', '6', '90', '92', '03']
# 8951 ['46909204', 'COR.MONET.E CAMBIAL DA DIVIDA MOBILIARIA', '4', '6', '90', '92', '04']
# 8952 ['46909205', 'COR.MONET.OPER.DE CRED.POR ANTECIP.DA RECEITA', '4', '6', '90', '92', '05']
# 8953 ['46909271', 'PRINCIPAL DA DIVIDA CONTRATUAL RESGATADO', '4', '6', '90', '92', '71']
# 8954 ['46909272', 'PRINCIPAL DA DIVIDA MOBILIARIA RESGATADO', '4', '6', '90', '92', '72']
# 8955 ['46909273', 'COR. MONET. OU CAMBIAL DA DIV. CONT. RESGAT.', '4', '6', '90', '92', '73']
# 8956 ['46909274', 'COR.MONET. OU CAMBIAL DA DIV. MOBIL.RESGATADA', '4', '6', '90', '92', '74']
# 8957 ['46909275', 'COR.MON.DA DIV POR OP.DE CRED.POR ANT.RECEITA', '4', '6', '90', '92', '75']
# 8958 ['46909276', 'PRINCIPAL CORRIGIDO DA DIVIDA MOBILIARIA REFINANCIADO', '4', '6', '90', '92', '76']
# 8959 ['46909277', 'PRINCIPAL CORRIGIDO DA DIVIDA CONTRATUAL REFINANCIADO', '4', '6', '90', '92', '77']
# 8960 ['46909284', 'INTEGRACAO DADOS ESTADOS E MUNICIPIOS', '4', '6', '90', '92', '84']
# 8961 ['46909290', 'INTEGR. DADOS ORGAOS E ENTID. PARCIAIS SIAFI', '4', '6', '90', '92', '90']
# 8962 ['46909299', 'OUTRAS DESPESAS DE EXERCICIOS ANTERIORES', '4', '6', '90', '92', '99']
# 8963 ['469093', 'SEM INFORMACAO', '4', '6', '90', '93', '-8']
# 8964 ['469093-7', 'CODIGO INVALIDO', '4', '6', '90', '93', '-7']
# 8965 ['469093-9', 'NAO SE APLICA', '4', '6', '90', '93', '-9']
# 8966 ['46909300', 'INDENIZACOES E RESTITUICOES', '4', '6', '90', '93', '00']
# 8967 ['46909301', 'INDENIZACOES', '4', '6', '90', '93', '01']
# 8968 ['46909302', 'RESTITUICOES', '4', '6', '90', '93', '02']
# 8969 ['46909384', 'IDENIZACOES E RESTIUICOES - INTEGRACAO SAFEM', '4', '6', '90', '93', '84']
# 8970 ['46909390', 'INDENIZ. RESTITUICOES -INTEGR.ORGAOS PARCIAIS', '4', '6', '90', '93', '90']
# 8971 ['46909399', 'DIVERSAS INDENIZACOES E RESTITUICOES', '4', '6', '90', '93', '99']
# 8972 ['469176-7', 'CODIGO INVALIDO', '4', '6', '91', '76', '-7']
# 8973 ['469176-8', 'SEM INFORMACAO', '4', '6', '91', '76', '-8']
# 8974 ['469176-9', 'NAO SE APLICA', '4', '6', '91', '76', '-9']
# 8975 ['46917600', 'PRINCIPAL CORRIGIDO DA DIV.MOB.REFINANCIADO', '4', '6', '91', '76', '00']
# 8976 ['46917601', 'REFINANCIAMENTO PRINCIPAL DIVIDA MOBILIARIA', '4', '6', '91', '76', '01']
# 8977 ['46917602', 'VARIACAO CAMBIAL DIV.MOBILIARIA REFINANCIADA', '4', '6', '91', '76', '02']
# 8978 ['46917603', 'ATUALIZACAO MONETARIA DIVIDA MOB.REFINANCIADA', '4', '6', '91', '76', '03']
# 8979 ['46917699', 'OUTROS REFINANCIAMENTOS DA DIVIDA MOBILIARIA', '4', '6', '91', '76', '99']
# 8980 ['469177', 'CODIGO INEXISTENTE NO SIAFI', '4', '6', '91', '77', '-8']
# 8981 ['469177-7', 'CODIGO INVALIDO', '4', '6', '91', '77', '-7']
# 8982 ['469177-9', 'NAO SE APLICA', '4', '6', '91', '77', '-9']
# 8983 ['46917700', 'PRINCIPAL CORRIGIDO DIVIDA CONTRATUAL REFINANCIADO', '4', '6', '91', '77', '00']
# 8984 ['46917701', 'REFINANCIAMENTO DO PRINCIPAL - DIVIDA CONTRATUAL', '4', '6', '91', '77', '01']
# 8985 ['469500-7', 'CODIGO INVALIDO', '4', '6', '95', '00', '-7']
# 8986 ['469500-9', 'NAO SE APLICA', '4', '6', '95', '00', '-9']
# 8987 ['46950000', 'APLICACAO DIRETA - ACOES E SERVICOS DE SAUDE', '4', '6', '95', '00', '00']
# 8988 ['469571-7', 'CODIGO INVALIDO', '4', '6', '95', '71', '-7']
# 8989 ['469571-9', 'NAO SE APLICA', '4', '6', '95', '71', '-9']
# 8990 ['46957100', 'PRINCIPAL DA DIVIDA CONTRATUAL RESGATADO', '4', '6', '95', '71', '00']
# 8991 ['469573-7', 'CODIGO INVALIDO', '4', '6', '95', '73', '-7']
# 8992 ['469573-9', 'NAO SE APLICA', '4', '6', '95', '73', '-9']
# 8993 ['46957300', 'CM OU CAMBIAL DA DIVIDA CONTRATUAL RESGATADA', '4', '6', '95', '73', '00']
# 8994 ['469577-7', 'CODIGO INVALIDO', '4', '6', '95', '77', '-7']
# 8995 ['469577-9', 'NAO SE APLICA', '4', '6', '95', '77', '-9']
# 8996 ['46957700', 'PRINCIPAL CORRIGIDO DA DIVIDA CONTRATUAL RESG', '4', '6', '95', '77', '00']
# 8997 ['469591-7', 'CODIGO INVALIDO', '4', '6', '95', '91', '-7']
# 8998 ['469591-9', 'NAO SE APLICA', '4', '6', '95', '91', '-9']
# 8999 ['46959100', 'SENTENCAS JUDICIAIS', '4', '6', '95', '91', '00']
# 9000 ['469592-7', 'CODIGO INVALIDO', '4', '6', '95', '92', '-7']
# 9001 ['469592-9', 'NAO SE APLICA', '4', '6', '95', '92', '-9']
# 9002 ['46959200', 'DESPESAS DE EXERCICIOS ANTERIORES', '4', '6', '95', '92', '00']
# 9003 ['469593-7', 'CODIGO INVALIDO', '4', '6', '95', '93', '-7']
# 9004 ['469593-9', 'NAO SE APLICA', '4', '6', '95', '93', '-9']
# 9005 ['46959300', 'INDENIZACOES E RESTITUICOES', '4', '6', '95', '93', '00']
# 9006 ['469600', 'SEM INFORMACAO', '4', '6', '96', '00', '-8']
# 9007 ['469600-7', 'CODIGO INVALIDO', '4', '6', '96', '00', '-7']
# 9008 ['469600-9', 'NAO SE APLICA', '4', '6', '96', '00', '-9']
# 9009 ['46960000', 'APLICACAO DIRETA - ACOES E SERVICOS DE SAUDE', '4', '6', '96', '00', '00']
# 9010 ['469671-7', 'CODIGO INVALIDO', '4', '6', '96', '71', '-7']
# 9011 ['469671-9', 'NAO SE APLICA', '4', '6', '96', '71', '-9']
# 9012 ['46967100', 'PRINCIPAL DA DIVIDA CONTRATUAL RESGATADO', '4', '6', '96', '71', '00']
# 9013 ['469673-7', 'CODIGO INVALIDO', '4', '6', '96', '73', '-7']
# 9014 ['469673-9', 'NAO SE APLICA', '4', '6', '96', '73', '-9']
# 9015 ['46967300', 'CM OU CAMBIAL DA DIVIDA CONTRATUAL RESGATADA', '4', '6', '96', '73', '00']
# 9016 ['469677-7', 'CODIGO INVALIDO', '4', '6', '96', '77', '-7']
# 9017 ['469677-9', 'NAO SE APLICA', '4', '6', '96', '77', '-9']
# 9018 ['46967700', 'PRINCIPAL CORRIGIDO DA DIVIDA CONTRATUAL RESG', '4', '6', '96', '77', '00']
# 9019 ['469691-7', 'CODIGO INVALIDO', '4', '6', '96', '91', '-7']
# 9020 ['469691-9', 'NAO SE APLICA', '4', '6', '96', '91', '-9']
# 9021 ['46969100', 'SENTENCAS JUDICIAIS', '4', '6', '96', '91', '00']
# 9022 ['469692-7', 'CODIGO INVALIDO', '4', '6', '96', '92', '-7']
# 9023 ['469692-9', 'NAO SE APLICA', '4', '6', '96', '92', '-9']
# 9024 ['46969200', 'DESPESAS DE EXERCICIOS ANTERIORES', '4', '6', '96', '92', '00']
# 9025 ['469693-7', 'CODIGO INVALIDO', '4', '6', '96', '93', '-7']
# 9026 ['469693-9', 'NAO SE APLICA', '4', '6', '96', '93', '-9']
# 9027 ['46969300', 'INDENIZACOES E RESTITUICOES', '4', '6', '96', '93', '00']
# 9028 ['53322005', 'AMAZONAS', '-7', '-7', '-7', '-7', '05']
# 9029 ['69034668', 'CODIGO INEXISTENTE NO SIAFI', '6', '9', '03', '46', '68']
# 9030 ['800000-7', 'CODIGO INVALIDO', '8', '0', '00', '00', '-7']
# 9031 ['800000-9', 'NAO SE APLICA', '8', '0', '00', '00', '-9']
# 9032 ['80000000', 'PASSIVO FINANCEIRO', '8', '0', '00', '00', '00']
# 9033 ['880000-7', 'CODIGO INVALIDO', '8', '8', '00', '00', '-7']
# 9034 ['880000-9', 'NAO SE APLICA', '8', '8', '00', '00', '-9']
# 9035 ['88000000', 'PASSIVO FINANCEIRO', '8', '8', '00', '00', '00']
# 9036 ['900000-7', 'CODIGO INVALIDO', '9', '0', '00', '00', '-7']
# 9037 ['900000-9', 'NAO SE APLICA', '9', '0', '00', '00', '-9']
# 9038 ['90000000', 'RESERVA DE CONTINGENCIA', '9', '0', '00', '00', '00']
# 9039 ['92802784', 'CODIGO INEXISTENTE NO SIAFI', '9', '2', '80', '27', '84']
# 9040 ['990000-7', 'CODIGO INVALIDO', '9', '9', '00', '00', '-7']
# 9041 ['990000-9', 'NAO SE APLICA', '9', '9', '00', '00', '-9']
# 9042 ['99000000', 'RESERVA DE CONTINGENCIA', '9', '9', '00', '00', '00']
# 9043 ['994000', 'SEM INFORMACAO', '9', '9', '40', '00', '-8']
# 9044 ['994000-7', 'CODIGO INVALIDO', '9', '9', '40', '00', '-7']
# 9045 ['994000-9', 'NAO SE APLICA', '9', '9', '40', '00', '-9']
# 9046 ['99400000', 'TRANSFERENCIAS A MUNICIPIOS', '9', '9', '40', '00', '00']
# 9047 ['999000', 'CODIGO INEXISTENTE NO SIAFI', '9', '9', '90', '00', '30']
# 9048 ['999000-7', 'CODIGO INVALIDO', '9', '9', '90', '00', '-7']
# 9049 ['999000-9', 'NAO SE APLICA', '9', '9', '90', '00', '-9']
# 9050 ['99900000', 'APLICACOES DIRETAS', '9', '9', '90', '00', '00']
# 9051 ['999900-7', 'CODIGO INVALIDO', '9', '9', '99', '00', '-7']
# 9052 ['999900-8', 'SEM INFORMACAO', '9', '9', '99', '00', '-8']
# 9053 ['999900-9', 'NAO SE APLICA', '9', '9', '99', '00', '-9']
# 9054 ['99990000', 'RESERVA DE CONTINGENCIA', '9', '9', '99', '00', '00']
# 9055 ['999999', 'SEM INFORMACAO', '9', '9', '99', '99', '-8']
# 9056 ['999999-7', 'CODIGO INVALIDO', '9', '9', '99', '99', '-7']
# 9057 ['999999-9', 'NAO SE APLICA', '9', '9', '99', '99', '-9']
# 9058 ['99999900', 'RESERVA DE CONTINGENCIA', '9', '9', '99', '99', '00']
# 9059 ['99999999', 'RESERVA DE CONTINGENCIA', '9', '9', '99', '99', '99']

# %%
for registro in  NaturezaDespesaDetalhadaLimpa:
    engine.execute('INSERT INTO tbl_FCDFNaturezaDespesaDetalhada (nfc_Codigo, nfc_Descricao, nfc_CategoriaEconomica, nfc_GrupoDespesa, nfc_ModalidadeAplicacao, nfc_ElementoDespesa) values ("'+registro[0]+'","'+registro[1]+'","'+registro[2]+'","'+registro[3]+'","'+registro[4]+'","'+registro[5]+'");')
