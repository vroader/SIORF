# %%
import pandas as pd
import sqlalchemy
import csv

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://siorf:PMseis06@mysql.siorf.kinghost.net:3306/siorf')

# %%
dfPIO = pd.read_csv('tbl_FCDFPlanoInterno.csv', delimiter = ';')
dfPIO
# Out:
#      Proposta  Quantidade             Valor
# 0          27         NaN   213.946.190,90
# 1          28         NaN   155.948.303,20
# 2          29         NaN    66.707.177,68
# 3          30         NaN     1.568.253,30
# 4          32         NaN   140.993.790,80
# ..        ...         ...               ...
# 107       327         1.0       500.000,00
# 108       328         1.0     1.000.000,00
# 109       267         1.0     7.872.600,00
# 110       268      2162.0     1.982.128,00
# 111       269         NaN     3.488.142,00
#
# [112 rows x 3 columns]

# %%
dfPIO['Valor'] = [x.replace('.','') for x in dfPIO['Valor']]
dfPIO['Valor'] = [x.replace(',', '.') for x in dfPIO['Valor']]
dfPIO
# Out:
#      Proposta  Quantidade           Valor
# 0          27         NaN   213946190.90
# 1          28         NaN   155948303.20
# 2          29         NaN    66707177.68
# 3          30         NaN     1568253.30
# 4          32         NaN   140993790.80
# ..        ...         ...             ...
# 107       327         1.0      500000.00
# 108       328         1.0     1000000.00
# 109       267         1.0     7872600.00
# 110       268      2162.0     1982128.00
# 111       269         NaN     3488142.00
#
# [112 rows x 3 columns]

# %%
propostaFCDF = pd.read_sql_table('tbl_FCDFProposta', engine)
propostaSetorial = pd.read_sql_table('tbl_PropostaSetorial',engine)
cadastro = pd.read_sql_table('tbl_CadastroDemandas',engine)

# %%
cadastro.head(1)
# Out:
#    Id_CadastroDemandas  cad_CodigoDemanda cad_CoordenadorSetorial  \
# 0                    1                174                     CCS
#
#            cad_Descricao cad_FCDFDespesaDetalhada cad_GDFDespesaDetalhada  \
# 0  Aquisição de medalhas                 33903105
#
#    cad_ProdutoUnidade  cad_Periodicidade  cad_EspecieDisponibilidade  \
# 0                 0.0                1.0                         5.0
#
#   cad_Observacao cad_DataInclusao
# 0           None              NaT

# %%
dfPIO1 = dfPIO.merge(cadastro, left_on='Proposta', right_on='cad_CodigoDemanda', how = 'left')
dfPIO1
# Out:
#      Proposta  Quantidade           Valor  Id_CadastroDemandas  \
# 0          27         NaN   213946190.90                   228
# 1          28         NaN   155948303.20                   229
# 2          29         NaN    66707177.68                   230
# 3          30         NaN     1568253.30                   231
# 4          32         NaN   140993790.80                   232
# ..        ...         ...             ...                  ...
# 107       327         1.0      500000.00                   130
# 108       328         1.0     1000000.00                   131
# 109       267         1.0     7872600.00                   294
# 110       268      2162.0     1982128.00                   253
# 111       269         NaN     3488142.00                   254
#
#      cad_CodigoDemanda cad_CoordenadorSetorial  \
# 0                   27                     DPP
# 1                   28                     DPP
# 2                   29                     DPP
# ...

# %%
propostaSetorial.head(1)
# Out:
#    Id_PropostaSetorial  pps_CadastroDemanda  \
# 0                    1                  241
#
#                          pps_Justificativa pps_alinhamentoEstrategico  \
# 0  LEI N° 10.486/2002 E LEI N° 12.086/2022                      1.2.1
#
#    pps_Quantidade   pps_Valor pps_Observacao pps_UnidadeDemandante  \
# 0          126648  34843636.0            nan                  DPPP
#
#    pps_Exercicio
# 0           2021

# %%
dfPIO2 = dfPIO1.merge(propostaSetorial, left_on='Id_CadastroDemandas', right_on='pps_CadastroDemanda', how = 'left')

# %%
dfPIO2.head(1)
# Out:
#    Proposta  Quantidade           Valor  Id_CadastroDemandas  \
# 0        27         NaN   213946190.90                   228
#
#    cad_CodigoDemanda cad_CoordenadorSetorial cad_Descricao  \
# 0                 27                     DPP         Soldo
#
#   cad_FCDFDespesaDetalhada cad_GDFDespesaDetalhada  cad_ProdutoUnidade  ...  \
# 0                 31901201                                       261.0  ...
#
#    cad_DataInclusao  Id_PropostaSetorial pps_CadastroDemanda  \
# 0               NaT                   23                 228
#
#                          pps_Justificativa  pps_alinhamentoEstrategico  \
# 0  LEI N° 10.486/2002 E LEI N° 12.086/2009                       1.2.1
#
#    pps_Quantidade    pps_Valor pps_Observacao  pps_UnidadeDemandante  \
# 0          144636  230354573.0            nan                   DPPP
#
#    pps_Exercicio
# 0           2021
#
# [1 rows x 23 columns]

# %%
propostaGDF.head(1)
# Out:
#    Id_FCDFProposta  prf_PropostaSetorial  prf_Quantidade  prf_Valor prf_Fonte  \
# 0                1                   116              12    20000.0       100
#
#   prf_Funcao prf_Subfuncao prf_Programa prf_Acao prf_Subtitulo
# 0         28           845         0903     00NR          0053

# %%
dfPIO3 = dfPIO2.merge(propostaFCDF, left_on = 'Id_PropostaSetorial', right_on='prf_PropostaSetorial', how = 'left')
dfPIO3.head(1)
# Out:
#    Proposta  Quantidade           Valor  Id_CadastroDemandas  \
# 0        27         NaN   213946190.90                   228
#
#    cad_CodigoDemanda cad_CoordenadorSetorial cad_Descricao  \
# 0                 27                     DPP         Soldo
#
#   cad_FCDFDespesaDetalhada cad_GDFDespesaDetalhada  cad_ProdutoUnidade  ...  \
# 0                 31901201                                       261.0  ...
#
#    Id_FCDFProposta  prf_PropostaSetorial prf_Quantidade    prf_Valor  \
# 0            266.0                  23.0       144636.0  230354573.0
#
#    prf_Fonte  prf_Funcao prf_Subfuncao prf_Programa  prf_Acao  prf_Subtitulo
# 0        100          28           845         0903      00NR           0053
#
# [1 rows x 33 columns]

# %%
dfPIOFINAL = dfPIO3[['Id_FCDFProposta', 'Quantidade', 'Valor']]
dfPIOFINAL
# Out:
#      Id_FCDFProposta  Quantidade           Valor
# 0              266.0         NaN   213946190.90
# 1              267.0         NaN   155948303.20
# 2              268.0         NaN    66707177.68
# 3              269.0         NaN     1568253.30
# 4              270.0         NaN   140993790.80
# ..               ...         ...             ...
# 108            121.0         1.0      500000.00
# 109            122.0         1.0     1000000.00
# 110             76.0         1.0     7872600.00
# 111             77.0      2162.0     1982128.00
# 112             78.0         NaN     3488142.00
#
# [113 rows x 3 columns]

# %%
#Agora transformar o DataFrame em uma lista para ser inserido no MYSQL
list_PIO = dfPIOFINAL.values.tolist()
PIO = []
#Transformando dados 'int' em string'
for lista in list_PIO:
    linha = []
    for registro in lista:
        registro = str(registro)
        linha.append(registro)
    PIO.append(linha)
print(PIO)
# Out:
# [['266.0', 'nan', ' 213946190.90 '], ['267.0', 'nan', ' 155948303.20 '], ['268.0', 'nan', ' 66707177.68 '], ['269.0', 'nan', ' 1568253.30 '], ['270.0', 'nan', ' 140993790.80 '], ['277.0', 'nan', ' 96000000.00 '], ['271.0', 'nan', ' 478481814.70 '], ['278.0', 'nan', ' 30000000.00 '], ['272.0', 'nan', ' 89578663.62 '], ['273.0', 'nan', ' 24781602.01 '], ['274.0', 'nan', ' 12914022.24 '], ['275.0', 'nan', ' 1413.48 '], ['276.0', 'nan', ' 110000000.00 '], ['282.0', 'nan', ' 34843636.20 '], ['283.0', 'nan', ' 4421741.52 '], ['284.0', 'nan', ' 446097878.80 '], ['285.0', 'nan', ' 240697190.80 '], ['286.0', 'nan', ' 534635935.30 '], ['287.0', 'nan', ' 5000000.00 '], ['288.0', 'nan', ' 91001829.00 '], ['289.0', 'nan', ' 880662.48 '], ['290.0', 'nan', ' 289000000.00 '], ['291.0', 'nan', ' 22458274.00 '], ['292.0', '12053.0', ' 117150750.00 '], ['293.0', '42199.0', ' 13726685.00 '], ['295.0', '170.0', ' 1600000.00 '], ['294.0', '515.0', ' 1000004.00 '], ['262.0', '1800.0', ' 200000.00 '], ['nan
# ...

# %%
for registro in PIO:
    engine.execute('SET FOREIGN_KEY_CHECKS=0;')
    engine.execute('INSERT INTO tbl_FCDFPlanoInterno ( pif_Proposta, pif_Quantidade, pif_Valor) values ("'+registro[0]+'","'+registro[1]+'","'+registro[2]+'");')
