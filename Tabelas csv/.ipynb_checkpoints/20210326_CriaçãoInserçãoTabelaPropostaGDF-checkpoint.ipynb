# %%
import pandas as pd
import sqlalchemy
import csv

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://siorf:PMseis06@mysql.siorf.kinghost.net:3306/siorf')

# %%
#Não foi possível localizar as tabelas que deram origem à Proposta encaminhada à Sutes
#Os planos de aquisição encaminhados não coincidem com a proposta encaminhada à Sutes
#É importante que exista a classificação programática da tbl_FDFProposta, todavia não será possível informar os valores para 2021
#Para fazer uma classificação programática serão utilizadas as tabelas tbl_PropostaSetorial e tbl_Cadastro e Demandas
#Com as tabelas mescladas será possível estabelecer os critérios para definir os programas em que cada demanda se enquadra
Proposta1 = pd.read_sql_table('tbl_PropostaSetorial',engine)
Cadastro = pd.read_sql_table('tbl_CadastroDemandas',engine)
Proposta1.head(3)
# Out:
#    Id_PropostaSetorial  pps_CadastroDemanda  \
# 0                    1                  241
# 1                    2                  223
# 2                    3                  242
#
#                          pps_Justificativa pps_alinhamentoEstrategico  \
# 0  LEI N° 10.486/2002 E LEI N° 12.086/2022                      1.2.1
# 1      LEI N° 840/2018/DECRETO 40.610/2030                      1.2.1
# 2  LEI N° 10.486/2002 E LEI N° 12.086/2023                      1.2.1
#
#    pps_Quantidade   pps_Valor pps_Observacao pps_UnidadeDemandante  \
# 0          126648  34843636.0            nan                  DPPP
# 1             370  18997202.0            nan                  DPPP
# 2          126648   4421741.0            nan                  DPPP
#
#    pps_Exercicio
# 0           2021
# 1           2021
# 2           2021

# %%
Cadastro.head(3)
# Out:
#    Id_CadastroDemandas  cad_CodigoDemanda cad_CoordenadorSetorial  \
# 0                    1                174                     CCS
# 1                    2                181                     DOP
# 2                    3                182                     DOP
#
#                 cad_Descricao cad_FCDFDespesaDetalhada  \
# 0       Aquisição de medalhas                 33903105
# 1                  Taxas Anac                 33904710
# 2  Abastecimento de aeronaves                 33903002
#
#   cad_GDFDespesaDetalhada  cad_ProdutoUnidade  cad_Periodicidade  \
# 0                                         0.0                1.0
# 1                                         0.0                1.0
# 2                                         0.0                1.0
#
#    cad_EspecieDisponibilidade cad_Observacao cad_DataInclusao
# 0                         5.0           None              NaT
# 1                         1.0           None              NaT
# ...

# %%
Proposta2 = Proposta1.merge(Cadastro, left_on='pps_CadastroDemanda', right_on='Id_CadastroDemandas')

# %%
#Comando realizado para verificar se as tabelas mescladas estão corretas (durante a inserção da tabela PropostaSetorial verifiquei a duplicidade)
Proposta2.loc[Proposta2['pps_CadastroDemanda']==198]
# Out:
#     Id_PropostaSetorial  pps_CadastroDemanda  \
# 45                   46                  198
# 46                   47                  198
#
#                           pps_Justificativa pps_alinhamentoEstrategico  \
# 45  LEI N° 10.486/2002 E LEI N° 12.086/2032                      1.2.1
# 46      LEI N° 840/2018/DECRETO 40.610/2026                      1.2.1
#
#     pps_Quantidade  pps_Valor pps_Observacao pps_UnidadeDemandante  \
# 45            1800   450000.0            nan                  DPPP
# 46             330   100000.0            nan                  DPPP
#
#     pps_Exercicio  Id_CadastroDemandas  cad_CodigoDemanda  \
# 45           2021                  198                 61
# 46           2021                  198                 61
#
#    cad_CoordenadorSetorial   cad_Descricao cad_FCDFDespesaDetalhada  \
# 45                     DPP  Diária no País                 33901514
# 46                     DPP  Diária no País                 33901514
#
# ...

# %%
#Construindo a tbl_FCDFProposta programa por programa
FCDFProposta = Proposta2.set_index('cad_CoordenadorSetorial')

# %%
FCDFPropostaDLF1 = FCDFProposta.loc[['CCS','DINFRA','DPTS', 'DCC', 'DEC','DITEL','CI','DOP'], ['Id_PropostaSetorial', 'pps_Quantidade', 'pps_Valor']]

# %%
FCDFPropostaDLF2 =FCDFPropostaDLF1.assign(Fonte='100', Função = '28', SubFunção = '845', Programa = '0903', Ação = '00NR', Subtítulo = '0053')

# %%
FCDFPropostaDLF2
# Out:
#                          Id_PropostaSetorial  pps_Quantidade  pps_Valor Fonte  \
# cad_CoordenadorSetorial
# CCS                                      116              12    20000.0   100
# CCS                                      117               6    20000.0   100
# CCS                                      118              12    20000.0   100
# CCS                                      119               1   150000.0   100
# CCS                                      120               1    50000.0   100
# ...                                      ...             ...        ...   ...
# DOP                                      193               0    40000.0   100
# DOP                                      194               0  1200000.0   100
# DOP                                      197               6    14000.0   100
# DOP                                      202               0   900000.0   100
# DOP                                      207               0   900000.0   100
#
# ...

# %%
#Proposta DSAP
FCDFPropostaDSAP1 = FCDFProposta.loc[['DPGC', 'DAO'], ['Id_PropostaSetorial', 'pps_Quantidade', 'pps_Valor']]

# %%
FCDFPropostaDSAP2 = FCDFPropostaDSAP1.assign(Fonte='100', Função = '28', SubFunção = '845', Programa = '0903', Ação = '00FM', Subtítulo = '0053')

# %%
FCDFPropostaDSAP2
# Out:
#                          Id_PropostaSetorial  pps_Quantidade  pps_Valor Fonte  \
# cad_CoordenadorSetorial
# DPGC                                      57               0   650000.0   100
# DPGC                                      59               0   893584.0   100
# DPGC                                      60               0   115000.0   100
# DPGC                                      61               0    12000.0   100
# DPGC                                      62               0   920000.0   100
# ...                                      ...             ...        ...   ...
# DAO                                      113               0  1800000.0   100
# DAO                                      114               0   115000.0   100
# DAO                                      115               0    65000.0   100
# DAO                                      315               0   501200.0   100
# DAO                                      316               0  2421586.0   100
#
# ...

# %%
FCDFPropostaDPP1 = FCDFProposta.loc[['DPP'], [ 'cad_FCDFDespesaDetalhada','Id_PropostaSetorial', 'pps_Quantidade', 'pps_Valor']]

# %%
FCDFPropostaDPP2 = FCDFPropostaDPP1.set_index('cad_FCDFDespesaDetalhada')
FCDFPropostaDPP2
# Out:
#                           Id_PropostaSetorial  pps_Quantidade    pps_Valor
# cad_FCDFDespesaDetalhada
# 31900109                                    1          126648   34843636.0
#                                             2             370   18997202.0
# 31900115                                    3          126648    4421741.0
# 31900117                                    4          126648  446097878.0
# 31900121                                    5          126648  240697190.0
# 31900122                                    6          126648  534635935.0
# 31900123                                    7          126648    5400089.0
# 31900126                                    8           10554   95281452.0
#                                             9            4440    1583100.0
#                                            10            4440    2773962.0
# 31900302                                   11           58704  288339863.0
# ...

# %%
FCDFPropostaDPPNR = FCDFPropostaDPP2.loc[['33901514', '33901516', '33901901', '33905901', '31901201', '31901204', '31901206', '31901208', '31901209', '31901211', '31901243', '31901245', '31901287', '31909114', '31909415', '31901210', '31901242'], ['Id_PropostaSetorial', 'pps_Quantidade', 'pps_Valor' ]]
FCDFPropostaDPPNR
# Out:
#                           Id_PropostaSetorial  pps_Quantidade    pps_Valor
# cad_FCDFDespesaDetalhada
# 33901514                                   46            1800     450000.0
# 33901514                                   47             330     100000.0
# 33901516                                   48             900     350000.0
# 33901901                                   49           12053   24755223.0
# 33905901                                   53              12      95062.0
# 31901201                                   23          144636  230354573.0
# 31901204                                   24          144636  165917967.0
# 31901206                                   25          144636   70776531.0
# 31901208                                   26          144636    1671914.0
# 31901209                                   28          144636  152517596.0
# 31901211                                   30          144636  527653219.0
# ...

# %%
FCDFPropostaDPPNR1 = FCDFPropostaDPPNR.assign(Fonte='100', Função = '28', SubFunção = '845', Programa = '0903', Ação = '00NR', Subtítulo = '0053')

# %%
FCDFPropostaDPPNR2 = FCDFPropostaDPPNR1.query('Id_PropostaSetorial!=47')
FCDFPropostaDPPNR2
# Out:
#                           Id_PropostaSetorial  pps_Quantidade    pps_Valor  \
# cad_FCDFDespesaDetalhada
# 33901514                                   46            1800     450000.0
# 33901516                                   48             900     350000.0
# 33901901                                   49           12053   24755223.0
# 33905901                                   53              12      95062.0
# 31901201                                   23          144636  230354573.0
# 31901204                                   24          144636  165917967.0
# 31901206                                   25          144636   70776531.0
# 31901208                                   26          144636    1671914.0
# 31901209                                   28          144636  152517596.0
# 31901211                                   30          144636  527653219.0
# 31901243                                   34           12053   89365604.0
# ...

# %%
FCDFPropostaDPPRS = FCDFPropostaDPP2.loc[['33909318', '33909319', '33909320'], ['Id_PropostaSetorial', 'pps_Quantidade', 'pps_Valor' ]].assign(Fonte='100', Função = '28', SubFunção = '845', Programa = '0903', Ação = '00RS', Subtítulo = '0053')

# %%
FCDFPropostaDPPRS
# Out:
#                           Id_PropostaSetorial  pps_Quantidade    pps_Valor  \
# cad_FCDFDespesaDetalhada
# 33909318                                   54             900   33000000.0
# 33909319                                   55             375     700000.0
# 33909320                                   56           22607  433012458.0
#
#                          Fonte Função SubFunção Programa  Ação Subtítulo
# cad_FCDFDespesaDetalhada
# 33909318                   100     28       845     0903  00RS      0053
# 33909319                   100     28       845     0903  00RS      0053
# 33909320                   100     28       845     0903  00RS      0053

# %%
FCDFPropostaDPPNS = FCDFPropostaDPP2.loc[['31900109', '31900115', '31900117', '31900121', '31900122', '31900123', '31900126', '31909115'], ['Id_PropostaSetorial', 'pps_Quantidade', 'pps_Valor' ]].assign(Fonte='100', Função = '28', SubFunção = '845', Programa = '0903', Ação = '00NS', Subtítulo = '0053')

# %%
FCDFPropostaDPPNS
# Out:
#                           Id_PropostaSetorial  pps_Quantidade    pps_Valor  \
# cad_FCDFDespesaDetalhada
# 31900109                                    1          126648   34843636.0
# 31900115                                    3          126648    4421741.0
# 31900117                                    4          126648  446097878.0
# 31900121                                    5          126648  240697190.0
# 31900122                                    6          126648  534635935.0
# 31900123                                    7          126648    5400089.0
# 31900126                                    8           10554   95281452.0
# 31909115                                   39             300     880662.0
#
#                          Fonte Função SubFunção Programa  Ação Subtítulo
# cad_FCDFDespesaDetalhada
# 31900109                   100     28       845     0903  00NS      0053
# 31900115                   100     28       845     0903  00NS      0053
# ...

# %%
FCDFPropostaDPPQ2 = FCDFPropostaDPP2.loc[['31900302', '31900304'], ['Id_PropostaSetorial', 'pps_Quantidade', 'pps_Valor' ]].assign(Fonte='100', Função = '28', SubFunção = '845', Programa = '0903', Ação = '00Q2', Subtítulo = '0053')

# %%
FCDFPropostaDPPQ2
# Out:
#                           Id_PropostaSetorial  pps_Quantidade    pps_Valor  \
# cad_FCDFDespesaDetalhada
# 31900302                                   11           58704  288339863.0
# 31900304                                   12            4892   22056646.0
#
#                          Fonte Função SubFunção Programa  Ação Subtítulo
# cad_FCDFDespesaDetalhada
# 31900302                   100     28       845     0903  00Q2      0053
# 31900304                   100     28       845     0903  00Q2      0053

# %%
dfPropostaFCDF = [FCDFPropostaDLF2, FCDFPropostaDSAP2, FCDFPropostaDPPNR2, FCDFPropostaDPPRS, FCDFPropostaDPPNS, FCDFPropostaDPPQ2]

# %%
dfPropostaFCDFFinal = pd.concat(dfPropostaFCDF)
dfPropostaFCDFFinal
# Out:
#           Id_PropostaSetorial  pps_Quantidade    pps_Valor Fonte Função  \
# CCS                       116              12      20000.0   100     28
# CCS                       117               6      20000.0   100     28
# CCS                       118              12      20000.0   100     28
# CCS                       119               1     150000.0   100     28
# CCS                       120               1      50000.0   100     28
# ...                       ...             ...          ...   ...    ...
# 31900123                    7          126648    5400089.0   100     28
# 31900126                    8           10554   95281452.0   100     28
# 31909115                   39             300     880662.0   100     28
# 31900302                   11           58704  288339863.0   100     28
# 31900304                   12            4892   22056646.0   100     28
#
#          SubFunção Programa  Ação Subtítulo
# CCS            845     0903  00NR      0053
# ...

# %%
#Agora transformar o DataFrame em uma lista para ser inserido no MYSQL
list_Proposta = dfPropostaFCDFFinal.values.tolist()
Proposta = []
#Transformando dados 'int' em string'
for lista in list_Proposta:
    linha = []
    for registro in lista:
        registro = str(registro)
        linha.append(registro)
    Proposta.append(linha)
print(Proposta)
# Out:
# [['116', '12', '20000.0', '100', '28', '845', '0903', '00NR', '0053'], ['117', '6', '20000.0', '100', '28', '845', '0903', '00NR', '0053'], ['118', '12', '20000.0', '100', '28', '845', '0903', '00NR', '0053'], ['119', '1', '150000.0', '100', '28', '845', '0903', '00NR', '0053'], ['120', '1', '50000.0', '100', '28', '845', '0903', '00NR', '0053'], ['121', '12', '900000.0', '100', '28', '845', '0903', '00NR', '0053'], ['122', '1', '180000.0', '100', '28', '845', '0903', '00NR', '0053'], ['242', '0', '11000000.0', '100', '28', '845', '0903', '00NR', '0053'], ['243', '0', '1000.0', '100', '28', '845', '0903', '00NR', '0053'], ['244', '0', '1000.0', '100', '28', '845', '0903', '00NR', '0053'], ['245', '0', '9000000.0', '100', '28', '845', '0903', '00NR', '0053'], ['246', '0', '5000000.0', '100', '28', '845', '0903', '00NR', '0053'], ['247', '0', '700000.0', '100', '28', '845', '0903', '00NR', '0053'], ['248', '0', '700000.0', '100', '28', '845', '0903', '00NR', '0053'], ['249', '0', '2000
# ...

# %%
for registro in Proposta:
    engine.execute('SET FOREIGN_KEY_CHECKS=0;')
    engine.execute('INSERT INTO tbl_FCDFProposta ( prf_PropostaSetorial, prf_Quantidade, prf_Valor, prf_Fonte, prf_Funcao, prf_Subfuncao, prf_Programa, prf_Acao, prf_Subtitulo) values ("'+registro[0]+'","'+registro[1]+'","'+registro[2]+'","'+registro[3]+'","'+registro[4]+'","'+registro[5]+'","'+registro[6]+'","'+registro[7]+'","'+registro[8]+'");')
